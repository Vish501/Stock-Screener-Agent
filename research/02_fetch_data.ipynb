# %% [markdown]
# # Environment Setting Up

# %%
import os
from dotenv import load_dotenv

# Loading environment variables from .env
load_dotenv()

# Changing directory to main directory for easy data access
working_directory = os.getenv("WORKING_DIRECTORY")
os.chdir(working_directory)

# Checking the change
# %pwd
# Out:
# 'D:\\Projects\\Stock Screener\\Stock-Screener-Agent'

# %%
from pathlib import Path

# Checking the change
print("Git folder exists:", Path(".git").exists())
# Out:
# Git folder exists: True

# %% [markdown]
# # 2. Fetch Data

# %% [markdown]
# ## Stock Price Data

# %%
# Cache Manager
# Avoid redundant API calls by checking last fetch timestamps

from datetime import datetime, timedelta
from StockScreener.utils.common import load_json, save_json, create_directories
import json

# Define where cache index JSON will be stored.
# Uses the working_directory environment variable if available.
WORK_DIR = Path(working_directory) / "artifacts"
CACHE_PATH = WORK_DIR / "cache_index.json"

# Define how long cache entries remain valid.
CACHE_EXPIRY_HOURS = 6

def update_cache_index(ticker: str, data_type: str) -> None:
    """
    Update or create a cache entry for the given ticker and data type.

    Args:
        ticker (str): Stock symbol (e.g., "AAPL").
        data_type (str): Type of data cached (e.g., "price", "news").
    """
    # Ensure the cache directory exists
    create_directories([WORK_DIR])

    ticker = ticker.upper()

    # Load the cache file if it exists, else create an empty dict
    try:
        cache = load_json(CACHE_PATH)
    except:
        cache = {}

    # Update timestamp for this ticker + data_type
    cache.setdefault(ticker, {})[data_type] = datetime.now().isoformat()

    # Save back to JSON
    save_json(save_path=CACHE_PATH, data=cache)


def is_cache_stale(ticker: str, data_type: str) -> bool:
    """
    Determine if cache for a given ticker and data_type is expired or missing.

    Args:
        ticker (str): Stock symbol (e.g., "AAPL").
        data_type (str): Type of data cached (e.g., "price", "news").

    Returns:
        bool: True if cache is stale or missing, False if still valid.
    """
    # Ensure the cache directory exists
    create_directories([WORK_DIR])

    ticker = ticker.upper()
    
    # Load cache safely
    try:
        cache = load_json(CACHE_PATH)
        entry = cache.get(ticker, {}).get(data_type)
    except (FileNotFoundError, json.JSONDecodeError):
        return True

    # If no entry found, it's stale
    if not entry:
        return True

    # Parse last updated timestamp and compare with expiry threshold
    last_updated = datetime.fromisoformat(entry)
    return datetime.now() - last_updated > timedelta(hours=CACHE_EXPIRY_HOURS)

# %%
import yfinance as yf
import pandas as pd

def fetch_prices(ticker: str):
    ticker = ticker.upper()
    load_path = f"artifacts/prices/{ticker}.pkl"

    if Path(load_path).exists() and not is_cache_stale(ticker, "prices"):
        return pd.read_pickle(load_path)
    
    df = yf.download(ticker, period="1y", interval="1d", auto_adjust=True)
    df.to_pickle(load_path)
    update_cache_index(ticker, "prices")
    return df

# %%
fetch_prices(ticker="AAPL")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [2025-10-27 18:17:49,932: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:17:49,932: ERROR: common: JSON file not found at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-27 18:17:49,932: ERROR: common: File not found: JSON file not found at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-27 18:17:49,932: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:17:49,932: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2024-10-25  230.338013  232.139626  228.506540  228.675751  38802300
# 2024-10-28  232.318787  233.642627  231.472733  232.239171  36087100
# 2024-10-29  232.587540  233.244486  231.243803  232.020188  35417200
# 2024-10-30  229.034088  232.388472  228.486633  231.532455  47070900
# 2024-10-31  224.863480  228.765318  224.325973  228.277583  64370100
# ...                ...         ...         ...         ...       ...
# 2025-10-20  262.239990  264.380005  255.630005  255.889999  90483000
# 2025-10-21  262.769989  265.290009  261.829987  261.880005  46695900
# 2025-10-22  258.450012  262.850006  255.429993  262.649994  45015300
# 2025-10-23  259.579987  260.619995  258.010010  259.940002  32754900
# 2025-10-24  262.820007  264.130005  259.179993  261.190002  38221700
#
# [250 rows x 5 columns]

# %% [markdown]
# ## Stock Fundamental Data

# %%
stock = yf.Ticker("AAPL")
info = stock.info  # Pulls full fundamental data
info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#  'fullTimeEmployees': 150000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Timothy D. Cook',
#    'age': 63,
#    'title': 'CEO & Director',
#    'yearBorn': 1961,
#    'fiscalYear': 2024,
#    'totalPay': 16520856,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Katherine L. Adams',
#    'age': 60,
#    'title': 'Senior VP & General Counsel',
#    'yearBorn': 1964,
#    'fiscalYear': 2024,
#    'totalPay': 5022182,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': "Ms. Deirdre  O'Brien",
#    'age': 57,
#    'title': 'Senior Vice President of Retail & People',
#    'yearBorn': 1967,
#    'fiscalYear': 2024,
#    'totalPay': 5022182,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jeffrey E. Williams',
#    'age': 60,
#    'title': 'Senior Vice President of Design, Watch, & Health',
#    'yearBorn': 1964,
#    'fiscalYear': 2024,
#    'totalPay': 5020737,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Kevan  Parekh',
#    'age': 52,
#    'title': 'Senior VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Sabih  Khan',
#    'title': 'Chief Operating Officer',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Chris  Kondo',
#    'title': 'Senior Director of Corporate Accounting',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Suhasini  Chandramouli',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Kristin Huguet Quayle',
#    'title': 'Vice President of Worldwide Communications',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Greg  Joswiak',
#    'title': 'Senior Vice President of Worldwide Marketing',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 7,
#  'boardRisk': 1,
#  'compensationRisk': 3,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 1,
#  'governanceEpochDate': 1759276800,
#  'compensationAsOfEpochDate': 1735603200,
#  'irWebsite': 'http://investor.apple.com/',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 259.58,
#  'open': 261.19,
#  'dayLow': 259.18,
#  'dayHigh': 264.13,
#  'regularMarketPreviousClose': 259.58,
#  'regularMarketOpen': 261.19,
#  'regularMarketDayLow': 259.18,
#  'regularMarketDayHigh': 264.13,
#  'dividendRate': 1.04,
#  'dividendYield': 0.4,
#  'exDividendDate': 1754870400,
#  'payoutRatio': 0.1533,
#  'fiveYearAvgDividendYield': 0.54,
#  'beta': 1.094,
#  'trailingPE': 39.821213,
#  'forwardPE': 31.626955,
#  'volume': 38253717,
#  'regularMarketVolume': 38253717,
#  'averageVolume': 54728796,
#  'averageVolume10days': 44960930,
#  'averageDailyVolume10Day': 44960930,
#  'bid': 262.69,
#  'ask': 263.01,
#  'bidSize': 4,
#  'askSize': 4,
#  'marketCap': 3900351184896,
#  'fiftyTwoWeekLow': 169.21,
#  'fiftyTwoWeekHigh': 265.29,
#  'allTimeHigh': 265.29,
#  'allTimeLow': 0.049107,
#  'priceToSalesTrailing12Months': 9.545063,
#  'fiftyDayAverage': 244.1418,
#  'twoHundredDayAverage': 222.4811,
#  'trailingAnnualDividendRate': 1.01,
#  'trailingAnnualDividendYield': 0.0038909009,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 3946677272576,
#  'profitMargins': 0.24295999,
#  'floatShares': 14814270914,
#  'sharesOutstanding': 14840390000,
#  'sharesShort': 109135657,
#  'sharesShortPriorMonth': 118199377,
#  'sharesShortPreviousMonthDate': 1757894400,
#  'dateShortInterest': 1760486400,
#  'sharesPercentSharesOut': 0.0074,
#  'heldPercentInsiders': 0.0197,
#  'heldPercentInstitutions': 0.63576,
#  'shortRatio': 2.08,
#  'shortPercentOfFloat': 0.0074,
#  'impliedSharesOutstanding': 14852540974,
#  'bookValue': 4.431,
#  'priceToBook': 59.313923,
#  'lastFiscalYearEnd': 1727481600,
#  'nextFiscalYearEnd': 1759017600,
#  'mostRecentQuarter': 1751068800,
#  'earningsQuarterlyGrowth': 0.093,
#  'netIncomeToCommon': 99280003072,
#  'trailingEps': 6.6,
#  'forwardEps': 8.31,
#  'lastSplitFactor': '4:1',
#  'lastSplitDate': 1598832000,
#  'enterpriseToRevenue': 9.658,
#  'enterpriseToEbitda': 27.853,
#  '52WeekChange': 0.12604976,
#  'SandP52WeekChange': 0.16625166,
#  'lastDividendValue': 0.26,
#  'lastDividendDate': 1754870400,
#  'quoteType': 'EQUITY',
#  'currentPrice': 262.82,
#  'targetHighPrice': 315.0,
#  'targetLowPrice': 180.0,
#  'targetMeanPrice': 253.56757,
#  'targetMedianPrice': 260.0,
#  'recommendationMean': 2.04167,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 41,
#  'totalCash': 55372001280,
#  'totalCashPerShare': 3.731,
#  'ebitda': 141696008192,
#  'totalDebt': 101698002944,
#  'quickRatio': 0.724,
#  'currentRatio': 0.868,
#  'totalRevenue': 408624988160,
#  'debtToEquity': 154.486,
#  'revenuePerShare': 27.173,
#  'returnOnAssets': 0.24545999,
#  'returnOnEquity': 1.49814,
#  'grossProfits': 190739005440,
#  'freeCashflow': 94873747456,
#  'operatingCashflow': 108564996096,
#  'earningsGrowth': 0.121,
#  'revenueGrowth': 0.096,
#  'grossMargins': 0.46678,
#  'ebitdaMargins': 0.34675997,
#  'operatingMargins': 0.29990998,
#  'financialCurrency': 'USD',
#  'symbol': 'AAPL',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'preMarketChange': 2.4299927,
#  'preMarketChangePercent': 0.9245843,
#  'preMarketPrice': 265.25,
#  'regularMarketChange': 3.2400208,
#  'regularMarketDayRange': '259.18 - 264.13',
#  'fullExchangeName': 'NasdaqGS',
#  'averageDailyVolume3Month': 54728796,
#  'fiftyTwoWeekLowChange': 93.61,
#  'fiftyTwoWeekLowChangePercent': 0.5532179,
#  'fiftyTwoWeekRange': '169.21 - 265.29',
#  'fiftyTwoWeekHighChange': -2.4700012,
#  'fiftyTwoWeekHighChangePercent': -0.009310571,
#  'fiftyTwoWeekChangePercent': 12.604976,
#  'dividendDate': 1755129600,
#  'earningsTimestamp': 1761854400,
#  'earningsTimestampStart': 1761854400,
#  'earningsTimestampEnd': 1761854400,
#  'earningsCallTimestampStart': 1761858000,
#  'earningsCallTimestampEnd': 1761858000,
#  'isEarningsDateEstimate': False,
#  'epsTrailingTwelveMonths': 6.6,
#  'epsForward': 8.31,
#  'epsCurrentYear': 7.39031,
#  'priceEpsCurrentYear': 35.562786,
#  'fiftyDayAverageChange': 18.678207,
#  'fiftyDayAverageChangePercent': 0.07650557,
#  'twoHundredDayAverageChange': 40.338913,
#  'twoHundredDayAverageChangePercent': 0.18131389,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '2.0 - Buy',
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 345479400000,
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'cryptoTradeable': False,
#  'marketState': 'PRE',
#  'corporateActions': [],
#  'preMarketTime': 1761569262,
#  'regularMarketTime': 1761336001,
#  'exchange': 'NMS',
#  'messageBoardId': 'finmb_24937',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'regularMarketChangePercent': 1.2481781,
#  'regularMarketPrice': 262.82,
#  'displayName': 'Apple',
#  'trailingPegRatio': 2.4662}

# %%
stock = yf.Ticker("AAPL")
info = stock.info
info.get("sector").lower()
# Out:
# 'technology'

# %%
import yfinance as yf

def get_fundamental_data(ticker: str) -> dict:
    ticker = ticker.upper()
    stock = yf.Ticker(ticker)
    info = stock.info  # Pulls full fundamental data
    
    # Select only relevant keys
    fundamentals = {
        "PE": info.get("trailingPE"),
        "PB": info.get("priceToBook"),
        "PS": info.get("priceToSalesTrailing12Months"),
        "EV_EBITDA": info.get("enterpriseToEbitda"),
        "ROE": info.get("returnOnEquity"),
        "EPS": info.get("trailingEps"),
        "Book Value": info.get("bookValue"),
        "Sector": info.get("sector").lower(),
    }

    return fundamentals

df = get_fundamental_data(ticker="AAPL")
df
# Out:
# {'PE': 39.821213,
#  'PB': 59.313923,
#  'PS': 9.545063,
#  'EV_EBITDA': 27.853,
#  'ROE': 1.49814,
#  'EPS': 6.6,
#  'Book Value': 4.431,
#  'Sector': 'technology'}

# %%
import yfinance as yf

def get_fundamental_data(ticker: str) -> dict:
    ticker = ticker.upper()
    stock = yf.Ticker(ticker)
    info = stock.info  # Pulls full fundamental data
    
    # Select only relevant keys
    fundamentals = {
        "PE": info.get("trailingPE", "Not Found"),
        "PB": info.get("priceToBook", "Not Found"),
        "PS": info.get("priceToSalesTrailing12Months", "Not Found"),
        "EV_EBITDA": info.get("enterpriseToEbitda", "Not Found"),
        "ROE": info.get("returnOnEquity", "Not Found"),
        "EPS": info.get("trailingEps", "Not Found"),
        "Book Value": info.get("bookValue", "Not Found"),
        "Sector": info.get("sector", "Not Found").title(),
    }

    return fundamentals


def fetch_fundamentals(ticker: str):
    ticker = ticker.upper()
    load_path = WORK_DIR / f"fundamentals/{ticker}.json"

    if Path(load_path).exists() and not is_cache_stale(ticker, "fundamentals"):
        return load_json(load_path)
    
    data = get_fundamental_data(ticker)

    save_json(save_path=load_path, data=data)
    update_cache_index(ticker, "fundamentals")
    
    return data

# %%
fetch_fundamentals(ticker="AAPL")
# Out:
# [2025-10-27 18:17:50,734: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\fundamentals created successfully.]
# [2025-10-27 18:17:50,734: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\fundamentals\AAPL.json]
# [2025-10-27 18:17:50,734: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:17:50,749: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-27 18:17:50,749: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:17:50,749: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# {'PE': 39.821213,
#  'PB': 59.313923,
#  'PS': 9.545063,
#  'EV_EBITDA': 27.853,
#  'ROE': 1.49814,
#  'EPS': 6.6,
#  'Book Value': 4.431,
#  'Sector': 'Technology'}

# %% [markdown]
# ## Stock Sentiment Data

# %%
from transformers import pipeline
import requests
import os
from newspaper import Article
import trafilatura


def get_feed(ticker: str, look_back: int=7):
    ticker = ticker.upper()
    api_key = os.getenv("NEWS_API_KEY")
    url = f"https://newsapi.org/v2/everything?q={ticker}&from={(datetime.now()-timedelta(days=look_back)).date()}&apiKey={api_key}"
    res = requests.get(url).json()
    articles = res.get("articles", [])
    return articles


def fetch_article_text(url: str):
    try:
        article = Article(url)
        article.download()
        article.parse()
        if len(article.text.strip()) < 200:  # Too short, likely failed
            raise ValueError("Incomplete text")
        return article.text
    
    except Exception as e:
        print(f"Failed to parse {url}: {e}")
        return None


def get_content(article):
    url = article.get("url", None)

    if url:
        text = fetch_article_text(url)
        if text:
            return text
        try:
            downloaded = trafilatura.fetch_url(url)
            return trafilatura.extract(downloaded)
        except:
            pass
    
    return article.get("title" + ". ", "") + article.get("description", "")


def fetch_sentiment(ticker: str):
    ticker = ticker.upper()
    load_path = WORK_DIR / f"sentiment/{ticker}.json"

    if Path(load_path).exists() and not is_cache_stale(ticker, "sentiment"):
        return load_json(load_path)

    # Creating the sentiment analysis pipeline
    classifier = pipeline(task='text-classification', model='ProsusAI/finbert', device='cpu')
    
    ticker_feed = get_feed(ticker=ticker, look_back=10)

    total = 0
    num_articles = 0
    positive = 0
    total_articles = 0
    all_content = []

    for article in ticker_feed:
        title = article.get("title", "") or ""
        desc = article.get("description", "") or ""
        content = f"{title}. {desc}".strip()

        if content:
            sentiment = classifier(content)[0]
            total_articles += 1

            if sentiment["label"] == 'positive' or sentiment["label"] == 'negative':
                total += sentiment["score"]
                num_articles += 1
                all_content.append(content)

            if sentiment["label"] == "positive":
                positive += 1

    data = {"Overall Sentiment": total / num_articles,
            "Positive Articles": positive,
            "Negative Artciles": num_articles - positive,
            "Total Artciles": total_articles,
            "Category": "Positive" if total >= 0.2 else "Negative" if total <= 0.2 else "Neutral",
            "Contents": all_content,}

    save_json(save_path=load_path, data=data)
    update_cache_index(ticker, "sentiment")
    return data

# %%
arts = get_feed("aapl")

# %%
arts
# Out:
# [{'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Yahoo Finance Video',
#   'title': '3 most important things to watch with Big Tech earnings next week',
#   'description': 'Big Tech earnings are on deck next week with Magnificent Seven companies Microsoft (MSFT), Amazon (AMZN), Apple (AAPL), Alphabet (GOOG, GOOGL), and Meta...',
#   'url': 'https://finance.yahoo.com/video/3-most-important-things-watch-205449651.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/yiQBY.8cGY1HQDxIiUwb3g--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/os/creatr-uploaded-images/2025-10/9ea40cb0-b11b-11f0-badf-defbcab889b0',
#   'publishedAt': '2025-10-24T20:54:49Z',
#   'content': 'Well Big tech taking center stage. Microsoft, Alphabet, Meta reporting earnings on Wednesday followed by Apple and Amazon on Thursday. Together, they represent a huge slice of the market, saying the … [+6287 chars]'},
#  {'source': {'id': None, 'name': '9to5Mac'},
#   'author': 'Ryan Christoffel',
#   'title': 'Apple’s stock hits new all-time high with iPhone 17 sales surging',
#   'description': 'Apple’s stock price just reached an all-time high, currently sitting around $263 per share and rising. Here are the details.\n\n\n\n more…',
#   'url': 'https://9to5mac.com/2025/10/20/apples-stock-hits-new-all-time-high-with-iphone-17-sales-surging/',
#   'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2025/09/apple-fifth-avenue-tim-cook-obrien-iphone17launch.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#   'publishedAt': '2025-10-20T15:42:55Z',
#   'content': 'Apples stock price just reached an all-time high, currently sitting around $263 per share and rising. Here are the details.\r\nApple reports its next quarterly earnings next week, when well get the fir… [+1513 chars]'},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Trefis Team, Contributor, \n Trefis Team, Contributor\n https://www.forbes.com/sites/greatspeculations/people/trefis/',
#   'title': 'Apple Stockholders Hit $850 Billion Jackpot',
#   'description': 'Over the past ten years, Apple stock has delivered a massive $847 billion back to its investors in tangible cash in the form of dividends and buybacks.',
#   'url': 'https://www.forbes.com/sites/greatspeculations/2025/10/22/apple-stockholders-hit-850-billion-jackpot/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/68f8b870949764003c85b9f7/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'publishedAt': '2025-10-22T14:14:54Z',
#   'content': 'Over the past ten years, Apple (AAPL)\r\n stock has delivered a massive $847 billion back to its investors in tangible cash in the form of dividends and buybacks. In fact, AAPL stock\r\n has provided the… [+4232 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'investors.com',
#   'title': 'Apple Shines, Leads Parade Of Megacap Hyperscaler Earnings Reports',
#   'description': 'Several megacap hyperscalers headline the latest earnings calendar, including Meta Platforms (META), Leaderboard stock Alphabet (GOOGL), Amazon.com (AMZN), Microsoft (MSFT) and Apple (AAPL). Apple stock is holding near a fresh buy point, helped by early signs…',
#   'url': 'https://biztoc.com/x/c99bbf321ed98527',
#   'urlToImage': 'https://biztoc.com/cdn/c99bbf321ed98527_s.webp',
#   'publishedAt': '2025-10-24T15:34:53Z',
#   'content': 'Several megacap hyperscalers headline the latest earnings calendar, including Meta Platforms (META), Leaderboard stock Alphabet (GOOGL), Amazon.com (AMZN), Microsoft (MSFT) and Apple (AAPL). Apple st… [+144 chars]'},
#  {'source': {'id': None, 'name': 'Iphoneitalia.com'},
#   'author': 'Giuseppe Migliorino',
#   'title': 'iPhone 17 va sempre più forte e spinge Apple ai massimi storici in Borsa',
#   'description': "Secondo Counterpoint, iPhone 17 vende il 14% in più dei 16 nei primi 10 giorni in USA e Cina. Ottime notizie per il titolo AAPL. \nLink all'articolo originale: iPhone 17 va sempre più forte e spinge Apple ai massimi storici in Borsa",
#   'url': 'https://www.iphoneitalia.com/842408/iphone-17-va-sempre-piu-forte-e-spinge-apple-ai-massimi-storici-in-borsa',
#   'urlToImage': 'https://static.iphoneitalia.com/wp-content/uploads/2025/09/iphone-17-pro-air.jpg',
#   'publishedAt': '2025-10-21T06:59:51Z',
#   'content': 'La linea iPhone 17 sta girando meglio della 16. Nei primi 10 giorni di disponibilità tra Stati Uniti e Cina, le vendite sono +14% rispetto allo scorso anno.\r\nÈ il segnale affidabile sul sentiment ver… [+1653 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Faheem Tahir',
#   'title': 'Wells Fargo Raises Its Price Target on Apple (AAPL) to $290, Maintains “Overweight” Rating',
#   'description': 'Apple Inc. (NASDAQ:AAPL) is one of the 13 best Fortune 500 stocks to invest in now. On October 21, 2025, Wells Fargo raised its price target on Apple Inc...',
#   'url': 'https://finance.yahoo.com/news/wells-fargo-raises-price-target-092546451.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/cVvSOEVgXXeSO16E_nX5FQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/insidermonkey.com/abe42548427d5976d59895bbd8b8797c',
#   'publishedAt': '2025-10-23T09:25:46Z',
#   'content': 'Apple Inc. (NASDAQ:AAPL) is one of the 13 best Fortune 500 stocks to invest in now.\r\nWells Fargo Raises Its Price Target on Apple (AAPL) to $290, Maintains Overweight Rating\r\nbrandon-romanchuk-NOFyRm… [+1760 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Ghazal Ahmed',
#   'title': 'Apple (AAPL) Upgraded to Buy at Loop Capital as Multi-Year iPhone Growth Cycle Begins',
#   'description': 'Apple Inc. (NASDAQ:AAPL) is one of the AI Stocks Making Moves on Wall Street. On October 20, Loop Capital upgraded the stock to “Buy” from Hold and raised...',
#   'url': 'https://finance.yahoo.com/news/apple-aapl-upgraded-buy-loop-212249909.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/ndU42yyiO6AR2iM7JKelxA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzM-/https://media.zenfs.com/en/insidermonkey.com/410ac07c4c90786d8592963501a2ed84',
#   'publishedAt': '2025-10-21T21:22:49Z',
#   'content': 'Apple Inc. (NASDAQ:AAPL) is one of the AI Stocks Making Moves on Wall Street.\xa0On October 20, Loop Capital upgraded the stock to Buy from Hold and raised its price target to $315 from $226 per share. … [+2301 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Sheryar Siddiq',
#   'title': 'Apple (AAPL) Stock Rated Outperform by Evercore Amid App Store Growth Slowdown',
#   'description': 'Apple Inc. (NASDAQ:AAPL) ranks among the best consumer electronics stocks to buy now. Despite observing a slowdown in the growth of App Store revenue...',
#   'url': 'https://finance.yahoo.com/news/apple-aapl-stock-rated-outperform-103110917.html',
#   'urlToImage': 'https://media.zenfs.com/en/insidermonkey.com/34b502e898c2836d5ddd7749c3880e97',
#   'publishedAt': '2025-10-20T10:31:10Z',
#   'content': 'Apple Inc. (NASDAQ:AAPL) ranks among the best consumer electronics stocks to buy now. Despite observing a slowdown in the growth of App Store revenue, Evercore ISI reaffirmed its Outperform rating an… [+1596 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Ramish Cheema',
#   'title': 'Jim Cramer Discusses Apple (AAPL)’s “Super Mission” Against Its Critics',
#   'description': 'We recently published Jim Cramer Discussed These 13 Stocks & Shared Major Warning For Rare Earth Stocks. Apple Inc. (NASDAQ:AAPL) is one of the stocks Jim...',
#   'url': 'https://finance.yahoo.com/news/jim-cramer-discusses-apple-aapl-232255424.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/Bg.Uwu0gVxaIoPDwyX05bQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/insidermonkey.com/d88c758980b1784bc50fad4c3c72bf6e',
#   'publishedAt': '2025-10-22T23:22:55Z',
#   'content': 'We recently published Jim Cramer Discussed These 13 Stocks &amp; Shared Major Warning For Rare Earth Stocks. Apple Inc. (NASDAQ:AAPL) is one of the stocks Jim Cramer recently discussed.\r\nCramer start… [+1328 chars]'},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Bill Stone, Contributor, \n Bill Stone, Contributor\n https://www.forbes.com/sites/bill_stone/',
#   'title': 'S&P 500 Surges: Magnificent 7 Earnings, Rate Cut, And AI Boom Drive Q3',
#   'description': 'S&P 500 surges as Magnificent 7 tech giants, Fed rate cut, and AI boom fuel record earnings. Get expert insights on market momentum and what’s next.',
#   'url': 'https://www.forbes.com/sites/bill_stone/2025/10/26/sp-500-surges-magnificent-7-earnings-rate-cut-and-ai-boom-drive-q3/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/68fce4b3e680d3a83be88ed0/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'publishedAt': '2025-10-26T09:53:54Z',
#   'content': 'Artificial Intelligence Innovation and Market Momentum: How Tech Titans and Fed Moves Are Shaping S&amp;P 500s Record Quarter\r\ngetty\r\nThe third-quarter earnings season begins its busiest week, which … [+5586 chars]'},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Catherine Brock, Contributor, \n Catherine Brock, Contributor\n https://www.forbes.com/sites/wealth-planning-insights/people/catherinebrock/',
#   'title': 'Stock Prices Rise On Apple iPhone Enthusiasm',
#   'description': 'Stocks rose on Monday as Apple realized new highs. Futures are flat ahead of the open on Tuesday. Also: what is a credit crisis?',
#   'url': 'https://www.forbes.com/sites/catherinebrock/2025/10/21/stock-prices-rise-on-apple-iphone-enthusiasm/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/68f77ad017ebeb4336980945/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'publishedAt': '2025-10-21T12:33:48Z',
#   'content': 'U.S. stocks rose Monday as Apple (AAPL) and the broader tech sector made gains.\r\ngetty\r\nU.S. stocks rose Monday as Apple (AAPL) and the broader tech sector made gains. Apple surged to a new high afte… [+5133 chars]'},
#  {'source': {'id': None, 'name': 'Macdailynews.com'},
#   'author': 'MacDailyNews',
#   'title': 'Apple shares hit new all-time intraday and closing highs',
#   'description': 'In Nasdaq trading today, shares of Apple Inc. rose to hit a new all-time closing high. Apple’s all-time intraday high was set…\nThe post Apple shares hit new all-time intraday and closing highs appeared first on MacDailyNews.',
#   'url': 'https://macdailynews.com/2025/10/21/apple-shares-hit-new-all-time-intraday-and-closing-highs-88/',
#   'urlToImage': 'https://macdailynews.com/wp-content/uploads/2024/12/241217_apple_logo.png',
#   'publishedAt': '2025-10-21T20:11:43Z',
#   'content': 'In Nasdaq trading today, shares of Apple Inc. (AAPL) rose $0.53, or 0.20%, to $262.77, a new all-time closing high. Apple’s intraday high was also set today at $265.28.\r\nApples 52-week low stands at … [+1706 chars]'},
#  {'source': {'id': None, 'name': 'Macdailynews.com'},
#   'author': 'MacDailyNews',
#   'title': 'Apple shares hit new all-time intraday and closing highs',
#   'description': 'In Nasdaq trading today, shares of Apple Inc. rose to hit a new all-time closing high. Apple’s all-time intraday high was set…\nThe post Apple shares hit new all-time intraday and closing highs appeared first on MacDailyNews.',
#   'url': 'https://macdailynews.com/2025/10/20/apple-shares-hit-new-all-time-intraday-and-closing-highs-87/',
#   'urlToImage': 'https://macdailynews.com/wp-content/uploads/2024/12/241217_apple_logo.png',
#   'publishedAt': '2025-10-20T20:24:58Z',
#   'content': 'In Nasdaq trading today, shares of Apple Inc. (AAPL) rose $9.95, or 3.94%, to $262.24, a new all-time closing high. Apple’s intraday high was also set today at $264.38.\r\nApples 52-week low stands at … [+1736 chars]'},
#  {'source': {'id': None, 'name': 'Macdailynews.com'},
#   'author': 'MacDailyNews',
#   'title': 'Apple shares hit new all-time closing high',
#   'description': "In Nasdaq trading today, shares of Apple Inc. (AAPL) rose $3.24, or 1.25%, to $262.82, a new all-time closing high. Apple's intraday high…\nThe post Apple shares hit new all-time closing high appeared first on MacDailyNews.",
#   'url': 'https://macdailynews.com/2025/10/24/apple-shares-hit-new-all-time-closing-high-251024/',
#   'urlToImage': 'https://macdailynews.com/wp-content/uploads/2025/10/251020_apple_logo.png',
#   'publishedAt': '2025-10-24T20:23:33Z',
#   'content': 'In Nasdaq trading today, shares of Apple Inc. (AAPL) rose $3.24, or 1.25%, to $262.82, a new all-time closing high. Apple’s intraday high stands at $265.29 set on October 21, 2025.\r\nApples 52-week lo… [+1683 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Faizan Farooque',
#   'title': 'Apple Surprises Market, Ships U.S.-Built AI Servers Ahead of Schedule',
#   'description': 'Houston facility starts production early under $600B domestic investment plan',
#   'url': 'https://finance.yahoo.com/news/apple-surprises-market-ships-u-122715649.html',
#   'urlToImage': 'https://media.zenfs.com/en/us.finance.gurufocus/40a12a1b7769c635ead36fab47a12566',
#   'publishedAt': '2025-10-24T12:27:15Z',
#   'content': 'This article first appeared on GuruFocus.\r\nApple (AAPL, Financials) has begun shipping advanced AI servers from a new manufacturing facility in Houston, Texas, months ahead of schedule. The milestone… [+870 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Yahoo 新聞',
#   'title': '立法會撤回「告別議案」免對選情不公｜蘋果股價創新高｜王晶狠批林志玲冇樣冇演技｜10 月 21 日・Yahoo 晚報',
#   'description': '晚安！今天是 10 月 21 日（星期二）。明日香港多雲有幾陣雨，稍涼；市區最低約 19 度（新界再低 2 至 3 度）、最高約 22 度，吹清勁偏北風，離岸強風，高地一度烈風，海有大浪及湧浪；最高紫外線指數約 4，屬中等。週後期隨「風神」遠離、季候風緩和，天色轉明朗，日間乾燥。',
#   'url': 'https://hk.news.yahoo.com/%E7%AB%8B%E6%B3%95%E6%9C%83%E6%92%A4%E5%9B%9E%E3%80%8C%E5%91%8A%E5%88%A5%E8%AD%B0%E6%A1%88%E3%80%8D%E5%85%8D%E5%B0%8D%E9%81%B8%E6%83%85%E4%B8%8D%E5%85%AC%EF%BD%9C%E8%98%8B%E6%9E%9C%E8%82%A1%E5%83%B9%E5%89%B5%E6%96%B0%E9%AB%98%EF%BD%9C%E7%8E%8B%E6%99%B6%E7%8B%A0%E6%89%B9%E6%9E%97%E5%BF%97%E7%8E%B2%E5%86%87%E6%A8%A3%E5%86%87%E6%BC%94%E6%8A%80%EF%BD%9C10-%E6%9C%88-21-%E6%97%A5%E3%83%BByahoo-%E6%99%9A%E5%A0%B1-123444759.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/WMoC2qiyC_QhzmN156BRrQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDk-/https://s.yimg.com/os/creatr-uploaded-images/2025-10/ade92920-ae79-11f0-b6fb-4c6f4a86c94f',
#   'publishedAt': '2025-10-21T04:34:44Z',
#   'content': '10 21 19 2 3 22 4\r\n2025 YahooYahoo 10 24 \r\n YahooYahoo 237 104 700 5 2027 GDP 2% \r\n YahooYahoo 41 30 \r\niPhone 17 iPhone 16Yahoo AAPL 4% iPhone 10 14% 3 17 ProPro Max iPhone 17 Pro 1,099 8,570 Pro Max… [+163 chars]'},
#  {'source': {'id': None, 'name': 'International Business Times'},
#   'author': 'David Unyime Nkanta',
#   'title': 'AAPL Stock Surges as Strong iPhone 17 Sales Drive Momentum in US and China',
#   'description': 'Apple stock jumps as iPhone 17 sales outperform expectations in the US and China, fuelling investor optimism ahead of earnings.',
#   'url': 'https://www.ibtimes.com/aapl-stock-surges-strong-iphone-17-sales-drive-momentum-us-china-3787730',
#   'urlToImage': 'https://d.ibtimes.com/en/full/4629959/iphone-17.jpg',
#   'publishedAt': '2025-10-20T23:32:11Z',
#   'content': "Apple Inc. has seen a notable surge in its share price following the release of the iPhone 17, with early sales figures from the United States and China exceeding expectations.\r\nThe tech giant's stoc… [+3425 chars]"},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Catherine Brock, Contributor, \n Catherine Brock, Contributor\n https://www.forbes.com/sites/wealth-planning-insights/people/catherinebrock/',
#   'title': 'Stock Futures Down After Tesla Earnings Miss',
#   'description': 'U.S. stocks lost ground Wednesday ahead of the Tesla earnings report. Futures declined after Tesla missed expectations. Also: how often does the stock market crash?',
#   'url': 'https://www.forbes.com/sites/catherinebrock/2025/10/23/stock-futures-down-after-tesla-earnings-miss/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/68fa181d5574fb9c827d09b0/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'publishedAt': '2025-10-23T11:59:54Z',
#   'content': 'Upset investor reviews stock prices on laptop\r\ngetty\r\nU.S. stocks lost ground Wednesday as investors processed disappointing earnings from Netflix (NFLX), amid ongoing trade tensions with China and a… [+2864 chars]'},
#  {'source': {'id': None, 'name': 'ifun.de › Apple-News seit 2001'},
#   'author': 'Chris',
#   'title': 'Apple-Aktie erreicht in den USA neues Rekordhoch',
#   'description': 'Die Apple-Aktie hat an der New Yorker Börse ein neues Rekordhoch erzielt. Das Papier wurde dort gestern zwischenzeitlich für 264,38 Dollar gehandelt, rund 4 Dollar höher als der bisherige Höchststand der unter dem Kürzel AAPL gehandelten Aktie Ende Dezember v…',
#   'url': 'https://www.ifun.de/apple-aktie-erreicht-in-den-usa-neues-rekordhoch-267426/',
#   'urlToImage': 'https://images.ifun.de/wp-content/uploads/2016/10/apple-investor-header-1.jpg',
#   'publishedAt': '2025-10-21T04:55:20Z',
#   'content': 'Die Apple-Aktie hat an der New Yorker Börse ein neues Rekordhoch erzielt. Das Papier wurde dort gestern zwischenzeitlich für 264,38 Dollar gehandelt, rund 4 Dollar höher als der bisherige Höchststand… [+1905 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Microsoft、「Microsoft 356/Office for Mac」でmacOS 13 Venturaのサポートを終了。',
#   'description': 'Microsoftが「Microsoft 356/Office 2024 for Mac」でmacOS 13 Venturaのサポートを終了しています。詳細は以下から。 \u3000Microsoftは2025年10月、Appl […]\nThe post Microsoft、「Microsoft 356/Office for Mac」でmacOS 13 Venturaのサポートを終了。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251025-microsoft-365-macos-end-of-support-on-macos-13-ventura.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/microsoft-365-macos-end-of-support-on-macOS-13-Ventura-Hero.webp',
#   'publishedAt': '2025-10-25T03:58:39Z',
#   'content': 'MicrosoftMicrosoft 356/Office 2024 for MacmacOS 13 Ventura\r\nMicrosoft202510Apple09macOS 26 TahoeMicrosoft 365/Office for MacmacOS 26 TahoemacOS 13 Ventura1015Microsoft 365/Office 2021-2024 for Mac v1… [+322 chars]'},
#  {'source': {'id': None, 'name': 'Investopedia'},
#   'author': 'Bill McColl',
#   'title': 'Top Stock Movers Now: Apple, Cleveland-Cliffs, USA Rare Earth, and More',
#   'description': 'Major U.S. equities indexes gained at midday Monday ahead of a slew of earnings due later in the week.',
#   'url': 'https://www.investopedia.com/top-stock-movers-now-apple-cleveland-cliffs-usa-rare-earth-and-more-11832830',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/oSGspjkNJwf0H7Hieehd9A--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/investopedia_245/edc571c045715c58769f62ae1f3fcac4',
#   'publishedAt': '2025-10-20T15:54:49Z',
#   'content': 'Cheng Xin / Getty Images\r\n Apple shares climbed to an all-time high Monday following a report suggesting strong demand for the companys new iPhone 17\r\n<ul><li>Major U.S. equities indexes gained at mi… [+2110 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Fahad Saleem',
#   'title': 'Analyst Explains Why Microsoft (MSFT) Has a Lead in Enterprise',
#   'description': 'We recently published 10 Trending Stocks This Week. Microsoft Corporation (NASDAQ:MSFT) is one of the trending stocks this week. Mike Fey, Co-Founder & CEO...',
#   'url': 'https://finance.yahoo.com/news/analyst-explains-why-microsoft-msft-134854144.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/RRl71T1aiRIw0bBud4JkUA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD03OTc-/https://media.zenfs.com/en/insidermonkey.com/8357d4801c2f5a834455cbcc99383b11',
#   'publishedAt': '2025-10-21T13:48:54Z',
#   'content': 'We recently published 10 Trending Stocks This Week. Microsoft Corporation (NASDAQ:MSFT) is one of the trending stocks this week.\r\nMike Fey, Co-Founder &amp; CEO of Island, said in a recent program on… [+1879 chars]'},
#  {'source': {'id': None, 'name': 'Investopedia'},
#   'author': 'Kara Greenberg',
#   'title': 'Tesla Posts Return to Revenue Growth, Though Q3 Profits Miss Estimates',
#   'description': 'Tesla reported a return to revenue growth in the third quarter as buyers rushed to take advantage of expiring tax credits, though earnings slightly missed...',
#   'url': 'https://www.investopedia.com/tesla-posts-return-to-revenue-growth-though-q3-profits-miss-estimates-11835164',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/RuSuJjnO_W67YI9c_eRVrA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/investopedia_245/f0ecf8c8d833397749a677c4649fe20d',
#   'publishedAt': '2025-10-22T20:33:29Z',
#   'content': "Getty Images\r\n Tesla shares were up roughly 9% for 2025 through Wednesday's close, after spending most of the year in negative territory\r\n<ul><li>Tesla posted revenue growth for the third quarter aft… [+2244 chars]"},
#  {'source': {'id': None, 'name': 'Investopedia'},
#   'author': 'Terry Lane',
#   'title': '5 Things to Know Before the Stock Market Opens',
#   'description': 'News of the day for Oct. 21, 2025',
#   'url': 'https://www.investopedia.com/5-things-to-know-before-the-stock-market-opens-october-21-2025-11833577',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/ko6HCBBVAJyE7doCzJ94Ng--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/investopedia_245/8a848813354151b5c51d9ba4402cf6a2',
#   'publishedAt': '2025-10-21T12:16:59Z',
#   'content': 'Spencer Platt / Getty Images\r\n Investors are keeping close tabs on earnings reports from major companies this week.\r\nStock futures are little changed this morning after major indexes moved sharply hi… [+4019 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Ghazal Ahmed',
#   'title': 'Apple’s (AAPL) iPhone Strength and Services Growth Drive Higher Price Target From Goldman Sachs',
#   'description': 'Apple Inc. (NASDAQ:AAPL) is one of the Trending AI Stocks on Wall Street’s Radar. On October 21, Goldman Sachs reiterated the stock as ‘Buy” and raised its...',
#   'url': 'https://finance.yahoo.com/news/apple-aapl-iphone-strength-services-185039561.html',
#   'urlToImage': 'https://media.zenfs.com/en/insidermonkey.com/62cb46e6eeef5e0adeaa5b81e9188f72',
#   'publishedAt': '2025-10-23T18:50:39Z',
#   'content': 'Apple Inc. (NASDAQ:AAPL) is one of the Trending AI Stocks on Wall Streets Radar.\xa0On October 21, Goldman Sachs reiterated the stock as Buy and raised its price target on Apple to $279 per share from $… [+1412 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'CalDigit、Thunderbolt 5対応のドッキングステーションTS5/TS5 Plus、Element 5 Hub向けにUSB/Thunderboltデバイスとの接続が切断される問題を修正した「Firmware Updater v64.1」をリリース。',
#   'description': 'CalDigitがThunderbolt 5対応のドッキングステーションTS5/TS5 Plus、Element 5 Hub向けにThunderbolt 5接続での安定性を向上させる「Firmware Updater […]\nThe post CalDigit、Thunderbolt 5対応のドッキングステーションTS5/TS5 Plus、Element 5 Hub向けにUSB/Thunderboltデバイスとの接続が切断される問題を修正した「Firmware Updater v64.1」をリリース。 first…',
#   'url': 'https://applech2.com/archives/20251022-caldigit-ts5-thunderbolt-5-firmware-updater.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/CalDigit-TS5-Plus-TS5-Element-5-Hub-Hero.webp',
#   'publishedAt': '2025-10-21T22:29:01Z',
#   'content': 'CalDigitThunderbolt 5TS5/TS5 PlusElement 5 HubThunderbolt 5Firmware Updater v64.1\r\nCalDigit202504Apple StoreThunderboltCalDigit Thunderbolt Station 4 (TS4)Thunderbolt 5TS51017TS5Thunderbolt firmware … [+634 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Primate Labs、Apple M3 Ultraチップを搭載したMac Studio (2025)のGeekbench CPU/GPUスコアの掲載を開始。',
#   'description': 'Primate LabsがApple M3 Ultraチップを搭載したMac Studio (2025)のGeekbench CPU/GPUスコアの掲載を開始しています。詳細は以下から。 \u3000カナダPrimate Lab […]\nThe post Primate Labs、Apple M3 Ultraチップを搭載したMac Studio (2025)のGeekbench CPU/GPUスコアの掲載を開始。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251021-apple-m3-ultra-geekbench.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Apple-M3-Ultra-Geekbench-Multi-CPU-Core-Hero.webp',
#   'publishedAt': '2025-10-20T18:59:28Z',
#   'content': 'Primate LabsApple M3 UltraMac Studio (2025)Geekbench CPU/GPU\r\nPrimate Labs Inc,20251020GeekbenchMac BenchmarksApple M3 UltraMac Studio (2025)\r\nGeekbench 6 scores are calibrated against a baseline sco… [+492 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Apple M5 (10コアGPU)のBlender 3DレンダリングベンチマークはM1 Ultra (64コアGPU)を上回り、M3 Pro (18コアGPU)に並ぶスコアに。',
#   'description': 'Apple M5 (10コアGPU)のBlender 3DレンダリングベンチマークはM1 Ultra (64コアGPU)を上回り、M3 Pro (18コアGPU)に並ぶスコアになっています。詳細は以下から。 \u3000Appl […]\nThe post Apple M5 (10コアGPU)のBlender 3DレンダリングベンチマークはM1 Ultra (64コアGPU)を上回り、M3 Pro (18コアGPU)に並ぶスコアに。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251023-apple-m5-blender-rendering-benchmark.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Apple-M5-Blender-rendering-benchmark-Hero.webp',
#   'publishedAt': '2025-10-23T04:23:25Z',
#   'content': 'Apple M5 (10GPU)Blender 3DM1 Ultra (64GPU)M3 Pro (18GPU)\r\nApple20251023MacBook Pro (14, 2025)AIGPUApple M5GPUAIGPU3D\r\nM5GPU14MacBook ProM41.61.6\r\n<ul><li>Blender3DM113MacBook Pro6.8M414MacBook Pro1.7… [+1094 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Framer、macOS 26 Tahoeでパフォーマンス問題を引き起こすElectronをアップデートした「Framer for Mac v2025.42」をリリース。',
#   'description': 'FramerがmacOS 26 Tahoeでパフォーマンス問題を引き起こすElectronをアップデートした「Framer for Mac v2025.42」をリリースしています。詳細は以下から。 \u3000オランダのFram […]\nThe post Framer、macOS 26 Tahoeでパフォーマンス問題を引き起こすElectronをアップデートした「Framer for Mac v2025.42」をリリース。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251026-framer-for-mac-fixed-electron-issue-on-macos-26-tahoe.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Framer-for-mac-fixed-electron-issue-on-macos-26-tahoe-Hero.webp',
#   'publishedAt': '2025-10-26T01:24:03Z',
#   'content': 'FramermacOS 26 TahoeElectronFramer for Mac v2025.42\r\nFramer B.V.20251022WebFramer(Mac/Windows)2025.42.xmacOS 26 TahoeLiquid GlassTahoeMacElectron\r\nWeve refreshed our macOS and Windows Desktop apps, m… [+457 chars]'},
#  {'source': {'id': None, 'name': 'Barchart.com'},
#   'author': 'Rob Isbitts',
#   'title': '1 Delicious Options Strategy to Trade Apple Stock at Record Highs',
#   'description': 'This option collar lets us keep riding the Apple high without risking a major downside move.',
#   'url': 'https://www.barchart.com/story/news/35568115/1-delicious-options-strategy-to-trade-apple-stock-at-record-highs',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/EpzO4tFpbUCUzes_L5Zfpw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/barchart_com_477/5c73a52b7903649f6e8fae3cb550b52f',
#   'publishedAt': '2025-10-20T18:47:18Z',
#   'content': 'I dont know about coring an apple, but I like the idea of collaring one. Not the red delicious kind, but the Cupertino variety. None other than Apple (AAPL).\r\nEverything to me starts with the chart. … [+3510 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'RayCue、USB-A/-CやSDカードリーダー、HDMI、NVMe SSDスロットの情報を確認できるスマートディスプレイ搭載のMac mini用ドック「RayCue ALL-in-One Dock For Mac Mini M4」を発売。',
#   'description': 'RayCue、USB-A/-CやSDカードリーダー、HDMI、NVMe SSDスロットの情報を確認できるスマートディスプレイ搭載のMac mini用ドック「RayCue ALL-in-One Dock For Mac […]\nThe post RayCue、USB-A/-CやSDカードリーダー、HDMI、NVMe SSDスロットの情報を確認できるスマートディスプレイ搭載のMac mini用ドック「RayCue ALL-in-One Dock For Mac Mini M4」を発売。 first appeared …',
#   'url': 'https://applech2.com/archives/20251024-raycue-all-in-one-dock-for-mac-mini-m4-with-smart-displays.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/RayCue-ALL-in-One-Dock-For-Mac-Mini-M4-with-Smart-Displays-Hero.webp',
#   'publishedAt': '2025-10-24T07:42:35Z',
#   'content': 'RayCueUSB-A/-CSDHDMINVMe SSDMac miniRayCue ALL-in-One Dock For Mac Mini M4\r\nRayCue202507140WUSB-C PDUSB-AHDMINVMe SSD11SSDMac miniRayCue ALL-in-One Charger Dock For Mac Mini M4 (RayCue ALL-in-One Cha… [+564 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'PULWTOP、HDMIとDisplayPortを備えトリプルディスプレイ出力が可能なMac mini用ドック「Mac Mini M4/M4 Pro 2024用 9-in-1 USB-Cドック」を発売。',
#   'description': 'PULWTOPがHDMIとDisplayPortを備えトリプルディスプレイ出力が可能なMac mini用ドック「Mac Mini M4 Dock Stand with DP 4K 144Hz & HDMI 4 […]\nThe post PULWTOP、HDMIとDisplayPortを備えトリプルディスプレイ出力が可能なMac mini用ドック「Mac Mini M4/M4 Pro 2024用 9-in-1 USB-Cドック」を発売。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251020-pulwtop-mac-mini-m4-dock-stand-9-in-1.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/PULWTOP-Mac-Mini-M4-Dock-Stand-9-in-1-Hero-v2.webp',
#   'publishedAt': '2025-10-20T06:06:06Z',
#   'content': 'PULWTOPHDMIDisplayPortMac miniMac Mini M4 Dock Stand with DP 4K 144Hz &amp; HDMI 4K 60Hz\r\nPULWTOP20251016USB-ASD/microSDNVMe SSDHDMIDisplayPortMac miniUSB-CPULWTOP Mac Mini M4 /Mac Mini M4 Pro 2024 9… [+534 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Google、macOS 26 TahoeのSpotlight検索でGoogle Drive内のコンテンツを検索できるようにした「Google Drive for Desktop v116.0」のロールアウトを開始。',
#   'description': 'GoogleがmacOS 26 TahoeのSpotlight検索でGoogle Drive内のコンテンツを検索できる機能を追加した「Google Drive for Desktop v116.0」のロールアウトを開始 […]\nThe post Google、macOS 26 TahoeのSpotlight検索でGoogle Drive内のコンテンツを検索できるようにした「Google Drive for Desktop v116.0」のロールアウトを開始。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251021-google-drive-support-macos-26-tahoe-spotlight.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Google-Drive-support-Spotlight-Search-on-macOS-26-Tahoe-Hero.webp',
#   'publishedAt': '2025-10-21T01:23:59Z',
#   'content': 'GooglemacOS 26 TahoeSpotlightGoogle DriveGoogle Drive for Desktop v116.0\r\nGoogle20251020Google DriveGoogle Drive for Desktop116.0macOS 26.0 TahoeGoogle DriveSpotlight\r\nAdded support for Apple Spotlig… [+693 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Apple Silicon Macに対応した「Cyberpunk 2077: Ultimate」や「DEATH STRANDING」「Frostpunk 2」などが最大50%OFFとなるハロウィンセールがMac App Storeで開催中。',
#   'description': 'AppleがApple Silicon Macに対応した「Cyberpunk 2077: Ultimate」や「DEATH STRANDING」「Frostpunk 2」などを最大50%OFFで提供するハロウィンセール […]\nThe post Apple Silicon Macに対応した「Cyberpunk 2077: Ultimate」や「DEATH STRANDING」「Frostpunk 2」などが最大50%OFFとなるハロウィンセールがMac App Storeで開催中。 first appeared …',
#   'url': 'https://applech2.com/archives/20251026-apple-silicon-mac-games-halloween-sale.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Apple-Silicon-Mac-Games-Halloween-sale-2025-Hero.webp',
#   'publishedAt': '2025-10-26T09:37:38Z',
#   'content': 'AppleApple Silicon MacCyberpunk 2077: UltimateDEATH STRANDINGFrostpunk 250%OFFMac App Store\r\n1031Apple Silicon MacCyberpunk 2077: UltimateDEATH STRANDING DIRECTOR’S CUTFrostpunk 250OFFMac App Store\r\n… [+248 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Fahad Saleem',
#   'title': 'Analyst Says Microsoft (MSFT) ‘Last of’ Undervalued AI Stocks',
#   'description': 'We recently published Top 10 Trending Stocks Everyone’s Watching in Q4. Microsoft Corporation (NASDAQ:MSFT) is one of the trending stocks everyone’s watching...',
#   'url': 'https://finance.yahoo.com/news/analyst-says-microsoft-msft-last-135741184.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/W5.8BHQwc0xmRewC8xwHVg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD03OTc-/https://media.zenfs.com/en/insidermonkey.com/5836bb178f6f3392a681b1ce3603e60a',
#   'publishedAt': '2025-10-23T13:57:41Z',
#   'content': "We recently published Top 10 Trending Stocks Everyones Watching in Q4. Microsoft Corporation (NASDAQ:MSFT) is one of the trending stocks everyone's watching.\r\nMorningstars Dave Sekera said in a recen… [+1526 chars]"},
#  {'source': {'id': None, 'name': 'Investopedia'},
#   'author': 'Michael Bromberg',
#   'title': 'S&P 500 Gains and Losses Today: Apple, Supermicro Surge; Oracle Stock Extends Losses',
#   'description': "Shares of a smartphone giant and AI server maker were among the benchmark index's top performers Monday, Oct. 20, 2025, while a large enterprise software...",
#   'url': 'https://www.investopedia.com/s-and-p-500-gains-and-losses-today-apple-supermicro-surge-oracle-stock-extends-losses-11832975',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/Xk8hwPEEvyY..o_AX6fgcA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/investopedia_245/fe11a00ca703fcb18e9aad4aeb0bd3ae',
#   'publishedAt': '2025-10-20T20:37:01Z',
#   'content': "VCG / VCG / Getty Images\r\n Shares of Apple climbed to a record high Monday following a report showing strong demand for the company's iPhone 17\r\n<ul><li>Shares of a smartphone giant and AI server mak… [+2746 chars]"},
#  {'source': {'id': None, 'name': "Investor's Business Daily"},
#   'author': "RYAN DEFFENBAUGH, Investor's Business Daily",
#   'title': 'Meta Stock Ahead Fifth Straight Day Amid AI Job Cuts Report, $27 Billion Data Center Deal',
#   'description': 'Meta stock was ahead Thursday, putting shares of the Facebook company on track for a five-day winning streak.',
#   'url': 'https://www.investors.com/news/technology/meta-stock-ai-blue-owl-data-center-q3-earnings/',
#   'urlToImage': 'https://www.investors.com/wp-content/uploads/2023/09/BIZ03_meta_092723AP.jpg',
#   'publishedAt': '2025-10-23T16:10:03Z',
#   'content': 'Meta Platforms (META) stock pushed higher Thursday, with shares of the Facebook parent company on track for a fifth consecutive day of gains. Meta is reporting third-quarter earning next week.\r\nThe g… [+3153 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'macOS Tahoeに対応し複数ウィンドウでの実行やWhoisプロバイダーにJPRSを追加した、macOS 11 Big Surで廃止されたネットワークユーティリティの代替アプリ「Neo Network Utility v2.0」がリリース。',
#   'description': 'macOS Tahoeに対応し複数ウィンドウでの実行やWhoisプロバイダーにJPRSを追加た、Appleが廃止したネットワークユーティリティの代替アプリ「Neo Network Utility v2.0」がリリースさ […]\nThe post macOS Tahoeに対応し複数ウィンドウでの実行やWhoisプロバイダーにJPRSを追加した、macOS 11 Big Surで廃止されたネットワークユーティリティの代替アプリ「Neo Network Utility v2.0」がリリース。 first appeare…',
#   'url': 'https://applech2.com/archives/20251024-neo-network-utility-v2.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Neo-Network-Utility-v2-Hero.webp',
#   'publishedAt': '2025-10-24T02:59:36Z',
#   'content': 'macOS TahoeWhoisJPRSAppleNeo Network Utility v2.0\r\nApple2020macOS 11 Big SurMacnetstatpinglookuptraceroutewhoisfingerGUI (Network Utility)\r\nmacOS 10.15 Catalina\r\n202407DEVONthinkDEVONtechnologies, LL… [+3077 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Serif、10月30日の発表を前に、macOS 26 Tahoe固有の不具合を修正しアカウントの作成やトライアル/ライセンス購入機能などを削除した「Affinity Designer、Photo、Publisher v2.6.5」を公開へ。',
#   'description': 'Serif、2025年10月30日の発表を前に、macOS 26 Tahoe固有の不具合を修正しアカウントの作成やトライアル/ライセンス購入案内機能などを削除した「Affinity Designer、Photo、Pub […]\nThe post Serif、10月30日の発表を前に、macOS 26 Tahoe固有の不具合を修正しアカウントの作成やトライアル/ライセンス購入機能などを削除した「Affinity Designer、Photo、Publisher v2.6.5」を公開へ。 first appeared…',
#   'url': 'https://applech2.com/archives/20251026-affinity-v2-macos-26-tahoe-bug-fix.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/affinity-v2-macos-26-tahoe-bug-fix-Hero.webp',
#   'publishedAt': '2025-10-26T07:25:28Z',
#   'content': 'Serif20251030macOS 26 Tahoe/Affinity DesignerPhotoPublisher v2.6.4\r\nAppleMac App Store BestApple Design AwardAdobeAffinity Photo, Designer, PublisherCanvaSerif Labs20251030Affinity v2.x\r\nNow that ver… [+537 chars]'},
#  {'source': {'id': None, 'name': 'Investopedia'},
#   'author': 'Kara Greenberg',
#   'title': "Netflix is Set to Report Earnings Today. Hits Like 'KPop Demon Hunters' Likely Drove Strong Results",
#   'description': "Wall Street analysts are widely bullish on the streaming giant's stock, anticipating a boost from hit shows and higher prices.",
#   'url': 'https://www.investopedia.com/netflix-q3-2025-earnings-preview-11833806',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/1V7yMCObhJ6407J5niKrNQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/investopedia_245/b05214fd68530870d523ad18c58f255d',
#   'publishedAt': '2025-10-21T17:42:18Z',
#   'content': 'ANTHONY WALLACE / AFP / Getty Images\r\n UBS analysts said hit shows like "KPop Demon Hunters" are likely to boost Netflix\'s results\r\n<ul><li>Netflix is scheduled to report its quarterly results after … [+2559 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'MOFT、カードケースとスタンドを一体化しMagSafeでiPhoneに装着できる「MOFT 多機能カードケース＆スタンド MagSafe対応」を発売。',
#   'description': 'MOFTがカードケースとスタンドを一体化した「MOFT 多機能カードケース＆スタンド MagSafe対応」を発売しています。詳細は以下から。 \u3000香港とカリフォルニアに拠点を置くアクセサリーメーカーMOFT(Mobile […]\nThe post MOFT、カードケースとスタンドを一体化しMagSafeでiPhoneに装着できる「MOFT 多機能カードケース＆スタンド MagSafe対応」を発売。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251023-moft-wallet-and-stand-magsafe.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Moft-wallet-and-stand-magsafe-Hero.webp',
#   'publishedAt': '2025-10-23T01:52:21Z',
#   'content': 'MOFTMOFT MagSafe\r\nMOFT(Mobile Office for Travellers)MagSafeiPhone MagSafe ()\r\nMagSafeiPhone\r\nMOFT MagSafe Amazon.co.jp\r\nMOFT8SIMSIM\r\n10 x 7 x 1.5cm79gRFIDMagSafeiPhone\r\nMOFT ()Amazon.co.jp7,180\r\nPV'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': '次期macOS 26.1 TahoeではLiquid Glassデザインを無効化できるオプションが廃止されるもよう。',
#   'description': '次期macOS 26.1 TahoeではLiquid Glassデザインを無効化できるオプションが廃止されるようです。詳細は以下から。 \u3000Appleが現地時間2025年09月15日にリリースした「macOS 26 Ta […]\nThe post 次期macOS 26.1 TahoeではLiquid Glassデザインを無効化できるオプションが廃止されるもよう。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251025-apple-will-remove-liquid-glass-disable-flag-in-macos-26-1-tahoe.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Apple-will-remove-Liquid-Glass-Disable-Flag-in-macOS-26-1-Tahoe-Hero.webp',
#   'publishedAt': '2025-10-25T06:00:27Z',
#   'content': 'macOS 26.1 TahoeLiquid Glass\r\nApple20250915macOS 26 TahoeiOS/iPadOS 26watchOS 26visionOSLiquid Glass\r\nLiquid Glass Design\r\nmacoS 26.0.x“com.apple.SwiftUI.DisableSolarium”macOS TahoemacOSUIApplemacOS … [+1563 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'OpenAI、AIによるWebページの要約や分析に加えユーザーに代わり複雑なブラウザ操作を行えるエージェントモードを搭載したWebブラウザ「ChatGPT Atlas」のmacOS版をリリース。',
#   'description': 'OpenAIがChatGPTサイドバーを搭載し開いているWebページの解析やアクションを実行できるWebブラウザ「ChatGPT Atlas」のmacOS版をリリースしています。詳細は以下から。 \u3000米OpenAIは現地 […]\nThe post OpenAI、AIによるWebページの要約や分析に加えユーザーに代わり複雑なブラウザ操作を行えるエージェントモードを搭載したWebブラウザ「ChatGPT Atlas」のmacOS版をリリース。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251022-chatgpt-atlas-by-openai-now-available.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/ChatGPT-Atlas-by-OpenAI-now-available-Hero.webp',
#   'publishedAt': '2025-10-21T20:49:15Z',
#   'content': 'OpenAIChatGPTWebWebChatGPT AtlasmacOS\r\nOpenAI20251021AIChatGPTChatGPTWebChatGPT AtlasmacOS\r\nToday were introducing ChatGPT Atlas, a new web browser built with ChatGPT at its core.[…]A browser built w… [+425 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Belkin、USB-AとUSB-Cポートに加え、最大60W出力の巻取り式のUSB-Cケーブルを備えた「Belkin BoostCharge カーチャージャー75W」を発売。',
#   'description': 'BelkinがUSB-AとUSB-Cの2つのポートに加え、最大60W出力の巻取り式のUSB-Cケーブルを備えた「Belkin BoostCharge カーチャージャー75W」を発売しています。詳細は以下から。 \u3000台湾F […]\nThe post Belkin、USB-AとUSB-Cポートに加え、最大60W出力の巻取り式のUSB-Cケーブルを備えた「Belkin BoostCharge カーチャージャー75W」を発売。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251018-belkin-usb-c-car-charger-75w-with-retractable-usb-c-cable.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Belkin-USB-C-Car-Charger-75W-with-Retractable-USB-C-Cable-Hero.webp',
#   'publishedAt': '2025-10-26T02:58:53Z',
#   'content': 'BelkinUSB-AUSB-C260WUSB-CBelkin BoostCharge 75W\r\nFoxconnBelkin International, Inc.75WUSB-CBelkin BoostCharge 75W ) (CCC001fqBK)\r\n2USB-C + USB-AUSB-C75cm60W\r\nBelkin BoostCharge 75W () – Belkin\r\nBelkin… [+315 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Daniel Howley',
#   'title': 'Apple stock hits all-time high, as iPhone 17 sales outpace iPhone 16 in US and China',
#   'description': "Apple's share price hit an all-time high on Monday after Counterpoint Research reported iPhone sales jumped 14% year-over-year.",
#   'url': 'https://finance.yahoo.com/news/apple-stock-hits-all-time-high-as-iphone-17-sales-outpace-iphone-16-in-us-and-china-153140378.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/z7tOKJ09r1fKCOwGhtXfmQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2025-10/ea0b7810-adc8-11f0-b6ef-7544319ad3bc',
#   'publishedAt': '2025-10-20T15:31:40Z',
#   'content': "Apple's (AAPL) stock price hit an all-time high on Monday, climbing more than 4% after Counterpoint Research published a report saying initial iPhone 17 sales have outpaced iPhone 16 sales in the US … [+2378 chars]"},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'FTNN新聞網',
#   'title': '投資人消化財報！美股主指道瓊獨漲百點\u3000輝達跌1.3%、台積電ADR跌1.6%',
#   'description': '[FTNN新聞網]財經中心／綜合報導美股在前一交易日漲勢後，投資人轉趨觀望，主要指數週二（21日）早盤在平盤附近震盪。道瓊工業指數漲逾百點或，其他主要指數...',
#   'url': 'https://tw.stock.yahoo.com/news/%E6%8A%95%E8%B3%87%E4%BA%BA%E6%B6%88%E5%8C%96%E8%B2%A1%E5%A0%B1-%E7%BE%8E%E8%82%A1%E4%B8%BB%E6%8C%87%E9%81%93%E7%93%8A%E7%8D%A8%E6%BC%B2%E7%99%BE%E9%BB%9E-%E8%BC%9D%E9%81%94%E8%B7%8C1-3-%E5%8F%B0%E7%A9%8D%E9%9B%BBadr%E8%B7%8C1-145700462.html',
#   'urlToImage': 'https://media.zenfs.com/ko/ftnn_com_tw_939/1ef74a7ff9599aaf35853fc0f0c22bd5',
#   'publishedAt': '2025-10-21T06:57:00Z',
#   'content': '[FTNN]\r\n215000.02%0.38%1.28%ADR1.6%1.3%\r\nFactSet500AIFactSet14.9%4936.7%\r\nAmeriprise FinancialAnthony Saglimbene\r\n20104046,897.91191.330.41%5006,733.691.440.02%22,902.9987.550.38%6,796.9088.121.28%\r\n… [+193 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'FTNN新聞網',
#   'title': '聯準會有望再降息！美股收盤創新高...道瓊站上47000點\u3000台股ADR全面收紅',
#   'description': '[FTNN新聞網]財經中心／綜合報導受惠美國公布9月通貨膨脹數據趨於溫和，投資人對於聯準會（Fed）降息再次抱有期待，激勵美股週五收盤創下新高。其中，台股ADR...',
#   'url': 'https://tw.stock.yahoo.com/news/%E8%81%AF%E6%BA%96%E6%9C%83%E6%9C%89%E6%9C%9B%E5%86%8D%E9%99%8D%E6%81%AF-%E7%BE%8E%E8%82%A1%E6%94%B6%E7%9B%A4%E5%89%B5%E6%96%B0%E9%AB%98-%E9%81%93%E7%93%8A%E7%AB%99%E4%B8%8A47000%E9%BB%9E-%E5%8F%B0%E8%82%A1adr%E5%85%A8%E9%9D%A2%E6%94%B6%E7%B4%85-232200813.html',
#   'urlToImage': 'https://media.zenfs.com/en/ftnn_com_tw_939/dec83533896f6737e8b0dc08bdac5744',
#   'publishedAt': '2025-10-24T15:22:00Z',
#   'content': '[FTNN]\r\n9FedADRADRTSM-US1.45%ADRASX-US1.25%ADRUMC-US0.27%ADRCHT-US0.28%\r\n472.511.01%47207.1250053.250.79%6791.69263.071.15%23204.87129.5491.89%6976.938\r\nMetaMETA-US0.59%AMZN-US1.41%AAPL-US 1.25%Alpha… [+123 chars]'},
#  {'source': {'id': None, 'name': 'Iphoneaddict.fr'},
#   'author': 'Jean-Baptiste A.',
#   'title': 'L’action d’Apple (AAPL) atteint son plus haut niveau après le succès des iPhone 17',
#   'description': 'Les premières données révélant que les iPhone 17 se vendent mieux que les iPhone 16 au lancement font plaisir aux marchés, au point que l’action d’Apple (AAPL) atteint son plus haut niveau à 264 dollars. Nouveau record pour Apple à la Bourse Le cabinet Counte…',
#   'url': 'https://iphoneaddict.fr/post/news-417710-laction-dapple-aapl-atteint-plus-niveau-apres-succes-iphone-17',
#   'urlToImage': 'https://static.iphoneaddict.fr/wp-content/uploads/2018/08/Apple-Argent-Picsou.jpg',
#   'publishedAt': '2025-10-20T15:56:21Z',
#   'content': 'Les premières données révélant que les iPhone 17 se vendent mieux que les iPhone 16 au lancement font plaisir aux marchés, au point que l’action d’Apple (AAPL) atteint son plus haut niveau à 264 doll… [+1594 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'macOS 26 Tahoeでは、macOSセットアップ時にAppleアカウントにサインインすると自動的にFileVaultがONになるので注意を。',
#   'description': 'macOS 26 Tahoeでは、macOSセットアップ時にAppleアカウントにサインインすると自動的にFileVaultがONになるので注意してください。詳細は以下から。 \u3000Appleは明日2025年10月22日よ […]\nThe post macOS 26 Tahoeでは、macOSセットアップ時にAppleアカウントにサインインすると自動的にFileVaultがONになるので注意を。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251021-macos-26-tahoe-filevault-turn-on-automatically.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/macOS-26-Tahoe-FileVault-turn-on-default-Hero.webp',
#   'publishedAt': '2025-10-21T09:22:16Z',
#   'content': 'macOS 26 TahoemacOSAppleFileVaultON\r\nApple20251022Apple M5MacBook Pro (14, M5)MacBook PromacOS 26 TahoeMacBook ProTahoe\r\nMacBook Pro (14, M5)\r\nTahoemacOS1Apple(Apple ID)FileVaultON\r\nmacOS 26 Tahoe\r\nA… [+1100 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'OpenAI、Mac用AIアシスタント「Sky」を開発する元Appleのショートカット/Workflowアプリの開発者らが設立した会社を買収。',
#   'description': 'OpenAIがMac用AIアシスタント「Sky」を開発する元Appleのショートカット(Workflow)アプリの開発メンバーが設立した会社を買収したそうです。詳細は以下から。 \u3000ChatGPTなどを開発する米Open […]\nThe post OpenAI、Mac用AIアシスタント「Sky」を開発する元Appleのショートカット/Workflowアプリの開発者らが設立した会社を買収。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251024-openai-acquires-sky-mac-ai-assitant.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Openai-acquires-sky-mac-ai-assitant-Hero.webp',
#   'publishedAt': '2025-10-23T21:23:46Z',
#   'content': 'OpenAIMacAISkyApple(Workflow)\r\nChatGPTOpenAI20251023MacAISkySoftware Applications Incorporated\r\nAI progress isnt only about advancing intelligenceits about unlocking it through interfaces that unders… [+932 chars]'},
#  {'source': {'id': None, 'name': 'Coinspeaker'},
#   'author': 'Godfrey Benjamin',
#   'title': 'Peter Brandt Expects Bitcoin Price to Hit $250,000, but There’s a Twist',
#   'description': 'Although Bitcoin BTC $107 716 24h volatility: 3.0% Market cap: $2.15 T Vol. 24h: $89.20 B is currently facing a rough path, top trader Peter Brandt recently ...',
#   'url': 'https://www.coinspeaker.com/peter-brandt-bitcoin-250k-volatility-warning/',
#   'urlToImage': 'https://media.zenfs.com/en/coinspeaker_us_106/678637c1ea877e6565cf065645614a4d',
#   'publishedAt': '2025-10-22T11:44:07Z',
#   'content': 'Although Bitcoin is currently facing a rough path, top trader Peter Brandt recently noted that the coin has a chance to hit $250,000. He noted that his prediction is not a case of probability but one… [+1909 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Dropbox、最新の「Dropbox for Mac」アップデートでmacOS 26 Tahoeを搭載したMacの動作が重くなってしまうElectronの不具合を修正したと発表。',
#   'description': 'Dropboxが最新の「Dropbox for Mac」アップデートでmacOS 26 Tahoeを搭載したMacの動作が重くなってしまうElectronの不具合を修正したと発表しています。詳細は以下から。 \u3000Drop […]\nThe post Dropbox、最新の「Dropbox for Mac」アップデートでmacOS 26 Tahoeを搭載したMacの動作が重くなってしまうElectronの不具合を修正したと発表。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251023-dropbox-fixed-electron-gpu-issue-on-macos-26-tahoe.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Dropbox-for-Mac-fixed-Electron-issue-on-macOS-26-Tahoe-Hero.webp',
#   'publishedAt': '2025-10-22T20:25:37Z',
#   'content': 'DropboxDropbox for MacmacOS 26 TahoeMacElectron\r\nDropbox20251021DropboxDropbox for MacmacOS 26 TahoeMacGPUMac\r\nHi everyone!Thank you for your patience, ir’s much appreciated.I can confirm that a fix … [+393 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'メニューバーアイコンにファイルやリンクをドラッグ&ドロップするだけでAirDrop機能を呼び出してくれるMacアプリ「Menu Drop」がリリース。',
# ...
#   'author': 'Terry Lane',
#   'title': 'What to Expect in Markets This Week: Fed Interest-Rate Decision; Earnings From Apple, Microsoft, Meta, Amazon, Alphabet',
#   'description': 'Coming up: FOMC interest rate decision, earnings from Apple, Microsoft, Meta, Amazon, Alphabet, and more.',
#   'url': 'https://www.investopedia.com/what-to-expect-in-markets-this-week-fed-interest-rate-decision-earnings-from-apple-microsoft-meta-amazon-alphabet-11835986',
#   'urlToImage': 'https://media.zenfs.com/en/investopedia_245/3b0f53aee77036b4362b52cf2575dc7c',
#   'publishedAt': '2025-10-26T09:00:00Z',
#   'content': "Anna Moneymaker/Getty Images\r\n Fed Chair Jerome Powell is set to speak this week after the central bank's next interest-rate decision.\r\nA Federal Reserve interest rate decision and a string of Magnif… [+5128 chars]"},
#  {'source': {'id': None, 'name': 'MarketWatch'},
#   'author': 'Jamie Chisholm',
#   'title': 'With Apple stock near a record high as earnings loom, here’s the options trade to make',
#   'description': 'The iPhone maker’s shares tend to rise in the last 3 months of the year, says Evercore',
#   'url': 'https://www.marketwatch.com/story/with-apple-stock-near-a-record-high-as-earnings-loom-heres-the-options-trade-to-make-73ef26ae',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/TSZqhHne7eGZkwud_Y9Zzg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02MDA-/https://media.zenfs.com/en/marketwatch_hosted_869/543456492925e805bc2c97ebe734f320',
#   'publishedAt': '2025-10-20T13:30:00Z',
#   'content': 'iPhone 17 sales have been better than analysts feared - Michael M. Santiago/Getty Images\r\nTheres a positive tone to markets at the start of the week. Investors appear to have shrugged off the recent … [+7240 chars]'},
#  {'source': {'id': None, 'name': 'Investopedia'},
#   'author': 'Colin Laidley',
#   'title': "Is the Magnificent Seven's Earnings Edge Fading?",
#   'description': 'The Magnificent Seven have been the stars of the S&P 500 for the past several years, but the group’s period of exceptional earnings growth may be nearing an ...',
#   'url': 'https://www.investopedia.com/is-the-magnificent-seven-earnings-edge-fading-11834250',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/XrbjfhH6xId58F_zMVuNyQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/investopedia_245/025ae6f2603daaa2bb14e53b47d85c25',
#   'publishedAt': '2025-10-22T09:30:00Z',
#   'content': 'Alice Morgan / Investopedia\r\n Tesla will kick off Mag 7 third-quarter earnings with its report, scheduled for Wednesday afternoon.\r\n<ul><li>Nvidia is the only Magnificent Seven company that is expect… [+3549 chars]'},
#  {'source': {'id': None, 'name': 'Barchart.com'},
#   'author': 'Oleksandr Pylypenko',
#   'title': 'Stocks Set to Open Higher as U.S.-China Tensions Ease, Inflation Data and Earnings Awaited',
#   'description': 'December S&P 500 E-Mini futures (ESZ25) are up +0.29%, and December Nasdaq 100 E-Mini futures (NQZ25) are up +0.41% this morning as signs of easing trade...',
#   'url': 'https://www.barchart.com/story/news/35556209/stocks-set-to-open-higher-as-u-s-china-tensions-ease-inflation-data-and-earnings-awaited',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/OKotpjNJCllhQM0IFuvFiA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/barchart_com_477/fcebfc40d659e147fc2e5eab7e6cb524',
#   'publishedAt': '2025-10-20T10:19:15Z',
#   'content': 'Third-quarter corporate earnings season kicks into high gear this week, with investors awaiting fresh reports from major companies such as Tesla (TSLA), Netflix (NFLX), Coca-Cola (KO), Intel (INTC), … [+9351 chars]'},
#  {'source': {'id': None, 'name': 'Barchart.com'},
#   'author': 'Oleksandr Pylypenko',
#   'title': 'Stock Index Futures Muted With Focus on Corporate Earnings',
#   'description': 'December S&P 500 E-Mini futures (ESZ25) are down -0.04%, and December Nasdaq 100 E-Mini futures (NQZ25) are down -0.08% this morning, pointing to a muted...',
#   'url': 'https://www.barchart.com/story/news/35578678/stock-index-futures-muted-with-focus-on-corporate-earnings',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/Sxsc7AGptQxSOfq4Q2t5Uw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/barchart_com_477/ae7ee21b7adc3615d29d0e151145646a',
#   'publishedAt': '2025-10-21T10:04:53Z',
#   'content': 'December S&amp;P 500 E-Mini futures (ESZ25) are down -0.04%, and\xa0December Nasdaq 100 E-Mini futures (NQZ25) are down -0.08% this morning, pointing to a muted open on Wall Street after yesterdays rall… [+9672 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': '247wallst.com',
#   'title': 'AI Has Destroyed Apple’s Future',
#   'description': 'Apple Inc. (NASDAQ: AAPL) made one huge mistake that will irreparably damage its future. What was once the most powerful tech company in the world stumbled in June. That’s when it said it would not release its highly advanced Siri AI product until 2026. That …',
#   'url': 'https://biztoc.com/x/db7bec0cd480737a',
#   'urlToImage': 'https://biztoc.com/cdn/db7bec0cd480737a_s.webp',
#   'publishedAt': '2025-10-20T13:55:05Z',
#   'content': 'Apple Inc. (NASDAQ: AAPL) made one huge mistake that will irreparably damage its future. What was once the most powerful tech company in the world stumbled in June. Thats when it said it would not re… [+147 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': '247wallst.com',
#   'title': 'Apple Can’t Fold a Foldable Phone',
#   'description': 'Despite all of the excitement about better-than-expected iPhone 17 sales, Apple Inc. (NASDAQ: AAPL) still cannot get the foldable smartphone product right. The project is important because archrival Samsung already has its Galaxy Z Fold7 and Galaxy Z Flip7. T…',
#   'url': 'https://biztoc.com/x/7628a94705c3b982',
#   'urlToImage': 'https://biztoc.com/cdn/7628a94705c3b982_s.webp',
#   'publishedAt': '2025-10-23T13:33:31Z',
#   'content': 'Despite all of the excitement about better-than-expected iPhone 17 sales, Apple Inc. (NASDAQ: AAPL) still cannot get the foldable smartphone product right. The project is important because archrival … [+144 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'investors.com',
#   'title': 'Breakout Watch: Why Nvidia, Apple, Meta And Others Use This AI Brain',
#   'description': 'Megacaps like Nvidia (NVDA), Apple (AAPL), Meta Platforms (META), Alphabet (GOOGL) and others have all ridden the artificial intelligence boom to record highs this year. One thing they all have in common is a relationship with Arm Holdings (ARM), whose techno…',
#   'url': 'https://biztoc.com/x/ba0bf8de3cb56b44',
#   'urlToImage': 'https://biztoc.com/cdn/ba0bf8de3cb56b44_s.webp',
#   'publishedAt': '2025-10-23T12:26:57Z',
#   'content': 'Megacaps like Nvidia (NVDA), Apple (AAPL), Meta Platforms (META), Alphabet (GOOGL) and others have all ridden the artificial intelligence boom to record highs this year. One thing they all have in co… [+145 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': '247wallst.com',
#   'title': 'Analysts Are Pounding the Table Over AAPL, TSLA, AVGO, META, NVDA',
#   'description': 'Key Points\n \n \n \n \n \n \nDespite the trade war and one of the longest government shutdowns in history, markets are shrugging it all off in favor of higher highs.\n \n \n \n \nIt sounds nuts, but SoFi is giving new active invest users up to $1k in stock, see for your…',
#   'url': 'https://biztoc.com/x/fb938269dba4ff55',
#   'urlToImage': 'https://biztoc.com/cdn/fb938269dba4ff55_s.webp',
#   'publishedAt': '2025-10-21T14:47:55Z',
#   'content': 'Key Points\r\nDespite the trade war and one of the longest government shutdowns in history, markets are shrugging it all off in favor of higher highs.\r\nIt sounds nuts, but SoFi is giving new active inv… [+115 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'finance.yahoo.com',
#   'title': '5 Things to Know Before the Stock Market Opens',
#   'description': 'Stock futures are little changed this morning after major indexes moved sharply higher to start the week; the U.S. government shutdown entered its 21st day as a top White House adviser predicted an end to the budget impasse this week; Apple (AAPL) shares rema…',
#   'url': 'https://biztoc.com/x/bb727b8d69dcc0d4',
#   'urlToImage': 'https://biztoc.com/cdn/bb727b8d69dcc0d4_s.webp',
#   'publishedAt': '2025-10-21T12:35:03Z',
#   'content': 'Stock futures are little changed this morning after major indexes moved sharply higher to start the week; the U.S. government shutdown entered its 21st day as a top White House adviser predicted an e… [+150 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'investors.com',
#   'title': 'Apple, Google, Meta, Amazon, Microsoft Earnings Due; Fed Rate Cut, Trump-Xi Ahead',
#   'description': 'The stock market is at record highs heading into peak earnings week, with Apple (AAPL), Microsoft, Meta Platforms, Google and Amazon all on tap. The Federal Reserve is expected to cut rates for a second straight meeting. President Donald Trump is set to meet …',
#   'url': 'https://biztoc.com/x/3e47d586a3057529',
#   'urlToImage': 'https://biztoc.com/cdn/3e47d586a3057529_s.webp',
#   'publishedAt': '2025-10-24T17:36:42Z',
#   'content': 'The stock market is at record highs heading into peak earnings week, with Apple (AAPL), Microsoft, Meta Platforms, Google and Amazon all on tap. The Federal Reserve is expected to cut rates for a sec… [+144 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'investopedia.com',
#   'title': '5 Things to Know Before the Stock Market Opens',
#   'description': 'Stock futures are little changed this morning after major indexes moved sharply higher to start the week; the U.S. government shutdown entered its 21st day as a top White House adviser predicted an end to the budget impasse this week; Apple (AAPL) shares rema…',
#   'url': 'https://biztoc.com/x/eb2d1f1e01c658c3',
#   'urlToImage': 'https://biztoc.com/cdn/eb2d1f1e01c658c3_s.webp',
#   'publishedAt': '2025-10-22T10:44:42Z',
#   'content': 'Stock futures are little changed this morning after major indexes moved sharply higher to start the week; the U.S. government shutdown entered its 21st day as a top White House adviser predicted an e… [+156 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'investors.com',
#   'title': '7 S&P 500 Companies On Pace To Make The Most Money This Year',
#   'description': "Now that the year is roughly 80% done, analysts have a good idea of where the most S&P 500 profit will come from. And it's not entirely Magnificent.\nAnalysts think seven companies — Alphabet (GOOGL), Apple (AAPL), Nvidia (NVDA), Microsoft (MSFT), Meta Platfor…",
#   'url': 'https://biztoc.com/x/8cd3193f88afde51',
#   'urlToImage': 'https://biztoc.com/cdn/8cd3193f88afde51_s.webp',
#   'publishedAt': '2025-10-22T12:25:41Z',
#   'content': "Now that the year is roughly 80% done, analysts have a good idea of where the most S&amp;P 500 profit will come from. And it's not entirely Magnificent.Analysts think seven companies Alphabet (GOOGL)… [+148 chars]"},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'investors.com',
#   'title': 'Stock Market Rallies To Highs But Huge Earnings, Fed Meeting, Trump-Xi Ahead',
#   'description': 'The stock market rally had a strong week, with the Dow Jones, S&P 500 and Nasdaq composite hitting record highs Friday. Leading stocks rebounded powerfully after coming under strain. Now get ready for a huge week of news. Apple (AAPL), Microsoft, Meta, Google…',
#   'url': 'https://biztoc.com/x/db032ef9b8f066c4',
#   'urlToImage': 'https://biztoc.com/cdn/db032ef9b8f066c4_s.webp',
#   'publishedAt': '2025-10-25T12:04:30Z',
#   'content': 'The stock market rally had a strong week, with the Dow Jones, S&amp;P 500 and Nasdaq composite hitting record highs Friday. Leading stocks rebounded powerfully after coming under strain. Now get read… [+145 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': '247wallst.com',
#   'title': 'Cramer Recommends Apple',
#   'description': 'Apple Inc. (NASDAQ: AAPL) stock rallied 4% yesterday on the back of research that showed brisk sales of the iPhone 17. The stock has risen 22% in the past three months, compared to 7% for the S&P 500. After prolonged anxiety about how well the iPhone would se…',
#   'url': 'https://biztoc.com/x/b50cef0b0cf1d758',
#   'urlToImage': 'https://biztoc.com/cdn/b50cef0b0cf1d758_s.webp',
#   'publishedAt': '2025-10-21T14:04:01Z',
#   'content': 'Apple Inc. (NASDAQ: AAPL) stock rallied 4% yesterday on the back of research that showed brisk sales of the iPhone 17. The stock has risen 22% in the past three months, compared to 7% for the S&amp;P… [+150 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'fastcompany.com',
#   'title': 'Apple stock just reached an all-time high—and it’s because of this landmark product',
#   'description': 'Apple stock just soared to an all-time high, and it might be thanks to the new iPhone 17.\nOn October 20, Apple shares (NASDAQ: AAPL) surged to more than $264 apiece, topping out their last peak at $258.10 in December 2024. As of this writing, the company is t…',
#   'url': 'https://biztoc.com/x/b3c1c4009ac21d78',
#   'urlToImage': 'https://biztoc.com/cdn/b3c1c4009ac21d78_s.webp',
#   'publishedAt': '2025-10-20T18:32:01Z',
#   'content': 'Apple stock just soared to an all-time high, and it might be thanks to the new iPhone 17.On October 20, Apple shares (NASDAQ: AAPL) surged to more than $264 apiece, topping out their last peak at $25… [+148 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'finance.yahoo.com',
#   'title': 'Cramer Recommends Apple',
#   'description': 'Apple Inc. (NASDAQ: AAPL) stock rallied 4% yesterday on the back of research that showed brisk sales of the iPhone 17. The stock has risen 22% in the past three months, compared to 7% for the S&P 500. After prolonged anxiety about how well the iPhone would se…',
#   'url': 'https://biztoc.com/x/57ae2d33bb46cca7',
#   'urlToImage': 'https://biztoc.com/cdn/57ae2d33bb46cca7_s.webp',
#   'publishedAt': '2025-10-21T14:36:58Z',
#   'content': 'Apple Inc. (NASDAQ: AAPL) stock rallied 4% yesterday on the back of research that showed brisk sales of the iPhone 17. The stock has risen 22% in the past three months, compared to 7% for the S&amp;P… [+154 chars]'},
#  {'source': {'id': None, 'name': 'International Business Times'},
#   'author': 'Vinay Patel',
#   'title': "ChatGPT Atlas 'Not 10x Better Than Chrome', Analyst Says — Browser Could Struggle to Win Over Chrome Users",
#   'description': "Gene Munster asserts that Google will ultimately prevail in the AI race, even against rivals like OpenAI's new Atlas browser.",
#   'url': 'https://www.ibtimes.com/chatgpt-atlas-not-10x-better-chrome-analyst-says-browser-could-struggle-win-over-chrome-users-3788014',
#   'urlToImage': 'https://d.ibtimes.com/en/full/4630444/chatgpt-atlas.jpg',
#   'publishedAt': '2025-10-22T11:20:21Z',
#   'content': "OpenAI's new ChatGPT Atlas browser is officially here, hoping to challenge Google Chrome's dominance by putting AI at the core of the web experience. However, not everyone is convinced it has the pow… [+5528 chars]"},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'benzinga.com',
#   'title': "Apple Stock Is Hitting All-Time Highs Monday: What's Going On?",
#   'description': 'Apple Inc (NASDAQ:AAPL) shares are trading higher on Monday after Loop Capital upgraded the technology giant’s stock and substantially increased its price target, signaling confidence in the company’s growth trajectory ahead.\nAAPL shares are at critical resis…',
#   'url': 'https://biztoc.com/x/a3f2cd1cd1739a99',
#   'urlToImage': 'https://biztoc.com/cdn/a3f2cd1cd1739a99_s.webp',
#   'publishedAt': '2025-10-20T18:20:46Z',
#   'content': 'Apple Inc (NASDAQ:AAPL) shares are trading higher on Monday after Loop Capital upgraded the technology giants stock and substantially increased its price target, signaling confidence in the companys … [+145 chars]'}]

# %%
from newspaper import Article

url = arts[0]["url"]
article = Article(url)
article.download()
article.parse()
print(article.text)
# Out:
# 00:00 Speaker A
#
# Well Big tech taking center stage. Microsoft, Alphabet, Meta reporting earnings on Wednesday followed by Apple and Amazon on Thursday. Together, they represent a huge slice of the market, saying the tone for stocks into year end. We're breaking down the three most important things to watch heading into these earnings. And joining us now we got Gil Luria, head of Technology research at D.A. Davidson. Gil, always great to see you. So big tech earnings on deck, Gil.
#
# 00:30 Speaker A
#
# Uh Big tech investors have plenty of questions about valuations, about the AI spending boom. Maybe uh maybe let let's start there, Gil. Let let's start on this question. AI boom, AI bubble. I'm sure you're getting questions from clients about that, Gil. What are you telling them?
#
# 00:54 Gil Luria
#
# That as far as the companies that report next week go, there's no bubble. Microsoft, Amazon, Google and Meta are spending most of the capital expenditures on AI, but they're doing it to match demand. Their customers are committing to long-term contracts to buy compute capacity, to do AI, and they're doing the right thing by expanding that capacity.
#
# 01:21 Gil Luria
#
# One of the things they're doing though is leveraging other people's capacity. So Oracle or Core Weave, they're they're creating new special purpose vehicles that are off balance sheet. Meta's doing that. And that's where you're going to start seeing more of the bubblicious aspects of this. The the parts where tens of billions of debt
#
# 01:46 Gil Luria
#
# are funding CapEx away from these companies. But what our companies that we're talking about, Microsoft, Amazon, Google, Meta, their investment is very prudent and and they're just leveraging this uh this huge demand for to deploy capital in AI, to reduce their own capx, to reduce their own need to borrow money. So they're being very savvy for them. This is a good investment.
#
# 02:08 Speaker A
#
# What do you make, Gil of questions about this sort of circular web of investments? You've seen this, right? So Nvidia will invest in Open AI, Open AI then commits to Nvidia's chips. That does get some people a bit concerned. I'm I'm curious how you think about it.
#
# 02:30 Gil Luria
#
# That is the unhealthy part of the behavior. That is Nvidia that could be selling all of its chips to these four big companies, saying, well, we actually want to expand the market beyond that. We want to stimulate demand beyond our core customers to extend the cycle. So they're creating these related party transactions with again, with the likes of Open AI and Oracle and um, and uh, and uh,
#
# 02:59 Gil Luria
#
# uh, Core Weave and Stargate and, um, and so those, that's the unhealthy behavior we're seeing, especially since that part is being funded by debt with very high leverage. And we're just getting started. We're maybe tens of millions of dollars of debt into this process, but Oracle's talking about another 38, and Meta's talking about another 27, and Open AI is talking about $400 billion dollars of
#
# 03:31 Gil Luria
#
# of debt that they want to raise to build the to build these data centers. Let's not forget, for as excited as we are about the AI roll out and how useful the tools are and how transformational they're going to be, it's still a speculative investment in assets that are very short-lived. Nvidia's chips are phenomenal, they may not get the same return in three or four years that they're getting now.
#
# 03:55 Gil Luria
#
# So, again, the large companies are are making the healthy part of the investment, but there's a lot of unhealthy behavior happening around that.
#
# 04:05 Speaker A
#
# You all you do cover Meta and Alphabet, Gil. So I'm also curious to get your take. High level, the ad market and the search market. How healthy and resilient do those markets look heading into these prints?
#
# 04:22 Gil Luria
#
# So they're doing well. Last quarter Meta grew 22%, Google only grew 12%. That could narrow a little bit as we comp the elections. Meta's growth will probably decelerate a little bit. Google is probably going to hold on. So Meta is still growing faster, but the the uh the gap between the two will probably narrow. But there's the elephant in the room, which is OpenAI hasn't turned on advertising yet.
#
# 04:54 Gil Luria
#
# So the big digital advertising platforms are Meta's, Google's by dance, Tik Tok. And the one that has all the users but is not selling ads yet is OpenAI. At some point, OpenAI is going to turn on ads and that's going to take share from the other three, mostly from Google. Hasn't happened yet, it's not going to happen this quarter, but it's something to look for especially as we get into next year.
#
# 05:22 Speaker A
#
# I want to finish here Gil, your thoughts on Apple as well. Uh, we saw this wave of positive headlines on Apple early this week, Gil, and I'm curious what you made of that. At just how how strong you think Gil, this iPhone cycle is looking.
#
# 05:43 Gil Luria
#
# I don't think we know, and we may not even know after Apple reports. This is the the really early stages until we get through the holiday season, we won't know how healthy of a cycle it is. We examine the product. We didn't feel like it was compelling enough to drive a large upgrade cycle, but the a lot of the data points are pointing to that, which is why the stock has done so well. We are at a point where Apple is the most expensive on earnings
#
# 06:11 Gil Luria
#
# of this group, in spite of the fact that even in a strong iPhone upgrade cycle, their growth will be the lowest. So there's a lot of excitement built in, they say anything disappointing next week, the stock could pull back.
#
# 06:26 Speaker A
#
# US and China trade tensions Gil finally, very quickly here. Listen, also in focus, Trump and G meeting next week. Um, how much of a risk are those tensions for the kind of big tech names we're talking about here or is that now priced in here?
#
# 06:44 Gil Luria
#
# It's mostly priced in for Nvidia, because let's not forget, Nvidia, the the one that's not reporting next week, is the topic of all these conversations. And they they have very little sales to China at this point. They may get them back, they may not. For Apple, it it's adds a lot of volatility, but again, that's mostly embedded here. But those are the two that are going to be mostly impacted.
#
# 07:03 Gil Luria
#
# There'll be a relief if we can come up with something constructive with China, but realistically speaking, that's not going to happen. We are in a slow process of decoupling from China, regardless of the geopolitical outcome of these negotiations. Apple is pulling production out of China, Nvidia is moving production out of Asia. We are pulling away from China one way or another.
#
# 07:22 Speaker A
#
# Gil, always great to have you on the show, my friend. Enjoy the weekend.
#
# 07:28 Gil Luria
#
# Thank you.

# %%
type(article.text)
# Out:
# str

# %%
import trafilatura

downloaded = trafilatura.fetch_url(url)
content = trafilatura.extract(downloaded)
content
# Out:
# 'Big Tech earnings are on deck next week with Magnificent Seven companies Microsoft (MSFT), Amazon (AMZN), Apple (AAPL), Alphabet (GOOG, GOOGL), and Meta Platforms (META) set to report quarterly results.\nD.A. Davidson Head of Technology Research Gil Luria explains to Josh Lipton where he is seeing "bubblicious aspects" begin to form around the AI trade and Big Tech\'s capex investments into artificial intelligence, including Nvidia\'s (NVDA) strategic partnership with OpenAI (OPAI.PVT), while also commenting on Meta and Google\'s advertising businesses.\nTo watch more expert insights and analysis on the latest market action, check out more Market Domination.\nWell Big tech taking center stage. Microsoft, Alphabet, Meta reporting earnings on Wednesday followed by Apple and Amazon on Thursday. Together, they represent a huge slice of the market, saying the tone for stocks into year end. We\'re breaking down the three most important things to watch heading into these earnings. And joining us now we got Gil Luria, head of Technology research at D.A. Davidson. Gil, always great to see you. So big tech earnings on deck, Gil.\nUh Big tech investors have plenty of questions about valuations, about the AI spending boom. Maybe uh maybe let let\'s start there, Gil. Let let\'s start on this question. AI boom, AI bubble. I\'m sure you\'re getting questions from clients about that, Gil. What are you telling them?\nThat as far as the companies that report next week go, there\'s no bubble. Microsoft, Amazon, Google and Meta are spending most of the capital expenditures on AI, but they\'re doing it to match demand. Their customers are committing to long-term contracts to buy compute capacity, to do AI, and they\'re doing the right thing by expanding that capacity.\nOne of the things they\'re doing though is leveraging other people\'s capacity. So Oracle or Core Weave, they\'re they\'re creating new special purpose vehicles that are off balance sheet. Meta\'s doing that. And that\'s where you\'re going to start seeing more of the bubblicious aspects of this. The the parts where tens of billions of debt\nare funding CapEx away from these companies. But what our companies that we\'re talking about, Microsoft, Amazon, Google, Meta, their investment is very prudent and and they\'re just leveraging this uh this huge demand for to deploy capital in AI, to reduce their own capx, to reduce their own need to borrow money. So they\'re being very savvy for them. This is a good investment.\nWhat do you make, Gil of questions about this sort of circular web of investments? You\'ve seen this, right? So Nvidia will invest in Open AI, Open AI then commits to Nvidia\'s chips. That does get some people a bit concerned. I\'m I\'m curious how you think about it.\nThat is the unhealthy part of the behavior. That is Nvidia that could be selling all of its chips to these four big companies, saying, well, we actually want to expand the market beyond that. We want to stimulate demand beyond our core customers to extend the cycle. So they\'re creating these related party transactions with again, with the likes of Open AI and Oracle and um, and uh, and uh,\nuh, Core Weave and Stargate and, um, and so those, that\'s the unhealthy behavior we\'re seeing, especially since that part is being funded by debt with very high leverage. And we\'re just getting started. We\'re maybe tens of millions of dollars of debt into this process, but Oracle\'s talking about another 38, and Meta\'s talking about another 27, and Open AI is talking about $400 billion dollars of\nof debt that they want to raise to build the to build these data centers. Let\'s not forget, for as excited as we are about the AI roll out and how useful the tools are and how transformational they\'re going to be, it\'s still a speculative investment in assets that are very short-lived. Nvidia\'s chips are phenomenal, they may not get the same return in three or four years that they\'re getting now.\nSo, again, the l ...

# %%
type(content)
# Out:
# str

# %%
print(len(article.text), len(content))
# Out:
# 6824 7109

# %%
fetch_sentiment("aapl")
# Out:
# Device set to use cpu
# [2025-10-27 18:18:01,070: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\sentiment created successfully.]
# [2025-10-27 18:18:01,070: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\sentiment\AAPL.json]
# [2025-10-27 18:18:01,070: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:01,070: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-27 18:18:01,070: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:01,070: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# {'Overall Sentiment': 0.8271641266696593,
#  'Positive Articles': 25,
#  'Negative Artciles': 9,
#  'Total Artciles': 100,
#  'Category': 'Positive',
#  'Contents': ['Apple Stockholders Hit $850 Billion Jackpot. Over the past ten years, Apple stock has delivered a massive $847 billion back to its investors in tangible cash in the form of dividends and buybacks.',
#   'Apple Shines, Leads Parade Of Megacap Hyperscaler Earnings Reports. Several megacap hyperscalers headline the latest earnings calendar, including Meta Platforms (META), Leaderboard stock Alphabet (GOOGL), Amazon.com (AMZN), Microsoft (MSFT) and Apple (AAPL). Apple stock is holding near a fresh buy point, helped by early signs…',
#   'Wells Fargo Raises Its Price Target on Apple (AAPL) to $290, Maintains “Overweight” Rating. Apple Inc. (NASDAQ:AAPL) is one of the 13 best Fortune 500 stocks to invest in now. On October 21, 2025, Wells Fargo raised its price target on Apple Inc...',
#   'Evercore ISI Maintains Bullish Outlook for Apple Inc. (AAPL) in Latest Update. Apple Inc. (NASDAQ:AAPL) is among the 14 Best Big Name Stocks to Invest in Right Now. On October 16, Evercore ISI maintained its Outperform rating and price ...',
#   'Apple (AAPL) Upgraded to Buy at Loop Capital as Multi-Year iPhone Growth Cycle Begins. Apple Inc. (NASDAQ:AAPL) is one of the AI Stocks Making Moves on Wall Street. On October 20, Loop Capital upgraded the stock to “Buy” from Hold and raised...',
#   'Apple (AAPL) Stock Rated Outperform by Evercore Amid App Store Growth Slowdown. Apple Inc. (NASDAQ:AAPL) ranks among the best consumer electronics stocks to buy now. Despite observing a slowdown in the growth of App Store revenue...',
#   'Stock Prices Rise On Apple iPhone Enthusiasm. Stocks rose on Monday as Apple realized new highs. Futures are flat ahead of the open on Tuesday. Also: what is a credit crisis?',
#   'Apple shares hit new all-time intraday and closing highs. In Nasdaq trading today, shares of Apple Inc. rose to hit a new all-time closing high. Apple’s all-time intraday high was set…\nThe post Apple shares hit new all-time intraday and closing highs appeared first on MacDailyNews.',
#   'Apple shares hit new all-time intraday and closing highs. In Nasdaq trading today, shares of Apple Inc. rose to hit a new all-time closing high. Apple’s all-time intraday high was set…\nThe post Apple shares hit new all-time intraday and closing highs appeared first on MacDailyNews.',
#   "Apple shares hit new all-time closing high. In Nasdaq trading today, shares of Apple Inc. (AAPL) rose $3.24, or 1.25%, to $262.82, a new all-time closing high. Apple's intraday high…\nThe post Apple shares hit new all-time closing high appeared first on MacDailyNews.",
#   'Apple Surprises Market, Ships U.S.-Built AI Servers Ahead of Schedule. Houston facility starts production early under $600B domestic investment plan',
#   'AAPL Stock Surges as Strong iPhone 17 Sales Drive Momentum in US and China. Apple stock jumps as iPhone 17 sales outperform expectations in the US and China, fuelling investor optimism ahead of earnings.',
#   'Stock Futures Down After Tesla Earnings Miss. U.S. stocks lost ground Wednesday ahead of the Tesla earnings report. Futures declined after Tesla missed expectations. Also: how often does the stock market crash?',
#   'Top Stock Movers Now: Apple, Cleveland-Cliffs, USA Rare Earth, and More. Major U.S. equities indexes gained at midday Monday ahead of a slew of earnings due later in the week.',
#   "'Non-Productive' Gold Zooms to $30T Market Cap, Leaving Bitcoin, Nvidia, Apple, Google Far Behind. Investors are increasingly pouring money into non-productive gold, raising alarm for the global economy while BTC lags behind.",
#   'Tesla Posts Return to Revenue Growth, Though Q3 Profits Miss Estimates. Tesla reported a return to revenue growth in the third quarter as buyers rushed to take advantage of expiring tax credits, though earnings slightly missed...',
#   'Apple’s (AAPL) iPhone Strength and Services Growth Drive Higher Price Target From Goldman Sachs. Apple Inc. (NASDAQ:AAPL) is one of the Trending AI Stocks on Wall Street’s Radar. On October 21, Goldman Sachs reiterated the stock as ‘Buy” and raised its...',
#   "S&P 500 Gains and Losses Today: Apple, Supermicro Surge; Oracle Stock Extends Losses. Shares of a smartphone giant and AI server maker were among the benchmark index's top performers Monday, Oct. 20, 2025, while a large enterprise software...",
#   'Meta Stock Ahead Fifth Straight Day Amid AI Job Cuts Report, $27 Billion Data Center Deal. Meta stock was ahead Thursday, putting shares of the Facebook company on track for a five-day winning streak.',
#   'S&P 500 Earnings Surge: Magnificent 7 Lead As Recession Odds Plunge. S&P 500 earnings soar as the Magnificent 7 lead. Credit fraud hits regional banks, while Wall Street giants post record results. Recession odds plunge despite shutdown.',
#   "Netflix is Set to Report Earnings Today. Hits Like 'KPop Demon Hunters' Likely Drove Strong Results. Wall Street analysts are widely bullish on the streaming giant's stock, anticipating a boost from hit shows and higher prices.",
#   "Apple stock hits all-time high, as iPhone 17 sales outpace iPhone 16 in US and China. Apple's share price hit an all-time high on Monday after Counterpoint Research reported iPhone sales jumped 14% year-over-year.",
#   'Peter Brandt Expects Bitcoin Price to Hit $250,000, but There’s a Twist. Although Bitcoin BTC $107 716 24h volatility: 3.0% Market cap: $2.15 T Vol. 24h: $89.20 B is currently facing a rough path, top trader Peter Brandt recently ...',
#   '‘Tech Rally into Year-End’: Daniel Ives Says Momentum Is Building for 3 Tech Stock Giants — Including TSLA. With the end of the year in sight, and tech stocks having driven the markets sharply higher this year, talk of a potential bubble on Wall Street is growing, ...',
#   "Loop Capital sees 25% upside on iPhone demand, Apple stock nears all-time record high. Apple's stock price is set to open near record levels on Monday, rising 1.4% in premarket trading, positioning the stock within reach…\nThe post Loop Capital sees 25% upside on iPhone demand, Apple stock nears all-time record high appeared first on MacDailyNew…",
#   'Apple dépasse Microsoft et devient la 2e entreprise la plus valorisée. Grâce à une importante demande pour les iPhone 17, Apple (AAPL) a repris sa place de deuxième entreprise la plus valorisée au monde, dépassant Microsoft. Cette performance a permis à la capitalisation boursière du géant technologique de frôler pour la premièr…',
#   'Stock market today: Dow, S&P 500, Nasdaq futures stall as investors eye earnings flood. US stock futures were little changed Monday night as Wall Street geared up for a packed week of corporate earnings.',
#   'Move Over, Magnificent 7: This 1 Rare Earth ETF Is Winning Over Wall Street Now. The SPDR S&P Metals & Mining ETF is up nearly 75% in 2025, outperforming the S&P 500 and tech giants like Nvidia as investors rotate into real assets...',
#   'IPO-rumored company beats every Wall Street giant with 99% profit margin. “We have a 99% profit margin. There is no other company in the world that has that," said Paolo Ardoino, CEO of stablecoin issuing company Tether. The bold...',
#   'Apple announces five-year partnership as U.S. broadcast partner for Formula 1. Apple (AAPL) and Formula 1 announced a five-year partnership that will bring all F1 races exclusively to Apple TV in the United States beginning next year. “The partnership builds on Apple’s deepening relationship with Formula 1 following the global success o…',
#   'The iPhone 17 is bringing Apple stock back to life—but Wall Street is worried about a catch. Shares of Apple climbed nearly 4% to close at ~$262,\xa0surpassing\xa0the company’s previous all-time high of $259 from last December.',
#   'Dow, S&P 500, Nasdaq jump as Apple leads tech stocks higher ahead of busy earnings week. Wall Street is gearing up for a heavy-hitting earnings season, with the federal government still in shutdown.',
#   'Apple Stock Hits All-Time High Amid Surging iPhone 17 Sales. In the first ten days following availability in both China and the United States, the iPhone 17 series sales surpassed the iPhone 16 by around 14%.\nThe post Apple Stock Hits All-Time High Amid Surging iPhone 17 Sales first appeared on iPhone in Canada.',
#   'Big Tech earnings, a crucial Fed meeting, and a Trump-Xi sit-down: What to watch this week. The market enters the fourth full week of the government shutdown with international trade and domestic rates in focus.']}

# %% [markdown]
# ## Benchmark Data

# %%
import yfinance as yf

ticker = "SPY"
stock = yf.Ticker(ticker)
info = stock.info  # Pulls full fundamental data

# Select only relevant keys
benchmark = {
    "PE": info.get("trailingPE", "Not Found"),
    "PB": info.get("priceToBook", "Not Found"),
    "Book Value": info.get("bookValue", "Not Found"),
}

benchmark
# Out:
# {'PE': 28.596827, 'PB': 1.5778621, 'Book Value': 429.22}

# %%
import yfinance as yf
from StockScreener.utils.common import read_yaml, load_json

def load_benchmark(ticker: str):
    ticker = ticker.upper()
    sector_path = Path("config/sector_map.yaml")
    sector_map = read_yaml(path=sector_path)

    ticker_sector = load_json(Path(f"artifacts/fundamentals/{ticker}.json")).Sector

    # Loading Technical and Fundamental data for sector ETF
    try:
        fetch_benchmark_fundamental(sector_map.sectors[ticker_sector])
        fetch_benchmark_technical(sector_map.sectors[ticker_sector])
    except:
        pass

    # Loading Technical and Fundamental data for market ETF
    try:
        fetch_benchmark_fundamental(sector_map.market)
        fetch_benchmark_technical(sector_map.market)
    except:
        pass


def fetch_benchmark_technical(ticker: str) -> None:
    ticker = ticker.upper()
    load_path = f"artifacts/benchmarks/{ticker}.pkl"

    if Path(load_path).exists() and not is_cache_stale(ticker, "benchmark_prices"):
        return pd.read_pickle(load_path)
    
    df = yf.download(ticker, period="1y", interval="1d", auto_adjust=True)
    df.to_pickle(load_path)
    update_cache_index(ticker, "benchmark_prices")
    return df


def get_benchmark_data(ticker: str) -> dict:
    ticker = ticker.upper()
    etf = yf.Ticker(ticker)
    info = etf.info  # Pulls full fundamental data
    
    # Select only relevant keys
    benchmark = {
        "PE": info.get("trailingPE", "Not Found"),
        "PB": info.get("priceToBook", "Not Found"),
        "Book Value": info.get("bookValue", "Not Found"),
    }

    return benchmark


def fetch_benchmark_fundamental(ticker: str):
    ticker = ticker.upper()
    load_path = WORK_DIR / f"benchmarks/{ticker}.json"

    if Path(load_path).exists() and not is_cache_stale(ticker, "benchmark_fundamental"):
        return load_json(load_path)
    
    data = get_benchmark_data(ticker)

    save_json(save_path=load_path, data=data)
    update_cache_index(ticker, "benchmark_fundamental")
    
    return data

# %%
sector = load_json(Path(f"artifacts/fundamentals/{'AAPL'}.json")).Sector
# Out:
# [2025-10-27 18:18:01,289: INFO: common: JSON file succesfully loaded form: artifacts\fundamentals\AAPL.json]

# %%
sector_map = read_yaml(path=Path("config/sector_map.yaml"))
sector_map.sectors[sector]
# Out:
# [2025-10-27 18:18:01,296: INFO: common: YAML file: config\sector_map.yaml loaded successfully]
# 'XLK'

# %%
load_benchmark("AAPL")
# Out:
# [2025-10-27 18:18:01,305: INFO: common: YAML file: config\sector_map.yaml loaded successfully]
# [2025-10-27 18:18:01,305: INFO: common: JSON file succesfully loaded form: artifacts\fundamentals\AAPL.json]
# [2025-10-27 18:18:01,498: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\benchmarks created successfully.]
# [2025-10-27 18:18:01,498: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\benchmarks\XLK.json]
# [2025-10-27 18:18:01,498: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:01,500: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-27 18:18:01,500: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:01,501: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [*********************100%***********************]  1 of 1 completed
# [2025-10-27 18:18:01,686: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:01,688: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-27 18:18:01,689: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:01,689: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-27 18:18:02,264: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\benchmarks created successfully.]
# [2025-10-27 18:18:02,265: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\benchmarks\SPY.json]
# [2025-10-27 18:18:02,267: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:02,267: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-27 18:18:02,267: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:02,267: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [*********************100%***********************]  1 of 1 completed
# [2025-10-27 18:18:02,481: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:02,481: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-27 18:18:02,481: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:02,481: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]

# %% [markdown]
# ## Combined

# %%
def update_all(ticker):
    fetch_prices(ticker)
    fetch_fundamentals(ticker)
    fetch_sentiment(ticker)
    load_benchmark(ticker)

# %%
stock = yf.Ticker("tsla")
info = stock.info
info.get("sector").lower()
# Out:
# 'consumer cyclical'

# %%
ticker = "TSLA"
update_all(ticker=ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [2025-10-27 18:18:05,910: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:05,910: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-27 18:18:05,911: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:05,912: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-27 18:18:06,807: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\fundamentals created successfully.]
# [2025-10-27 18:18:06,808: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\fundamentals\TSLA.json]
# [2025-10-27 18:18:06,809: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:06,809: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-27 18:18:06,810: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:06,811: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# Device set to use cpu
# [2025-10-27 18:18:12,458: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\sentiment created successfully.]
# [2025-10-27 18:18:12,458: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\sentiment\TSLA.json]
# [2025-10-27 18:18:12,458: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:12,464: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-27 18:18:12,464: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:12,464: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-27 18:18:12,470: INFO: common: YAML file: config\sector_map.yaml loaded successfully]
# [2025-10-27 18:18:12,481: INFO: common: JSON file succesfully loaded form: artifacts\fundamentals\TSLA.json]
# [2025-10-27 18:18:12,482: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:12,489: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-27 18:18:12,491: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\benchmarks\SPY.json]
# [2025-10-27 18:18:12,492: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-27 18:18:12,492: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]

# %% [markdown]
# ## Cleaned

# %%
from dataclasses import dataclass
from pathlib import Path
from StockScreener.utils.logger import get_logger

# Initializing the logger
logger = get_logger()

@dataclass(frozen=True)
class IngestionConfig:
    """
    Immutable configuration class to hold all necessary paths 
    and parameters required for the ingestion stage.
    """
    root_dir: Path

# %%
# TEMP INGESTION PATHS

'''

CACHE_PATH = "artifacts/cache_index.json"
CACHE_EXPIRY_HOURS = 6
working_directory = os.getenv("WORKING_DIRECTORY")


"artifacts/prices/{ticker}.pkl"
load_path = WORK_DIR / f"fundamentals/{ticker}.json"


load_path = WORK_DIR / f"sentiment/{ticker}.json"
api_key = os.getenv("NEWS_API_KEY")
url = f"https://newsapi.org/v2/everything?q={ticker}&from={(datetime.now()-timedelta(days=look_back)).date()}&apiKey={api_key}"


sector_path = Path("config/sector_map.yaml")
ticker_sector = load_json(Path(f"artifacts/fundamentals/{ticker}.json")).Sector


'''
# Out:
# '\n\nCACHE_PATH = "artifacts/cache_index.json"\nCACHE_EXPIRY_HOURS = 6\nworking_directory = os.getenv("WORKING_DIRECTORY")\n\n\n"artifacts/prices/{ticker}.pkl"\nload_path = WORK_DIR / f"fundamentals/{ticker}.json"\n\n\nload_path = WORK_DIR / f"sentiment/{ticker}.json"\napi_key = os.getenv("NEWS_API_KEY")\nurl = f"https://newsapi.org/v2/everything?q={ticker}&from={(datetime.now()-timedelta(days=look_back)).date()}&apiKey={api_key}"\n\n\nsector_path = Path("config/sector_map.yaml")\nticker_sector = load_json(Path(f"artifacts/fundamentals/{ticker}.json")).Sector\n\n\n'
