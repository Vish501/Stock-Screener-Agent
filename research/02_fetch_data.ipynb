# %% [markdown]
# # Environment Setting Up

# %%
import os
from dotenv import load_dotenv

# Loading environment variables from .env
load_dotenv()

# Changing directory to main directory for easy data access
working_directory = os.getenv("WORKING_DIRECTORY")
os.chdir(working_directory)

# Checking the change
# %pwd
# Out:
# 'D:\\Projects\\Stock Screener\\Stock-Screener-Agent'

# %%
from pathlib import Path

# Checking the change
print("Git folder exists:", Path(".git").exists())
# Out:
# Git folder exists: True

# %% [markdown]
# # 2. Fetch Data

# %% [markdown]
# ## Stock Price Data

# %%
# Cache Manager
# Avoid redundant API calls by checking last fetch timestamps

from datetime import datetime, timedelta
from StockScreener.utils.common import load_json, save_json, create_directories
import json

# Define where cache index JSON will be stored.
# Uses the working_directory environment variable if available.
WORK_DIR = Path(working_directory) / "artifacts"
CACHE_PATH = WORK_DIR / "cache_index.json"

# Define how long cache entries remain valid.
CACHE_EXPIRY_HOURS = 6

def update_cache_index(ticker: str, data_type: str) -> None:
    """
    Update or create a cache entry for the given ticker and data type.

    Args:
        ticker (str): Stock symbol (e.g., "AAPL").
        data_type (str): Type of data cached (e.g., "price", "news").
    """
    # Ensure the cache directory exists
    create_directories([WORK_DIR])

    ticker = ticker.upper()

    # Load the cache file if it exists, else create an empty dict
    try:
        cache = load_json(CACHE_PATH)
    except:
        cache = {}

    # Update timestamp for this ticker + data_type
    cache.setdefault(ticker, {})[data_type] = datetime.now().isoformat()

    # Save back to JSON
    save_json(save_path=CACHE_PATH, data=cache)


def is_cache_stale(ticker: str, data_type: str) -> bool:
    """
    Determine if cache for a given ticker and data_type is expired or missing.

    Args:
        ticker (str): Stock symbol (e.g., "AAPL").
        data_type (str): Type of data cached (e.g., "price", "news").

    Returns:
        bool: True if cache is stale or missing, False if still valid.
    """
    # Ensure the cache directory exists
    create_directories([WORK_DIR])

    ticker = ticker.upper()
    
    # Load cache safely
    try:
        cache = load_json(CACHE_PATH)
        entry = cache.get(ticker, {}).get(data_type)
    except (FileNotFoundError, json.JSONDecodeError):
        return True

    # If no entry found, it's stale
    if not entry:
        return True

    # Parse last updated timestamp and compare with expiry threshold
    last_updated = datetime.fromisoformat(entry)
    return datetime.now() - last_updated > timedelta(hours=CACHE_EXPIRY_HOURS)

# %%
import yfinance as yf
import pandas as pd

def fetch_prices(ticker: str):
    ticker = ticker.upper()
    load_path = f"artifacts/prices/{ticker}.pkl"

    if Path(load_path).exists() and not is_cache_stale(ticker, "prices"):
        return pd.read_pickle(load_path)
    
    df = yf.download(ticker, period="1y", interval="1d", auto_adjust=True)
    df.to_pickle(load_path)
    update_cache_index(ticker, "prices")
    return df

# %%
fetch_prices(ticker="AAPL")
# Out:
# [2025-10-17 12:59:15,630: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 12:59:15,639: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [*********************100%***********************]  1 of 1 completed
# [2025-10-17 12:59:15,835: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 12:59:15,836: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-17 12:59:15,837: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 12:59:15,837: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2024-10-17  231.074570  232.766707  229.452131  232.348639  32993800
# 2024-10-18  233.911377  235.085903  232.925958  235.085903  46431500
# 2024-10-21  235.384521  235.752818  233.363927  233.363927  36254500
# 2024-10-22  234.767395  235.125728  231.522502  232.806520  38846600
# 2024-10-23  229.691010  234.050724  226.704907  232.995637  52287000
# ...                ...         ...         ...         ...       ...
# 2025-10-10  245.270004  256.380005  244.000000  254.940002  61999100
# 2025-10-13  247.660004  249.690002  245.559998  249.380005  38142900
# 2025-10-14  247.770004  248.850006  244.699997  246.600006  35478000
# 2025-10-15  249.339996  251.820007  247.470001  249.490005  33893600
# 2025-10-16  247.449997  249.039993  245.130005  248.250000  39698000
#
# [250 rows x 5 columns]

# %% [markdown]
# ## Stock Fundamental Data

# %%
stock = yf.Ticker("AAPL")
info = stock.info  # Pulls full fundamental data
info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#  'fullTimeEmployees': 150000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Timothy D. Cook',
#    'age': 63,
#    'title': 'CEO & Director',
#    'yearBorn': 1961,
#    'fiscalYear': 2024,
#    'totalPay': 16520856,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Katherine L. Adams',
#    'age': 60,
#    'title': 'Senior VP & General Counsel',
#    'yearBorn': 1964,
#    'fiscalYear': 2024,
#    'totalPay': 5022182,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': "Ms. Deirdre  O'Brien",
#    'age': 57,
#    'title': 'Senior Vice President of Retail & People',
#    'yearBorn': 1967,
#    'fiscalYear': 2024,
#    'totalPay': 5022182,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jeffrey E. Williams',
#    'age': 60,
#    'title': 'Senior Vice President of Design, Watch, & Health',
#    'yearBorn': 1964,
#    'fiscalYear': 2024,
#    'totalPay': 5020737,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Kevan  Parekh',
#    'age': 52,
#    'title': 'Senior VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Sabih  Khan',
#    'title': 'Chief Operating Officer',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Chris  Kondo',
#    'title': 'Senior Director of Corporate Accounting',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Suhasini  Chandramouli',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Kristin Huguet Quayle',
#    'title': 'Vice President of Worldwide Communications',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Greg  Joswiak',
#    'title': 'Senior Vice President of Worldwide Marketing',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 7,
#  'boardRisk': 1,
#  'compensationRisk': 3,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 1,
#  'governanceEpochDate': 1759276800,
#  'compensationAsOfEpochDate': 1735603200,
#  'irWebsite': 'http://investor.apple.com/',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 249.34,
#  'open': 248.27,
#  'dayLow': 245.13,
#  'dayHigh': 249.04,
#  'regularMarketPreviousClose': 249.34,
#  'regularMarketOpen': 248.27,
#  'regularMarketDayLow': 245.13,
#  'regularMarketDayHigh': 249.04,
#  'dividendRate': 1.04,
#  'dividendYield': 0.42,
#  'exDividendDate': 1754870400,
#  'payoutRatio': 0.1533,
#  'fiveYearAvgDividendYield': 0.54,
#  'beta': 1.094,
#  'trailingPE': 37.606384,
#  'forwardPE': 29.777374,
#  'volume': 39218197,
#  'regularMarketVolume': 39218197,
#  'averageVolume': 54379421,
#  'averageVolume10days': 40980600,
#  'averageDailyVolume10Day': 40980600,
#  'bid': 247.27,
#  'ask': 260.82,
#  'bidSize': 3,
#  'askSize': 1,
#  'marketCap': 3672254447616,
#  'fiftyTwoWeekLow': 169.21,
#  'fiftyTwoWeekHigh': 260.1,
#  'allTimeHigh': 260.1,
#  'allTimeLow': 0.049107,
#  'priceToSalesTrailing12Months': 8.986857,
#  'fiftyDayAverage': 240.4252,
#  'twoHundredDayAverage': 222.07555,
#  'trailingAnnualDividendRate': 1.01,
#  'trailingAnnualDividendYield': 0.004050694,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 3718580535296,
#  'profitMargins': 0.24295999,
#  'floatShares': 14814270914,
#  'sharesOutstanding': 14840390000,
#  'sharesShort': 110777598,
#  'sharesShortPriorMonth': 113582365,
#  'sharesShortPreviousMonthDate': 1756425600,
#  'dateShortInterest': 1759190400,
#  'sharesPercentSharesOut': 0.0075,
#  'heldPercentInsiders': 0.0197,
#  'heldPercentInstitutions': 0.63611,
#  'shortRatio': 1.84,
#  'shortPercentOfFloat': 0.0075,
#  'impliedSharesOutstanding': 14852540974,
#  'bookValue': 4.431,
#  'priceToBook': 55.845177,
#  'lastFiscalYearEnd': 1727481600,
#  'nextFiscalYearEnd': 1759017600,
#  'mostRecentQuarter': 1751068800,
#  'earningsQuarterlyGrowth': 0.093,
#  'netIncomeToCommon': 99280003072,
#  'trailingEps': 6.58,
#  'forwardEps': 8.31,
#  'lastSplitFactor': '4:1',
#  'lastSplitDate': 1598832000,
#  'enterpriseToRevenue': 9.1,
#  'enterpriseToEbitda': 26.243,
#  '52WeekChange': 0.052978754,
#  'SandP52WeekChange': 0.13033986,
#  'lastDividendValue': 0.26,
#  'lastDividendDate': 1754870400,
#  'quoteType': 'EQUITY',
#  'currentPrice': 247.45,
#  'targetHighPrice': 310.0,
#  'targetLowPrice': 175.0,
#  'targetMeanPrice': 248.1203,
#  'targetMedianPrice': 245.0,
#  'recommendationMean': 2.08333,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 41,
#  'totalCash': 55372001280,
#  'totalCashPerShare': 3.731,
#  'ebitda': 141696008192,
#  'totalDebt': 101698002944,
#  'quickRatio': 0.724,
#  'currentRatio': 0.868,
#  'totalRevenue': 408624988160,
#  'debtToEquity': 154.486,
#  'revenuePerShare': 27.173,
#  'returnOnAssets': 0.24545999,
#  'returnOnEquity': 1.49814,
#  'grossProfits': 190739005440,
#  'freeCashflow': 94873747456,
#  'operatingCashflow': 108564996096,
#  'earningsGrowth': 0.121,
#  'revenueGrowth': 0.096,
#  'grossMargins': 0.46678,
#  'ebitdaMargins': 0.34675997,
#  'operatingMargins': 0.29990998,
#  'financialCurrency': 'USD',
#  'symbol': 'AAPL',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'earningsTimestamp': 1761854400,
#  'earningsTimestampStart': 1761854400,
#  'earningsTimestampEnd': 1761854400,
#  'earningsCallTimestampStart': 1761858000,
#  'earningsCallTimestampEnd': 1761858000,
#  'isEarningsDateEstimate': False,
#  'epsTrailingTwelveMonths': 6.58,
#  'epsForward': 8.31,
#  'epsCurrentYear': 7.4108,
#  'priceEpsCurrentYear': 33.390457,
#  'fiftyDayAverageChange': 7.0247955,
#  'fiftyDayAverageChangePercent': 0.029218215,
#  'twoHundredDayAverageChange': 25.37445,
#  'twoHundredDayAverageChangePercent': 0.11426044,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '2.1 - Buy',
#  'cryptoTradeable': False,
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 345479400000,
#  'postMarketChangePercent': -0.424329,
#  'postMarketPrice': 246.4,
#  'postMarketChange': -1.05,
#  'regularMarketChange': -1.89,
#  'regularMarketDayRange': '245.13 - 249.04',
#  'marketState': 'PREPRE',
#  'fullExchangeName': 'NasdaqGS',
#  'averageDailyVolume3Month': 54379421,
#  'fiftyTwoWeekLowChange': 78.23999,
#  'fiftyTwoWeekLowChangePercent': 0.46238396,
#  'fiftyTwoWeekRange': '169.21 - 260.1',
#  'fiftyTwoWeekHighChange': -12.650009,
#  'fiftyTwoWeekHighChangePercent': -0.048635174,
#  'fiftyTwoWeekChangePercent': 5.2978754,
#  'dividendDate': 1755129600,
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'exchange': 'NMS',
#  'messageBoardId': 'finmb_24937',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'regularMarketChangePercent': -0.758001,
#  'regularMarketPrice': 247.45,
#  'corporateActions': [],
#  'postMarketTime': 1760659196,
#  'regularMarketTime': 1760644801,
#  'displayName': 'Apple',
#  'trailingPegRatio': 2.4662}

# %%
stock = yf.Ticker("AAPL")
info = stock.info
info.get("sector").lower()
# Out:
# 'technology'

# %%
import yfinance as yf

def get_fundamental_data(ticker: str) -> dict:
    ticker = ticker.upper()
    stock = yf.Ticker(ticker)
    info = stock.info  # Pulls full fundamental data
    
    # Select only relevant keys
    fundamentals = {
        "PE": info.get("trailingPE"),
        "PB": info.get("priceToBook"),
        "PS": info.get("priceToSalesTrailing12Months"),
        "EV_EBITDA": info.get("enterpriseToEbitda"),
        "ROE": info.get("returnOnEquity"),
        "EPS": info.get("trailingEps"),
        "Book Value": info.get("bookValue"),
        "Sector": info.get("sector").lower(),
    }

    return fundamentals

df = get_fundamental_data(ticker="AAPL")
df
# Out:
# {'PE': 37.606384,
#  'PB': 55.845177,
#  'PS': 8.986857,
#  'EV_EBITDA': 26.243,
#  'ROE': 1.49814,
#  'EPS': 6.58,
#  'Book Value': 4.431,
#  'Sector': 'technology'}

# %%
import yfinance as yf

def get_fundamental_data(ticker: str) -> dict:
    ticker = ticker.upper()
    stock = yf.Ticker(ticker)
    info = stock.info  # Pulls full fundamental data
    
    # Select only relevant keys
    fundamentals = {
        "PE": info.get("trailingPE", "Not Found"),
        "PB": info.get("priceToBook", "Not Found"),
        "PS": info.get("priceToSalesTrailing12Months", "Not Found"),
        "EV_EBITDA": info.get("enterpriseToEbitda", "Not Found"),
        "ROE": info.get("returnOnEquity", "Not Found"),
        "EPS": info.get("trailingEps", "Not Found"),
        "Book Value": info.get("bookValue", "Not Found"),
        "Sector": info.get("sector", "Not Found").title(),
    }

    return fundamentals


def fetch_fundamentals(ticker: str):
    ticker = ticker.upper()
    load_path = WORK_DIR / f"fundamentals/{ticker}.json"

    if Path(load_path).exists() and not is_cache_stale(ticker, "fundamentals"):
        return load_json(load_path)
    
    data = get_fundamental_data(ticker)

    save_json(save_path=load_path, data=data)
    update_cache_index(ticker, "fundamentals")
    
    return data

# %%
fetch_fundamentals(ticker="AAPL")
# Out:
# [2025-10-17 12:59:16,636: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 12:59:16,638: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-17 12:59:16,677: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\fundamentals created successfully.]
# [2025-10-17 12:59:16,678: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\fundamentals\AAPL.json]
# [2025-10-17 12:59:16,679: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 12:59:16,679: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-17 12:59:16,680: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 12:59:16,681: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# {'PE': 37.606384,
#  'PB': 55.845177,
#  'PS': 8.986857,
#  'EV_EBITDA': 26.243,
#  'ROE': 1.49814,
#  'EPS': 6.58,
#  'Book Value': 4.431,
#  'Sector': 'Technology'}

# %% [markdown]
# ## Stock Sentiment Data

# %%
from transformers import pipeline
import requests
import os
from newspaper import Article
import trafilatura


def get_feed(ticker: str, look_back: int=7):
    ticker = ticker.upper()
    api_key = os.getenv("NEWS_API_KEY")
    url = f"https://newsapi.org/v2/everything?q={ticker}&from={(datetime.now()-timedelta(days=look_back)).date()}&apiKey={api_key}"
    res = requests.get(url).json()
    articles = res.get("articles", [])
    return articles


def fetch_article_text(url: str):
    try:
        article = Article(url)
        article.download()
        article.parse()
        if len(article.text.strip()) < 200:  # Too short, likely failed
            raise ValueError("Incomplete text")
        return article.text
    
    except Exception as e:
        print(f"Failed to parse {url}: {e}")
        return None


def get_content(article):
    url = article.get("url", None)

    if url:
        text = fetch_article_text(url)
        if text:
            return text
        try:
            downloaded = trafilatura.fetch_url(url)
            return trafilatura.extract(downloaded)
        except:
            pass
    
    return article.get("title" + ". ", "") + article.get("description", "")


def fetch_sentiment(ticker: str):
    ticker = ticker.upper()
    load_path = WORK_DIR / f"sentiment/{ticker}.json"

    if Path(load_path).exists() and not is_cache_stale(ticker, "sentiment"):
        return load_json(load_path)

    # Creating the sentiment analysis pipeline
    classifier = pipeline(task='text-classification', model='ProsusAI/finbert')
    
    ticker_feed = get_feed(ticker=ticker, look_back=10)

    total = 0
    num_articles = 0
    positive = 0
    total_articles = 0
    all_content = []

    for article in ticker_feed:
        title = article.get("title", "") or ""
        desc = article.get("description", "") or ""
        content = f"{title}. {desc}".strip()

        if content:
            sentiment = classifier(content)[0]
            total_articles += 1

            if sentiment["label"] == 'positive' or sentiment["label"] == 'negative':
                total += sentiment["score"]
                num_articles += 1
                all_content.append(content)

            if sentiment["label"] == "positive":
                positive += 1

    data = {"Overall Sentiment": total / num_articles,
            "Positive Articles": positive,
            "Negative Artciles": num_articles - positive,
            "Total Artciles": total_articles,
            "Category": "Positive" if total >= 0.2 else "Negative" if total <= 0.2 else "Neutral",
            "Contents": all_content,}

    save_json(save_path=load_path, data=data)
    update_cache_index(ticker, "sentiment")
    return data

# %%
arts = get_feed("aapl")

# %%
arts
# Out:
# [{'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Jim Edwards',
#   'title': 'Global markets tumble as Beijing imposes new ban on U.S. shipping and Bessent vows China ‘will be hurt the most’ if it doesn’t surrender',
#   'description': 'China showed no signs of backing down from President Trump’s trade war.',
#   'url': 'https://finance.yahoo.com/news/global-markets-tumble-beijing-imposes-101818085.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/AbOODaNKz5V0uPrmU7mHLA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD03ODU-/https://media.zenfs.com/en/fortune_175/2ad8b422b81beffbed27abe05923f8d3',
#   'publishedAt': '2025-10-14T10:18:18Z',
#   'content': '<ul><li>Global stock markets fell after China banned certain U.S. shipping firms and Treasury Secretary Scott Bessent said if they want to slow down the global economy, they will be hurt the most. As… [+4085 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Ghazal Ahmed',
#   'title': 'Apple (AAPL) Stock Faces “More Downside Than Upside” as Jefferies Flags Tariff Concerns',
#   'description': 'Apple Inc. (NASDAQ:AAPL) is one of the AI Stocks in Focus on Wall Street. On October 13, Jefferies reiterated the stock as “Underperform” and lowered its...',
#   'url': 'https://finance.yahoo.com/news/apple-aapl-stock-faces-more-155645038.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/Rg5jM6lGKnZVF2uSKRUA_Q--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzM-/https://media.zenfs.com/en/insidermonkey.com/a151e7f10510a23c539d22a07dc2f5b8',
#   'publishedAt': '2025-10-15T15:56:45Z',
#   'content': 'Apple Inc. (NASDAQ:AAPL) is one of theAI Stocks in Focus on Wall Street.\xa0On October 13, Jefferies reiterated the stock as Underperform and lowered its price target on the stock to $203.07 per share f… [+1908 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Fahad Saleem',
#   'title': 'Analyst Explains ‘The Problem’ With Apple (AAPL)',
#   'description': 'We recently published 10 AI Analyst Calls You Should Pay Attention To. Apple Inc (NASDAQ:AAPL) is one of the stocks analysts were recently talking about...',
#   'url': 'https://finance.yahoo.com/news/analyst-explains-problem-apple-aapl-192307165.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/cVvSOEVgXXeSO16E_nX5FQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/insidermonkey.com/abe42548427d5976d59895bbd8b8797c',
#   'publishedAt': '2025-10-12T19:23:07Z',
#   'content': 'We recently published 10 AI Analyst Calls You Should Pay Attention To. Apple Inc (NASDAQ:AAPL) is one of the stocks analysts were recently talking about.\r\nDaniel Newman, The Futurum Group CEO, said i… [+2582 chars]'},
#  {'source': {'id': None, 'name': 'Osxdaily.com'},
#   'author': 'Jamie Cuevas',
#   'title': 'New M5 Chip Comes to iPad Pro, MacBook Pro 14″, & Apple Vision Pro',
#   'description': 'Apple has updated the iPad Pro lineup, MacBook Pro 14″, and Apple Vision Pro, to feature the all new M5 chip. These are basically spec-bump updates focused on the new M5 chip architecture, with no new hardware redesign or major new features or changes otherwi…',
#   'url': 'https://osxdaily.com/2025/10/15/new-m5-chip-comes-to-ipad-pro-macbook-pro-14-apple-vision-pro/',
#   'urlToImage': 'https://cdn.osxdaily.com/wp-content/uploads/2025/10/m5-macbook-pro.jpg',
#   'publishedAt': '2025-10-15T23:20:44Z',
#   'content': 'Apple has updated the iPad Pro lineup, MacBook Pro 14″, and Apple Vision Pro, to feature the all new M5 chip. These are basically spec-bump updates focused on the new M5 chip architecture, with no ne… [+3261 chars]'},
#  {'source': {'id': None, 'name': 'Barchart.com'},
#   'author': 'Gavin McMaster',
#   'title': 'Options Alert: Iron Condor Screener Results for October 15th',
#   'description': 'A short iron condor is an income strategy that aims to profit when a stock stays within a specified range over the course of the trade. The trade is composed...',
#   'url': 'https://www.barchart.com/story/news/35457782/options-alert-iron-condor-screener-results-for-october-15th',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/lTS9dgH9LvGHCBBSN8FKyA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/barchart_com_477/af1ede3e8ffa3a9be285b729fedecee5',
#   'publishedAt': '2025-10-15T11:00:02Z',
#   'content': 'A short iron condor is an income strategy that aims to profit when a stock stays within a specified range over the course of the trade. The trade is composed of four options with the same expiration:… [+3768 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'AppleデバイスやNintendo Switch 2にも対応するBluetoothゲームコントローラー「8BitDo Pro 3」レビュー。',
#   'description': 'AppleデバイスやNintendo Switch 2にも対応するBluetoothゲームコントローラー「8BitDo Pro 3」レビューです。詳細は以下から。 \u3000香港のゲームコントローラーメーカー8BitDoは20 […]\nThe post AppleデバイスやNintendo Switch 2にも対応するBluetoothゲームコントローラー「8BitDo Pro 3」レビュー。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251012-8bitdo-pro-3-bluetooth-controller-review.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/8BitDo-Pro-3-Bluetooth-Controller-Hero.webp',
#   'publishedAt': '2025-10-12T01:09:58Z',
#   'content': 'AppleNintendo Switch 2Bluetooth8BitDo Pro 3\r\n8BitDo20250720218BitDo Pro 2 Bluetooth8BitDo Pro 3 Bluetooth 8BitDo Pro 3Amazon10%OFF1\r\n8BitDo Pro 3 Gray\r\n8BitDo Pro 3ABXYJoyNintendoUSB-A – USB-CUSB-C\r\n… [+593 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Apple Silicon Macへ移植されたアクションアドベンチャーゲーム「Control」が、2026年にiPhoneやiPad、Vision Proでもプレイ可能になるもよう。',
#   'description': 'Apple Silicon Macへ移植されたアクションアドベンチャーゲーム「Control」が2026年にiPhoneやiPad、Vision Proでもプレイ可能になるそうです。詳細は以下から。 \u3000Appleは20 […]\nThe post Apple Silicon Macへ移植されたアクションアドベンチャーゲーム「Control」が、2026年にiPhoneやiPad、Vision Proでもプレイ可能になるもよう。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251010-control-for-iphone-and-vision-pro-early-2026.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2024/11/Control-Ultimate-Edition-for-Mac-pre-order-features-1.jpg',
#   'publishedAt': '2025-10-10T09:35:56Z',
#   'content': 'Apple Silicon MacControl2026iPhoneiPadVision Pro\r\nApple202406WWDC24WindowsDirectX 12MacGame Porting Toolkit 2 (PTK2)Remedy Entertainment Ltd.80Control Ultimate EditionMac202503Mac App Store\r\nWinner o… [+1008 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Elgato、Stream DeckシリーズでMac/Windowsのウィンドウ管理が可能なプラグイン「Window Mover」をリリース。',
#   'description': 'ElgatoがStream DeckシリーズでMac/Windowsのウィンドウ管理が可能なプラグイン「Window Mover」をリリースしています。詳細は以下から。 \u3000米CORSAIR Inc.傘下のElgatoは […]\nThe post Elgato、Stream DeckシリーズでMac/Windowsのウィンドウ管理が可能なプラグイン「Window Mover」をリリース。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251010-elgato-stream-deck-window-mover.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Elgato-Stream-Deck-Window-Mover-Hero.webp',
#   'publishedAt': '2025-10-10T12:35:58Z',
#   'content': 'Move, resize, and snap windows into place with a single press. Window Mover lets you easily reposition apps across displays, so youre ready to share, stream, or multitask. Organize your workspace, no… [+170 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Belkin、MagSafe/Qi2 25Wワイヤレス充電に対応したiPhone Air/17/Pro用の「Belkin SheerForceクリア/カラーケース」を発売。',
#   'description': 'BelkinがMagSafeとQi2ワイヤレス充電に対応したiPhone Air/17/Pro用ケース「Belkin SheerForce iPhoneクリアケース」を発売しています。詳細は以下から。 \u3000台湾Foxco […]\nThe post Belkin、MagSafe/Qi2 25Wワイヤレス充電に対応したiPhone Air/17/Pro用の「Belkin SheerForceクリア/カラーケース」を発売。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251015-belkin-sheerforce-iphone-air-17-case.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Belkin-SheerForce-iPhone-Air-17-Case-Hero.webp',
#   'publishedAt': '2025-10-15T05:21:38Z',
#   'content': 'BelkinMagSafeQi2iPhone Air/17/ProBelkin SheerForce iPhone\r\nFoxconnBelkin International, Inc.20251015Apple0919iPhoneiPhone AirA19/ProiPhone 17/17 ProBelkin SheerForce iPhone/\r\nBelkin SheerForce iPhone… [+150 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': '初代Macintosh風デザインで5インチHDディスプレイを搭載したMac mini用ドッキングステーション「Wokyis M5」レビュー。',
#   'description': '初代Macintosh風デザインで5インチHDディスプレイを搭載したMac mini用ドッキングステーション「Wokyis M5」レビューです。詳細は以下から。 \u3000中国の周辺機器メーカーWokyisは現地時間2025年 […]\nThe post 初代Macintosh風デザインで5インチHDディスプレイを搭載したMac mini用ドッキングステーション「Wokyis M5」レビュー。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251014-wokyis-m5-dock-for-mac-mini.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Wokyis-M5-Dock-for-Mac-mini-review-Hero.webp',
#   'publishedAt': '2025-10-14T19:49:54Z',
#   'content': 'Macintosh5HDMac miniWokyis M5\r\nWokyis20250701Apple11Apple M4/M4 ProThunderbolt 4/5Mac mini (2024)Wokyis M5\r\nKickstarterWokyis M5()Mac mini\r\nWokyis M5 \r\nWokyis M5\r\nWokyis M5KickstarterWokyis M5PCUSB-C… [+823 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Apple、開発者向けに「macOS 26.1 Tahoe」や「iOS/iPadOS 26.1」のBeta 3を公開。',
#   'description': 'Appleが開発者向けに「macOS 26.1 Tahoe」や「iOS/iPadOS 26.1」のBeta 3を公開しています。詳細は以下から。 \u3000Appleは現地時間2025年09月15日、Liquid Glassデ […]\nThe post Apple、開発者向けに「macOS 26.1 Tahoe」や「iOS/iPadOS 26.1」のBeta 3を公開。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251014-macos-26-1-tahoe-and-ios-26-1-beta-3.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/macOS-26-1-Tahoe-and-ios-26-1-beta-3-Hero.webp',
#   'publishedAt': '2025-10-13T22:10:29Z',
#   'content': 'ApplemacOS 26.1 TahoeiOS/iPadOS 26.1Beta 3\r\nApple20250915Liquid GlassmacOS 26 TahoeiOS/iPadOS 261013macOS 26.1iOS/iPadOS 26.1watchOS 26.1tvOS 26.1visionOS 26.1Beta 3\r\n<ul><li>iOS 26.1 beta 3 (23B5064… [+354 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Parallels、macOS 26 TahoeやWindows 11 25H2をサポートした「Parallels Desktop 26 for Mac」を最大45%OFFで販売するフラッシュセールを開催。',
#   'description': 'ParallelsがmacOS 26 TahoeやWindows 11 25H2をサポートした「Parallels Desktop 26 for Mac」を45%OFFで販売するフラッシュセールを開催しています。詳細は […]\nThe post Parallels、macOS 26 TahoeやWindows 11 25H2をサポートした「Parallels Desktop 26 for Mac」を最大45%OFFで販売するフラッシュセールを開催。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251015-parallels-desktop-26-for-mac-sale.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Parallels-Desktop-26-for-Mac-sale-Hero.webp',
#   'publishedAt': '2025-10-14T21:27:29Z',
#   'content': 'ParallelsmacOS 26 TahoeWindows 11 25H2Parallels Desktop 26 for Mac45%OFF\r\nAlludo(Corel)Parallels International GmbH.20251014macOS 26 TahoeWindows 11 25H2Parallels Desktop 26 for Mac45%OFF\r\n45% off Pa… [+626 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Ghazal Ahmed',
#   'title': 'Apple (AAPL) Price Target Stays at $220 as UBS Sees Flattening iPhone Wait Times',
#   'description': 'Apple Inc. (NASDAQ:AAPL) is one of the AI Stocks In The Spotlight For Investors. On October 8, UBS analyst David Vogt maintained a Neutral rating on the...',
#   'url': 'https://finance.yahoo.com/news/apple-aapl-price-target-stays-124402752.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/F5JlmXnBqeSZCpfgrAp10w--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzM-/https://media.zenfs.com/en/insidermonkey.com/a71568c8c3ad6fbd1e12b07207b045d2',
#   'publishedAt': '2025-10-11T12:44:02Z',
#   'content': 'Apple Inc. (NASDAQ:AAPL) is one of the AI Stocks In The Spotlight For Investors.\xa0On October 8, UBS analyst David Vogt maintained a Neutral rating on the stock with a $220.00 price target. The firm no… [+1528 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'GPUにNeural Acceleratorを備えた「Apple M5」チップのスペックまとめ。',
#   'description': 'Apple M5チップのスペックまとめです。詳細は以下から。 \u3000Appleは現地時間2025年10月15日、AIパフォーマンスにさらなる進化をもたらす次世代GPUを搭載した第5世代のApple Silicon「Appl […]\nThe post GPUにNeural Acceleratorを備えた「Apple M5」チップのスペックまとめ。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251016-apple-m5-chip.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Apple-M5-CPU-GPU-NE-Media-engine-Hero-v2.webp',
#   'publishedAt': '2025-10-15T19:31:00Z',
#   'content': 'Apple M5\r\nApple20251015AIGPU5Apple SiliconApple M5\r\nM5M4AI4GPUNeural AcceleratorGPUCPUNeural Engine\r\nAppleAppleAIM5 Apple\r\nApple M505Apple M423nm33nm(TSMC N3P?)CPU6410CPU\r\nApple M4\r\nGPUiPhone 17/ProA… [+351 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Elgato、長時間デスクワークを行うクリエイター向けのスタジオチェア「Elgato Embrace」を発表。',
#   'description': 'Elgatoが長時間デスクワークを行うクリエイター向けのスタジオチェア「Elgato Embrace」を発売すると発表しています。詳細は以下から。 \u3000米CORSAIR Inc.は現地時間2025年10月10日、傘下のゲ […]\nThe post Elgato、長時間デスクワークを行うクリエイター向けのスタジオチェア「Elgato Embrace」を発表。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251011-elgato-embrace-studio-chair.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Elgato-Embrace-studio-chair-Hero.webp',
#   'publishedAt': '2025-10-11T04:05:05Z',
#   'content': 'Munich, Germany, October 10, 2025 Elgato, a CORSAIR® brand, today announced its first studio chair, Embrace. Built from the ground up for creators, professionals, and anyone who spends serious time a… [+150 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Microsoft、アイコンのデザインを刷新した「Microsoft 365 for Mac」のロールアウトを開始。',
#   'description': 'MicrosoftがCopilotからインスピレーションを受けた新アイコンの「Microsoft 365 for Mac」をロールアウト開始しています。詳細は以下から。 \u3000Microsoftは現地時間2025年10月0 […]\nThe post Microsoft、アイコンのデザインを刷新した「Microsoft 365 for Mac」のロールアウトを開始。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251016-microsoft-365-for-mac-new-icons.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Microsoft-365-Office-2025-icons-Hero.webp',
#   'publishedAt': '2025-10-16T02:50:22Z',
#   'content': 'MicrosoftCopilotMicrosoft 365 for Mac\r\nMicrosoft20251001Microsoft 365/OfficeWord, Excel, PowerPoint for Mac\r\nWith Copilot now being such a more complete and integrated system within Microsoft 365, it… [+571 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Anker Japan、DisplayLinkチップを採用し8Kと4K60Hz x2のトリプルディスプレイ出力が可能な「Anker Prime ドッキングステーション (14-in-1, Triple Display, DisplayLink)」を発売。',
#   'description': 'Anker JapanがDisplayLinkチップを採用し8K+4Kx2のトリプルディスプレイ出力が可能なドック「Anker Prime ドッキングステーション (14-in-1, Triple Display, D […]\nThe post Anker Japan、DisplayLinkチップを採用し8Kと4K60Hz x2のトリプルディスプレイ出力が可能な「Anker Prime ドッキングステーション (14-in-1, Triple Display, DisplayLink)」を発売。 first ap…',
#   'url': 'https://applech2.com/archives/20251016-anker-prime-docking-station-14-in-1-triple-displa-displaylink.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Anker-Prime-Docking-Station-14-in-1-Triple-Displa-DisplayLink-Hero.webp',
#   'publishedAt': '2025-10-16T03:40:13Z',
#   'content': 'Anker JapanDisplayLink8K+4Kx2Anker Prime (14-in-1, Triple Display, DisplayLink)\r\nAnker Japan20251016Anker PrimeUSBUSBDisplayLinkAnker Prime Docking Station (14-in-1, Triple Display, DisplayLink) (Ank… [+1138 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Nonstrict、AirPods Pro 3やApple Watchの心拍センサーからのリアルタイム心拍数を利用したマインドフルネスアプリ「Rhythm」をリリース。',
#   'description': 'NonstrictがAirPods Pro 3やBeats Powerbeats Pro 2、Apple Watchで取得したリアルタイムの心拍数を利用するマインドフルネスアプリ「Rhythm」をリリースしています。詳 […]\nThe post Nonstrict、AirPods Pro 3やApple Watchの心拍センサーからのリアルタイム心拍数を利用したマインドフルネスアプリ「Rhythm」をリリース。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251014-rhythm-heart-rate-meditation-with-airpods-pro-3.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Rhythm-Heart-Rate-Meditation-with-AirPods-Pro-3-Hero.webp',
#   'publishedAt': '2025-10-14T04:16:20Z',
#   'content': 'NonstrictAirPods Pro 3Beats Powerbeats Pro 2Apple WatchRhythm\r\nApple202509192(ANC)AirPods Pro 3\r\nAirPods Pro 3Beats Powerbeats Pro 2Apple Watch1Rhythm\r\nRhythmMacVision ProSplitscreeniPhoneVision ProT… [+528 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Amazonプライム感謝祭で、SatechiやRayCue、Ugreen、OricoのMac mini用ドックやストレージが特選タイムセール中。',
#   'description': 'Amazonプライム感謝祭でSatechiやRayCue、Ugreen、OricoのMac mini用ドックやストレージが特選タイムセールとなっています。詳細は以下から。 \u3000Amazon Japanは本日10月10日2 […]\nThe post Amazonプライム感謝祭で、SatechiやRayCue、Ugreen、OricoのMac mini用ドックやストレージが特選タイムセール中。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251010-amazon-mac-mini-prime-sale.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Amazon-Mac-mini-Prime-Sale.webp',
#   'publishedAt': '2025-10-10T00:38:23Z',
#   'content': 'AmazonSatechiRayCueUgreenOricoMac mini\r\nAmazon Japan10102359Amazon200AmazonMac mini (2024)\r\nSatechiRayCueUgreenOricoMac miniSatechiMac Mini M4 &amp; USB4 NVMe SSD \r\nSatechi\r\nSatechi Mac Mini M4 &amp;… [+1404 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Apple M5チップを搭載した「MacBook Pro」が近く発表されるもよう。',
#   'description': 'AppleはApple M5チップを搭載した「MacBook Pro」を近く発表するようです。詳細は以下から。 \u3000AppleでWorldwide Marketingを務めるのGreg Joswiak SVPは現地時間2 […]\nThe post Apple M5チップを搭載した「MacBook Pro」が近く発表されるもよう。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251015-apple-m5-macbook-pro-is-coming.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Apple-M5-MacBook-Pro-is-coming-Hero-v2.webp',
#   'publishedAt': '2025-10-14T20:28:00Z',
#   'content': 'AppleApple M5MacBook Pro\r\nAppleWorldwide MarketingGreg Joswiak SVP20251014X\r\nMmmmm something powerful is coming.\r\nX\r\nMacBook ProV202410Apple M4/M4 ProiMac (24, M4, 2024)MacBook Pro (14/16, M4/M4 Pro/… [+430 chars]'},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Trefis Team, Contributor, \n Trefis Team, Contributor\n https://www.forbes.com/sites/greatspeculations/people/trefis/',
#   'title': 'Medtronic Stock’s $50 Billion Gift To Investors',
#   'description': 'In the last decade, Medtronic (MDT) stock has returned a notable $52 Bil back to its shareholders through cold, hard cash via dividends and buybacks',
#   'url': 'https://www.forbes.com/sites/greatspeculations/2025/10/13/medtronic-stocks-50-billion-gift-to-investors/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/68ecd481ff9f42ca6c1567fa/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'publishedAt': '2025-10-13T10:29:33Z',
#   'content': 'GLASGOW, SCOTLAND - MAY 22: Dr Catherine Calderwood (2L), Chief Medical Officer for Scotland, Professor Sir Pete Downes, Principal and Vice Chancellor (2R), Dr Vanessa Kay, Co-Director DIHS (R) and D… [+4093 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': '財訊快報',
#   'title': '蘋果以M5晶片升級三款裝置，鎖定假日季需求與AI效能紅利',
#   'description': '【財訊快報／陳孟朔】外電報導，蘋果公司(美股代碼AAPL)週三發布搭載新款M5晶片的iPad Pro、Vision Pro與入門級MacBook Pro，外觀維持現行設計，處理器全面升級以強化運算、圖像與AI任務表現，搶攻年終假日購物季。三款產品起售價格不變，iPad Pro為999美元、MacBook Pro為1,599美元、Vision Pro為3,499美元。本輪升級除處理器外，iPad Pro新增自研N1無線晶片與C1X數據機，Vision Pro則提供全新頭帶選項，著重連線體驗與配戴舒適度優化。定價維持…',
#   'url': 'https://tw.stock.yahoo.com/news/%E8%98%8B%E6%9E%9C%E4%BB%A5m5%E6%99%B6%E7%89%87%E5%8D%87%E7%B4%9A%E4%B8%89%E6%AC%BE%E8%A3%9D%E7%BD%AE-%E9%8E%96%E5%AE%9A%E5%81%87%E6%97%A5%E5%AD%A3%E9%9C%80%E6%B1%82%E8%88%87ai%E6%95%88%E8%83%BD%E7%B4%85%E5%88%A9-234954213.html',
#   'urlToImage': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo-1200x1200.png',
#   'publishedAt': '2025-10-15T15:49:54Z',
#   'content': '(AAPL)M5iPad ProVision ProMacBook ProAIiPad Pro999MacBook Pro1,599Vision Pro3,499iPad ProN1C1XVision Pro\r\n1022iPhone 17iPhone AirAirPodsApple Watch\r\nM5AI'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': '財訊快報',
#   'title': 'iPhone Air 10/17開放中國預購，三大運營商eSIM商用試驗獲批',
#   'description': '【財訊快報／陳孟朔】蘋果公司(美股代碼AAPL)執行長庫克(Tim Cook)週一在抖音直播宣布，iPhone Air將於10月17日早上9時起在中國開放預購，10月22日起正式發售，售價自人民幣7,999元(下同)起。該機主打輕薄設計並全面採用eSIM，為蘋果在中國市場首款「無實體卡槽」的iPhone。配合機型上市節奏，中國三大電訊商的eSIM商用試驗同步推進。消息指，中國聯通已於9月初率先獲批；中國電信與中國移動於10月相繼獲批開展eSIM手機運營服務商用試驗，為eSIM終端大規模上線鋪路。中國聯通表示，已正…',
#   'url': 'https://tw.stock.yahoo.com/news/iphone-air-10-17%E9%96%8B%E6%94%BE%E4%B8%AD%E5%9C%8B%E9%A0%90%E8%B3%BC-%E4%B8%89%E5%A4%A7%E9%81%8B%E7%87%9F%E5%95%86esim%E5%95%86%E7%94%A8%E8%A9%A6%E9%A9%97%E7%8D%B2%E6%89%B9-003446078.html',
#   'urlToImage': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo-1200x1200.png',
#   'publishedAt': '2025-10-13T16:34:46Z',
#   'content': '(AAPL)(Tim Cook)iPhone Air1017910227,999()eSIMiPhoneeSIM910eSIMeSIM\r\nAppeSIMeSIMeSIM31\r\niPhone 179eSIMeSIMiPhone Air\r\neSIMGSMASIMeSIM\r\niPhone AireSIM12.795%2.390.97%247.661.1%'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'iPod Classicに最大2枚のmicroSDカードを搭載可能にするiPod用Modeアダプター「iFlash-uDUAL」が発売。',
#   'description': 'iPod ClassicにmicroSDカードを2枚搭載可能なiPod用Modeアダプター「iFlash-uDUAL」が発売されています。詳細は以下から。 \u3000iFlashはイギリスのTarkanさんが開発しているMod […]\nThe post iPod Classicに最大2枚のmicroSDカードを搭載可能にするiPod用Modeアダプター「iFlash-uDUAL」が発売。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251014-iflash-udual-for-ipod-classic-microsd-card-adapter.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/iFlash-uDUAL-for-iPod-Classic-Adapter-Hero-v2.webp',
#   'publishedAt': '2025-10-13T21:49:33Z',
#   'content': 'iPod ClassicmicroSD2iPodModeiFlash-uDUAL\r\niFlashTarkanModApple20149iPod ClassicCFSD/microSD1TBiPod (Tera Pod)iPodiFlashiFlash-uDUAL (SKU:uDUAL)\r\nFor those seeking solid state storage capabilities for… [+755 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'macOS 26 TahoeでWindowServerがGPU使用率を上昇させてしまう不具合を修正した「VS Code v1.105」がリリース。',
#   'description': 'macOS 26 TahoeでWindowServerがGPU使用率を上昇させてしまう不具合が修正された「VS Code v1.105」がリリースされています。詳細は以下から。 \u3000Microsoftは現地時間2025年 […]\nThe post macOS 26 TahoeでWindowServerがGPU使用率を上昇させてしまう不具合を修正した「VS Code v1.105」がリリース。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251011-vs-code-fixed-windowserver-gpu-issue-on-macos-26-tahoe.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/VS-Code-fixed-windowserver-gpu-issue-on-macos-26-tahoe-features-1.webp',
#   'publishedAt': '2025-10-11T00:28:46Z',
#   'content': 'macOS 26 TahoeWindowServerGPUVS Code v1.105\r\nMicrosoft20251009Visual Studio Code1.105macOS 26 TahoeGPU\r\nFix: Disable window shadows on macOS Tahoe to prevent GPU performance issues PR #267724\r\nSeptem… [+228 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'RME、macOS 26 TahoeではFireWire 400/800のサポートがシステムレベルで削除されたことにより「Fireface 400/800」を利用したオーディオデバイスが使用できなくなったと発表。',
#   'description': 'RMEがAppleがmacOS 26 TahoeでFireWire 400/800のサポートをシステムレベルで削除したことにより「Fireface 400/800」などのデバイス使用できなくなっていると発表しています。 […]\nThe post RME、macOS 26 TahoeではFireWire 400/800のサポートがシステムレベルで削除されたことにより「Fireface 400/800」を利用したオーディオデバイスが使用できなくなったと発表。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251016-apple-removes-system-level-firewire-support.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/RME-Fireface-400-800-end-support-on-macOS-26-Tahoe.webp',
#   'publishedAt': '2025-10-15T23:00:18Z',
#   'content': 'RMEApplemacOS 26 TahoeFireWire 400/800Fireface 400/800\r\nRME20250930macOS 26 TahoemacOS 26 TahoeFireface 400/800\r\nWith the release of macOS 26 (“Tahoe”), Apple has removed system-level support for Fir… [+783 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Amazonプライム感謝祭で、Microsoft 365サブスクリプションのセールやKindle本秋の特別セールなどのキャンペーンが本日10月10日まで開催中。',
#   'description': 'Amazonプライム感謝祭で、Microsoft 365のサブスクリプションのセールやAmazonギフトカード購入500ポイントキャンペーンなどが開催中。ます。詳細は以下から。 \u3000Amazon Japanは本日10月1 […]\nThe post Amazonプライム感謝祭で、Microsoft 365サブスクリプションのセールやKindle本秋の特別セールなどのキャンペーンが本日10月10日まで開催中。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251010-amazon-prime-campaign.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Amazon-Microsoft-365-Prime-Sale-Hero-2.webp',
#   'publishedAt': '2025-10-10T13:23:40Z',
#   'content': 'AmazonMicrosoft 365Amazon500\r\nAmazon Japan10102359Amazon200Amazon\r\nAmazon\r\nMicrosoft 365 PersonalFamily121%OFF179%OFF\r\nKindle\r\nKindle30,000Kidle50%OFF12%OFF\r\n<ul><li>Kindle – Amazon.co.jp</li><li> – … [+150 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Newtalk新聞 |張柏源 綜合報導',
#   'title': '川普放軟舒緩美中貿易緊張! 美股強勢反彈、台積電ADR大漲7.89％',
#   'description': '[Newtalk新聞] 中國近日宣布擴大限制稀土出口再掀美中貿易緊張，美國總統川普（Donald Trump）揚言要對從中國進口的商品加徵100%關稅，但之後他態度明顯放軟，使美國股市從上週末的大幅跌勢反彈回升，美股4個主要指數13日全部收漲，台積電ADR更大漲近8%。 美股13日收盤，道瓊工業指數揚升587.98點或1.29%，收46067.58點。標準普爾500指數上漲102.21點或1.56%，收6654.72點。以科技股為主的那斯達克指數勁揚490.18點或2.21%，收22694.61點。費城半導體指數…',
#   'url': 'https://tw.news.yahoo.com/%E5%B7%9D%E6%99%AE%E6%94%BE%E8%BB%9F%E8%88%92%E7%B7%A9%E7%BE%8E%E4%B8%AD%E8%B2%BF%E6%98%93%E7%B7%8A%E5%BC%B5-%E7%BE%8E%E8%82%A1%E5%BC%B7%E5%8B%A2%E5%8F%8D%E5%BD%88-%E5%8F%B0%E7%A9%8D%E9%9B%BBadr%E5%A4%A7%E6%BC%B27-89-000029901.html',
#   'urlToImage': 'https://media.zenfs.com/ko/newtalk.tw/1d84fd2e20e5c71ab08dc641a777b49e',
#   'publishedAt': '2025-10-13T16:00:29Z',
#   'content': '-3132%NVIDIAADR8%0.5%10%OpenAI 10 GWOpenAI18OpenAI NVIDIAAMD2024202550%1.5 587.981.29%46,067.58 S&amp;P500102.211.56%6,654.72 NASDAQ490.182.21%22,694.61 315.864.93%6,723.47 1. (MSFT)0.60%514.05 (AAPL… [+23 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'Satechi Japan、Mac mini用USBハブや40Gbps対応のNVMe SSDエンクロージャ、SM1メカニカルキーボードなどを特別価格で販売する「秋大感謝祭」セールを開催。',
#   'description': 'Satechi JapanがMac mini用USBハブや40Gbps対応のNVMeエンクロージャ、SM1メカニカルキーボードなどを特別価格で販売する「秋大感謝祭」セールを開催しています。詳細は以下から。 \u3000Satec […]\nThe post Satechi Japan、Mac mini用USBハブや40Gbps対応のNVMe SSDエンクロージャ、SM1メカニカルキーボードなどを特別価格で販売する「秋大感謝祭」セールを開催。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251013-satechi-autumn-sale-2025.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Satechi-Japan-Autumn-Sale-2025-Hero-v2.webp',
#   'publishedAt': '2025-10-12T22:55:08Z',
#   'content': 'Satechi JapanMac miniUSB40GbpsNVMeSM1\r\nSatechi Japan20251011AppleSatechi1015\r\nMac miniSMSSDUSB-CSM1/SM3\r\nSSD\r\nM.2 NVMe SSD 9,590 6,329\r\nType-2230NVMe SSD1USB 3.2 Gen 2 (10Gbps)SSD34%OFF\r\nM.2 NVMe SSD… [+605 chars]'},
#  {'source': {'id': None, 'name': 'Applech2.com'},
#   'author': 'applech2',
#   'title': 'macOS 26 TahoeのSpotlightのデザインをベースにアプリケーションランチャーとして必要な機能を実装したLaunchpad代替アプリ「Blossom」のBeta版がリリース。',
#   'description': 'macOS 26 TahoeのSpotlightのデザインをベースにアプリケーションランチャーとしての機能を強化したLaunchpad代替アプリ「Blossom」のBeta版がリリースされています。詳細は以下から。 \u3000 […]\nThe post macOS 26 TahoeのSpotlightのデザインをベースにアプリケーションランチャーとして必要な機能を実装したLaunchpad代替アプリ「Blossom」のBeta版がリリース。 first appeared on AAPL Ch..',
#   'url': 'https://applech2.com/archives/20251013-blossom-for-mac-replacement-for-launchpad.html',
#   'urlToImage': 'https://applech2.com/wp-content/uploads/2025/10/Blossom-for-Mac-replacement-for-Launchpad-Hero.webp',
#   'publishedAt': '2025-10-13T02:42:59Z',
#   'content': 'macOS 26 TahoeSpotlightLaunchpadBlossomBeta\r\nApple202509macOS 26 Tahoe2011Mac OS X 10.7 LionMac OS X/macOSLaunchpadSpotlight\r\nApple Event, October 2010201107Mac OS X 10.7 LionLaunchpad\r\nSpotlightLaun… [+709 chars]'},
#  {'source': {'id': None, 'name': 'MarketWatch'},
#   'author': 'Barbara Kollmeyer',
#   'title': 'Friday’s selloff broke something in the stock market. Here’s what that means for investors.',
#   'description': 'Longview Economics says investors should tread carefully with stocks as something was broken with Friday’s selloff last week.',
#   'url': 'https://www.marketwatch.com/story/fridays-selloff-broke-something-in-the-stock-market-heres-what-that-means-for-investors-f93ae0c3',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/c7BY0Ym9UwXYWw7K41euHA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02MDA-/https://media.zenfs.com/en/marketwatch_hosted_869/c00db3aa71ea12e137d7380a43904a09',
#   'publishedAt': '2025-10-14T13:44:00Z',
#   'content': "Something has shifted in the stock market after Fridays selloff. Longview Economics says it's time to be careful. - Getty Images/iStockphoto\r\nInvestors who would like to fully focus on the start of e… [+8301 chars]"},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'FTNN新聞網',
#   'title': '台積電擴展美廠晶圓聚落！美股四大指數同步小漲\u3000台積電ADR衝漲2%急墜翻黑',
#   'description': '[FTNN新聞網]財經中心／綜合報導台積電強勁財報提振市場信心，美股主要指數週四（16日）早盤小漲開局，輝達等AI概念股同步走揚，不過，台積電ADR在開盤大漲逾...',
#   'url': 'https://tw.stock.yahoo.com/news/%E5%8F%B0%E7%A9%8D%E9%9B%BB%E6%93%B4%E5%B1%95%E7%BE%8E%E5%BB%A0%E6%99%B6%E5%9C%93%E8%81%9A%E8%90%BD-%E7%BE%8E%E8%82%A1%E5%9B%9B%E5%A4%A7%E6%8C%87%E6%95%B8%E5%90%8C%E6%AD%A5%E5%B0%8F%E6%BC%B2-%E5%8F%B0%E7%A9%8D%E9%9B%BBadr%E8%A1%9D%E6%BC%B22-%E6%80%A5%E5%A2%9C%E7%BF%BB%E9%BB%91-144700380.html',
#   'urlToImage': 'https://media.zenfs.com/zh-tw/ftnn_com_tw_939/5e4eb47d83dd381f1807b184b5f33259',
#   'publishedAt': '2025-10-16T06:47:00Z',
#   'content': '[FTNN]\r\n16AIADR2%0.55%161030590.13%5000.27%0.53%1.12%\r\n39899.24,523EPS17.441630%30%34%36%4202GIGAFAB\r\n34AINVDA-US1.63%MU-US6.52%AVGO-US2.02%\r\n14103046,312.8459.530.13%5006,689.0317.970.27%22,789.4311… [+180 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': '財訊快報',
#   'title': '全球Q3智慧型手機增長3%，蘋果市占18%創單季新高，三星蟬聯榜首',
#   'description': '【財訊快報／陳孟朔】外電引述研究機構Omdia公布最新報告指出，2025年第三季全球智慧型手機市場年增3%，在新機密集發表與通路提前備貨帶動下，出貨動能回溫；換機需求回升亦助攻該季重返成長軌道。三星電子(005930.KS)以19%市占連三季穩居全球第一，主力來自GalaxyA系列銷量續強，且第七代摺疊機升級帶動高階產品組合。同季，蘋果公司(美股代碼AAPL)iPhone出貨年增4%、市占升至18%，寫下其史上最強第三季表現。iPhone17系列表現亮眼，基礎款在不調價下升級容量超乎預期，17Pro/ProMax…',
#   'url': 'https://tw.stock.yahoo.com/news/%E5%85%A8%E7%90%83q3%E6%99%BA%E6%85%A7%E5%9E%8B%E6%89%8B%E6%A9%9F%E5%A2%9E%E9%95%B73-%E8%98%8B%E6%9E%9C%E5%B8%82%E5%8D%A018-%E5%89%B5%E5%96%AE%E5%AD%A3%E6%96%B0%E9%AB%98-%E4%B8%89%E6%98%9F%E8%9F%AC%E8%81%AF%E6%A6%9C%E9%A6%96-045642792.html',
#   'urlToImage': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo-1200x1200.png',
#   'publishedAt': '2025-10-14T20:56:42Z',
#   'content': 'Omdia20253%(005930.KS)19%GalaxyA\r\n(AAPL)iPhone4%18%iPhone1717Pro/ProMax\r\n(1810.HK)14%(Transsion)vivo9%\r\nOmdia)))\r\n(ASP)AI'},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Brett Owens, Contributor, \n Brett Owens, Contributor\n https://www.forbes.com/sites/brettowens/',
#   'title': '5 High Yield CEFs With Steep Discounts Right Now',
#   'description': 'CEFs are the last bargains left on the board. CEFs are often confused with mutual funds and ETFs, but they are different because they often trade at discounts',
#   'url': 'https://www.forbes.com/sites/brettowens/2025/10/12/5-high-yield-cefs-with-steep-discounts-right-now/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/68e69f91d909781923d68555/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'publishedAt': '2025-10-12T14:00:00Z',
#   'content': 'Taiwanese senior man sitting at table and calculating finances\r\ngetty\r\nClosed-end funds (CEFs) are the last bargains left on the board. CEFs are often confused with mutual funds and ETFs, but they ar… [+7015 chars]'},
#  {'source': {'id': None, 'name': 'Macdailynews.com'},
#   'author': 'MacDailyNews',
#   'title': 'Apple is searching for a replacement for AI chief John Giannandrea',
#   'description': 'Apple is reportedly seeking a new head of artificial intelligence as John Giannandrea, the company’s current AI chief. Giannandrea has…\nThe post Apple is searching for a replacement for AI chief John Giannandrea appeared first on MacDailyNews.',
#   'url': 'https://macdailynews.com/2025/10/10/apple-is-searching-for-a-replacement-for-ai-chief-john-giannandrea/',
#   'urlToImage': 'https://macdailynews.com/wp-content/uploads/2025/08/250822_john_giannandrea.png',
#   'publishedAt': '2025-10-10T17:01:33Z',
#   'content': 'John Giannandrea, Apple’s Senior Vice President ofAI Strategy, as depicted by xAI’s Grok\r\nApple is reportedly seeking a new head of artificial intelligence as John Giannandrea, the companys current A… [+1839 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'FTNN新聞網',
#   'title': '川普又TACO！美股道瓊、那指強彈400點\u3000台積電ADR回神猛噴7.7%',
#   'description': '[FTNN新聞網]記者曾奕語／綜合報導美股在歷經上週五（10日）的大跌後，於週一（13日）強勢反彈。美國總統川普上週五他才揚言對中國商品加徵100%關稅，卻在台...',
#   'url': 'https://tw.stock.yahoo.com/news/%E5%B7%9D%E6%99%AE%E5%8F%88taco-%E7%BE%8E%E8%82%A1%E9%81%93%E7%93%8A-%E9%82%A3%E6%8C%87%E5%BC%B7%E5%BD%88400%E9%BB%9E-%E5%8F%B0%E7%A9%8D%E9%9B%BBadr%E5%9B%9E%E7%A5%9E%E7%8C%9B%E5%99%B47-7-150700966.html',
#   'urlToImage': 'https://media.zenfs.com/ko/ftnn_com_tw_939/bb906f35db672a267df40aac80ed3096',
#   'publishedAt': '2025-10-13T07:07:00Z',
#   'content': '[FTNN]\r\n1013100%13Truth SocialTACOTrump Always Chickens Out5405004%ADR7.7%\r\nJamieson Greer\r\n13105045,950.06470.461.03%5006,638.5486.031.31%22,638.46434.031.95%6,693.40285.804.46%\r\nMetaMETA-US1.35%AMZ… [+141 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'FTNN新聞網',
#   'title': '中國喊制裁...美股又嚇崩！道瓊狂洩615點\u3000台積電ADR失守300美元跌逾2%',
#   'description': '[FTNN新聞網]記者曾奕語／綜合報導中國今（14）日宣布制裁南韓造船巨頭韓華海洋旗下5家美國子公司，表明這是對美國展開301調查的反制措施，激化市場對美中貿...',
#   'url': 'https://tw.stock.yahoo.com/news/%E4%B8%AD%E5%9C%8B%E5%96%8A%E5%88%B6%E8%A3%81-%E7%BE%8E%E8%82%A1%E5%8F%88%E5%9A%87%E5%B4%A9-%E9%81%93%E7%93%8A%E7%8B%82%E6%B4%A9615%E9%BB%9E-%E5%8F%B0%E7%A9%8D%E9%9B%BBadr%E5%A4%B1%E5%AE%88300%E7%BE%8E%E5%85%83%E8%B7%8C%E9%80%BE2-151300003.html',
#   'urlToImage': 'https://media.zenfs.com/ko/ftnn_com_tw_939/15a8e6e60310524e049b7e46c029fcba',
#   'publishedAt': '2025-10-14T07:13:00Z',
#   'content': '[FTNN]\r\n14530114615480ADR300295.712.37%\r\n14Hanwha Ocean530114\r\nOCI20265AMDGPUAMD1%4%\r\n141146,019.1148.470.11%5006,621.4133.310.50%22,464.54230.071.95%6,605.69117.781.75%\r\nMetaMETA-US0.88%AMZN-US1.81%… [+173 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Rian Howlett',
#   'title': "Stock market today: Dow, S&P 500, Nasdaq futures rise as TSMC's stellar earnings eclipse trade-war jitters",
#   'description': 'Investors weighed corporate earnings against the escalating US-China trade war.',
#   'url': 'https://finance.yahoo.com/news/live/stock-market-today-dow-sp-500-nasdaq-futures-rise-as-tsmcs-stellar-earnings-eclipse-trade-war-jitters-232657775.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/uU5rg.frAh_RhxrAPtcdyA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2024-12/3d337060-b0c2-11ef-b2ff-f975239e7b1f',
#   'publishedAt': '2025-10-15T23:26:57Z',
#   'content': "US stock futures rose on Thursday as chip giant TSMC's stellar earnings buoyed AI hopes, taking minds off fears of a prolonged US-China trade war stoked by President Trump.\r\nNasdaq 100 futures (NQ=F)… [+5255 chars]"},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': '三立新聞網',
#   'title': '國際／美中貿易戰降溫！美股全面開飆\u3000日韓股有望迎春風回暖！',
#   'description': '在川普上週威脅對中國商品加徵100%懲罰性關稅、導致美股蒸發約2兆美元市值後，他週末改口「別擔心中國」，更強調「美國希望幫助中國，而不是傷害它」，使投資人信心重回。美股週一全面回神，美國總統川普淡化美中貿易對峙，釋出「一切都會好起來」的緩和言論，成功安撫上週市場的恐慌情緒。',
#   'url': 'https://tw.news.yahoo.com/%E5%9C%8B%E9%9A%9B-%E7%BE%8E%E4%B8%AD%E8%B2%BF%E6%98%93%E6%88%B0%E9%99%8D%E6%BA%AB-%E7%BE%8E%E8%82%A1%E5%85%A8%E9%9D%A2%E9%96%8B%E9%A3%86-%E6%97%A5%E9%9F%93%E8%82%A1%E6%9C%89%E6%9C%9B%E8%BF%8E%E6%98%A5%E9%A2%A8%E5%9B%9E%E6%9A%96-233500851.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/j84saiSH.RZEExcaEjVe5Q--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzY-/https://media.zenfs.com/ko/setn.com.tw/4283201a804fff2587eb44a30a15c758',
#   'publishedAt': '2025-10-13T15:35:00Z',
#   'content': '100%2\r\n587.9846,067.581.29%5001.56%6,654.722.21%22,694.614.93%6,723.47AI12.524,909.75S&amp;P1.75\r\nAIMetaMETA-US1.47%AAPL-US0.97%AlphabetGOOGL-US3.2%MSFT-US0.6%AMZN-US1.71%TSLA-US5.42%\r\nOpenAIAVGO-US1… [+148 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Daniel Howley',
#   'title': 'Apple debuts new M5 chip alongside upgraded 14-inch MacBook Pro and iPad Pro',
#   'description': 'Apple on Wednesday announced its latest M5 chip and upgraded MacBook Pro and iPad Pro lines.',
#   'url': 'https://finance.yahoo.com/news/apple-debuts-new-m5-chip-alongside-upgraded-14-inch-macbook-pro-and-ipad-pro-140442179.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/e9010dyzf57z.OUFNkbizg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD0xMDE3/https://s.yimg.com/os/creatr-uploaded-images/2025-10/35d60bf0-a9cf-11f0-bdfb-d6266cc9804f',
#   'publishedAt': '2025-10-15T14:04:42Z',
#   'content': "Apple (AAPL) on Wednesday announced its new M5 processor, which it says offers improved AI performance in both its latest $1,599 MacBook Pro and $999 iPad Pro.\r\nApple says the chip, the company's mos… [+2680 chars]"},
#  {'source': {'id': None, 'name': 'Macdailynews.com'},
#   'author': 'MacDailyNews',
#   'title': 'Sustained iPhone demand points to 2026 upside for Apple – Gene Munster',
#   'description': 'Three weeks into the iPhone 17 cycle, global iPhone lead time data indicates that demand is slightly higher than last year. Gene Munster…\nThe post Sustained iPhone demand points to 2026 upside for Apple – Gene Munster appeared first on MacDailyNews.',
#   'url': 'https://macdailynews.com/2025/10/14/sustained-iphone-demand-points-to-2026-upside-for-apple-gene-munster/',
#   'urlToImage': 'https://macdailynews.com/wp-content/uploads/2025/09/250909_iphone_17_02.png',
#   'publishedAt': '2025-10-14T19:01:00Z',
#   'content': 'Apple’s iPhone 17\r\nThree weeks into the iPhone 17 cycle, global iPhone lead time data indicates that demand is slightly higher than last year. Veteran Apple analyst Gene Munster predicts a modest ret… [+2246 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'finance.yahoo.com',
#   'title': 'Analyst Explains ‘The Problem’ With Apple (AAPL)',
#   'description': 'We recently published 10 AI Analyst Calls You Should Pay Attention To. Apple Inc (NASDAQ:AAPL) is one of the stocks analysts were recently talking about.\nDaniel Newman, The Futurum Group CEO, said in a recent program on Schwab Network that things are “tough” …',
#   'url': 'https://biztoc.com/x/a116e7bada7ac2bb',
#   'urlToImage': 'https://biztoc.com/cdn/a116e7bada7ac2bb_s.webp',
#   'publishedAt': '2025-10-12T19:41:22Z',
#   'content': 'We recently published 10 AI Analyst Calls You Should Pay Attention To. Apple Inc (NASDAQ:AAPL) is one of the stocks analysts were recently talking about.Daniel Newman, The Futurum Group CEO, said in … [+148 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'seekingalpha.com',
#   'title': "Six Reasons To Ride Apple's Rally Cautiously And Why Continue To Use APLY",
#   'description': "Summary\n- Apple remains resilient amid tariff pressures, with strong free cash flow and stable profit margins demonstrating durable pricing power.\n- APLY, a conservative covered call ETF on AAPL, has captured ~20% of AAPL's ~27% rally, offering defensive upsi…",
#   'url': 'https://biztoc.com/x/4ffe0b6447aad004',
#   'urlToImage': 'https://biztoc.com/cdn/4ffe0b6447aad004_s.webp',
#   'publishedAt': '2025-10-11T07:37:11Z',
#   'content': 'Summary- Apple remains resilient amid tariff pressures, with strong free cash flow and stable profit margins demonstrating durable pricing power.- APLY, a conservative covered call ETF on AAPL, has c… [+148 chars]'},
#  {'source': {'id': None, 'name': 'Barchart.com'},
#   'author': 'Sushree Mohanty',
#   'title': 'Wedbush Sees an AI M&A Boom Ahead: 3 Prime Takeover Targets',
#   'description': 'The analyst believes the next innings in the AI revolution will be written with mergers and acquisitions.',
#   'url': 'https://www.barchart.com/story/news/35471539/wedbush-sees-an-ai-m-a-boom-ahead-3-prime-takeover-targets',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/JCnbzRIQs5OU1bSFB4msRA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02Mzk-/https://media.zenfs.com/en/barchart_com_477/7fdec65f8e6ecf6aa0253d0d6f820e97',
#   'publishedAt': '2025-10-15T17:57:36Z',
#   'content': 'The artificial intelligence (AI) arms race has entered a new phase, this time focused on mergers and acquisitions. According to CNBC, Wedbush Securities analyst Dan Ives believes that the "AI M&amp;A… [+6331 chars]'},
#  {'source': {'id': None, 'name': 'Barchart.com'},
#   'author': 'Rich Asplund',
#   'title': 'Stocks Settle Sharply Higher on Trade Hopes and AI Optimism',
#   'description': 'The S&P 500 Index ($SPX ) (SPY ) on Monday closed up +1.56%, the Dow Jones Industrials Index ($DOWI ) (DIA ) closed up +1.29%, and the Nasdaq 100 Index...',
#   'url': 'https://www.barchart.com/story/news/35414255/stocks-settle-sharply-higher-on-trade-hopes-and-ai-optimism',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/PkJR.Vd0boRPePjXLgXFFw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD03OTU-/https://media.zenfs.com/en/barchart_com_477/bab324b7ff3e454bd77e3afc82d85ce5',
#   'publishedAt': '2025-10-13T20:34:25Z',
#   'content': 'The\xa0S&amp;P 500 Index ($SPX) (SPY) on Monday closed up +1.56%,\xa0the Dow Jones Industrials Index ($DOWI)\xa0(DIA) closed up +1.29%, and the\xa0Nasdaq 100 Index ($IUXX) (QQQ) closed up +2.18%.\xa0 December E-min… [+9791 chars]'},
#  {'source': {'id': None, 'name': 'Barchart.com'},
#   'author': 'Rich Asplund',
#   'title': 'Stocks Supported by Trade Hopes and Broadcom’s AI Deal',
#   'description': 'The S&P 500 Index ($SPX ) (SPY ) today is up +1.18%, the Dow Jones Industrials Index ($DOWI ) (DIA ) is up +0.97%, and the Nasdaq 100 Index ($IUXX ) (QQQ...',
#   'url': 'https://www.barchart.com/story/news/35409014/stocks-supported-by-trade-hopes-and-broadcoms-ai-deal',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/F_ZJDS12E4olt5iHV3X55A--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/barchart_com_477/fda4fa13493a27d0c8a4c56df32e0629',
#   'publishedAt': '2025-10-13T15:11:24Z',
#   'content': 'The\xa0S&amp;P 500 Index ($SPX) (SPY) today is up +1.18%,\xa0the Dow Jones Industrials Index ($DOWI)\xa0(DIA) is up +0.97%, and the\xa0Nasdaq 100 Index ($IUXX) (QQQ) is up +1.52%.\xa0 December E-mini S&amp;P future… [+8695 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'benzinga.com',
#   'title': "Here's How Much $100 Invested In Apple 15 Years Ago Would Be Worth Today",
#   'description': 'Apple (NASDAQ:AAPL) has outperformed the market over the past 15 years by 10.82% on an annualized basis producing an average annual return of 22.99%. Currently, Apple has a market capitalization of $3.71 trillion. \nBuying $100 In AAPL: If an ...\nFull story av…',
#   'url': 'https://biztoc.com/x/a79eb9e8cd3d3e18',
#   'urlToImage': 'https://biztoc.com/cdn/950/og.png',
#   'publishedAt': '2025-10-14T15:09:34Z',
#   'content': 'Apple (NASDAQ:AAPL) has outperformed the market over the past 15 years by 10.82% on an annualized basis producing an average annual return of 22.99%. Currently, Apple has a market capitalization of $… [+139 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'thestreet.com',
#   'title': 'Apple CEO sends signal on crucial China moment',
#   'description': 'In many ways, Apple’s (AAPL) 2025 story has been one of quiet resilience. \nDespite sluggish global smartphone demand, the world’s most valuable business was able to find new ways to bend the curve.\nIts success had everything to do with supply-chain recalibrat…',
#   'url': 'https://biztoc.com/x/4cbe4598afeb6c75',
#   'urlToImage': 'https://biztoc.com/cdn/4cbe4598afeb6c75_s.webp',
#   'publishedAt': '2025-10-15T22:48:11Z',
#   'content': 'In many ways, Apples (AAPL) 2025 story has been one of quiet resilience. Despite sluggish global smartphone demand, the worlds most valuable business was able to find new ways to bend the curve.Its s… [+142 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'investors.com',
#   'title': 'Dow Jones Tech Titan Apple Eyes Latest Buy Point Amid Stock Market Volatility',
#   'description': 'As the Dow Jones Industrial Average and other stock indexes traded higher during Wednesday trade, tech titan Apple (AAPL), Alnylam Pharmaceuticals (ALNY), Hims & Hers Health (HIMS) and Zscaler (ZS) were among the best names to watch in the current market. Wit…',
#   'url': 'https://biztoc.com/x/0336056a447f4931',
#   'urlToImage': 'https://biztoc.com/cdn/0336056a447f4931_s.webp',
#   'publishedAt': '2025-10-15T15:46:59Z',
#   'content': 'As the Dow Jones Industrial Average and other stock indexes traded higher during Wednesday trade, tech titan Apple (AAPL), Alnylam Pharmaceuticals (ALNY), Hims &amp; Hers Health (HIMS) and Zscaler (Z… [+149 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'benzinga.com',
#   'title': 'Apple iPhone 17 Pro, Pro Max Ship Times Stay Stable Globally: Analyst',
#   'description': "Apple's (NASDAQ:AAPL) iPhone 17 Pro and Pro Max maintain stable global lead times, while the iPhone Air remains widely available with nearly all configurations in stock.\nAAPL is demonstrating strength. Stay ahead of the curve here.\nAccording to the Bank of Am…",
#   'url': 'https://biztoc.com/x/32fdd1250b84a4e0',
#   'urlToImage': 'https://biztoc.com/cdn/32fdd1250b84a4e0_s.webp',
#   'publishedAt': '2025-10-15T17:26:38Z',
#   'content': "Apple's (NASDAQ:AAPL) iPhone 17 Pro and Pro Max maintain stable global lead times, while the iPhone Air remains widely available with nearly all configurations in stock.AAPL is demonstrating strength… [+141 chars]"},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'benzinga.com',
#   'title': 'Apple Unveils New M5 Chip Boosting AI, Graphics, Performance Across MacBook Pro, iPad Pro, Vision Pro',
#   'description': 'Apple (NASDAQ:AAPL) stock gained on Wednesday after it unveiled the new M5 chip, featuring advanced graphics processing units (GPUs) with Neural Accelerators, high-performance central processing units (CPUs), and a faster Neural Engine, which supercharges App…',
#   'url': 'https://biztoc.com/x/5f9a956e9fdcf3af',
#   'urlToImage': 'https://biztoc.com/cdn/5f9a956e9fdcf3af_s.webp',
#   'publishedAt': '2025-10-15T15:57:59Z',
#   'content': 'Apple (NASDAQ:AAPL) stock gained on Wednesday after it unveiled the new M5 chip, featuring advanced graphics processing units (GPUs) with Neural Accelerators, high-performance central processing unit… [+138 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Rian Howlett',
#   'title': "Stock market today: S&P 500 and Dow turn higher, Nasdaq dips with Fed's Powell, China tariff tensions in focus",
#   'description': "China upped the ante in its trade spat with the US, rattling investors' nerves as big Wall Street banks kicked off earnings season.",
#   'url': 'https://finance.yahoo.com/news/live/stock-market-today-sp-500-and-dow-turn-higher-nasdaq-dips-with-feds-powell-china-tariff-tensions-in-focus-233314697.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/lvmtNDwzV7lcqAQNJZd0kA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2025-10/6f40c5f0-a863-11f0-b3eb-c74a2e7e85d5',
#   'publishedAt': '2025-10-13T23:33:14Z',
#   'content': "US stocks diverged on Tuesday after China upped the ante in its trade spat with the US, while investors digested the kickoff of third quarter earnings season from Wall Street's banking giants.\r\nThe D… [+12255 chars]"},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Rian Howlett',
#   'title': 'Stock market today: S&P 500, Nasdaq slide as US-China tensions simmer; Dow steadies as big banks report',
#   'description': "China upped the ante in its trade spat with the US, rattling investors' nerves as big Wall Street banks kicked off earnings season.",
#   'url': 'https://finance.yahoo.com/news/live/stock-market-today-sp-500-nasdaq-slide-as-us-china-tensions-simmer-dow-steadies-as-big-banks-report-233314488.html',
# ...
#   'content': 'The\xa0S&amp;P 500 Index ($SPX) (SPY) today is down -0.99%,\xa0the Dow Jones Industrials Index ($DOWI)\xa0(DIA) is down -0.86%, and the\xa0Nasdaq 100 Index ($IUXX) (QQQ) is down -1.37%.\xa0 December E-mini S&amp;P … [+8143 chars]'},
#  {'source': {'id': None, 'name': 'MarketWatch'},
#   'author': 'Barbara Kollmeyer',
#   'title': '‘Expensive, but not nutty.’ Howard Marks on U.S. stocks and the one thing investors should be doing right now.',
#   'description': 'Oaktree co-founder Howard Marks says investors should start taking some “chips off the table,” after a strong run for markets.',
#   'url': 'https://www.marketwatch.com/story/expensive-but-not-nutty-howard-marks-on-u-s-stocks-and-the-one-thing-investors-should-be-doing-right-now-74c75960',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/NYgEExp0I.x2Jt5DHNPvvg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02MDA-/https://media.zenfs.com/en/marketwatch_hosted_869/76cd5b4eb85d5b4d1c5c72381bb52fb5',
#   'publishedAt': '2025-10-15T13:41:00Z',
#   'content': 'Howard Marks, co-chairman and co-founder of Oaktree Capital, pictured in 2021. The widely respected investor has some fresh thoughts on U.S. stocks and what investors should be doing. - patrick t. fa… [+8435 chars]'},
#  {'source': {'id': None, 'name': 'Barchart.com'},
#   'author': 'Rich Asplund',
#   'title': 'Stocks Rebound as President Trump Softens China Rhetoric',
#   'description': 'The S&P 500 Index ($SPX ) (SPY ) today is up +1.22%, the Dow Jones Industrials Index ($DOWI ) (DIA ) is up +0.91%, and the Nasdaq 100 Index ($IUXX ) (QQQ...',
#   'url': 'https://www.barchart.com/story/news/35407923/stocks-rebound-as-president-trump-softens-china-rhetoric',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/aTA0X0Oi8o_pib7JfkoiZw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/barchart_com_477/8c1393d38f5c7ec1f5961087d75b1c44',
#   'publishedAt': '2025-10-13T14:04:26Z',
#   'content': 'The\xa0S&amp;P 500 Index ($SPX) (SPY) today is up +1.22%,\xa0the Dow Jones Industrials Index ($DOWI)\xa0(DIA) is up +0.91%, and the\xa0Nasdaq 100 Index ($IUXX) (QQQ) is up +1.67%.\xa0 December E-mini S&amp;P future… [+8132 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Newtalk新聞 |蘇元和 綜合報導',
#   'title': '美股重點一次看》輝達抱xAI 、AMD攜OpenAI！投資布局全解析',
#   'description': '[Newtalk新聞] 近期AI與半導體產業持續成為市場主軸，主要科技龍頭紛紛釋出策略性合作與投資動向，推升相關供應鏈與晶片股表現強勁。另一方面，隨著衛星通訊、生成式 AI、以及先進製程技術的發展，美股市場結構正快速轉變。整體而言，資金仍圍繞在「AI 基礎設施」與「高性能運算」兩大主題。 以下是國泰證期整理解析最新美股重點與動向： 針對明確 AI 成長動能的個股（如 NVDA、AMD、TSM、PLTR），可沿短中期均線偏多操作；對於基本面穩健但短線漲幅過高的標的（如 ONDS、TSLA），建議等待拉回布局；而蘋果…',
#   'url': 'https://tw.news.yahoo.com/%E7%BE%8E%E8%82%A1%E9%87%8D%E9%BB%9E-%E6%AC%A1%E7%9C%8B-%E8%BC%9D%E9%81%94%E6%8A%B1xai-amd%E6%94%9Copenai-%E6%8A%95%E8%B3%87%E5%B8%83%E5%B1%80%E5%85%A8%E8%A7%A3%E6%9E%90-080234493.html',
#   'urlToImage': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo-1200x1200.png',
#   'publishedAt': '2025-10-11T00:02:34Z',
#   'content': '[Newtalk] AI AIAI \r\n AI NVDAAMDTSMPLTR ONDSTSLA\r\n1NVDA\r\n xAI 200 20 AI xAI SPV GPU GPU AI \r\n2AAPL\r\nStarlink650Direct to Cell15,000GlobalstariPhoneSpaceXiPhoneAAPLAAPL\r\n3TSLA\r\n 9 30 49.71 7% 9 30 7,50… [+415 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': '財訊快報',
#   'title': '蘋果COO走訪果鏈，探訪藍思與瑞聲自動化產線，聚焦i17中框與均熱板',
#   'description': '【財訊快報／陳孟朔】外電報導，蘋果公司(美股代碼AAPL)執行長庫克(Tim Cook)展開訪華行程之際，營運總監(COO)Sabih Khan近日走訪江蘇泰州的藍思精密(藍思科技，06613.HK)，在董事長周群飛陪同下深入車間，觀察iPhone 17與iPhone 17 Pro中框的製程與良率控管，凸顯新機量產節奏與供應穩定性的重要性。藍思目前覆蓋iPhone、Apple Watch、Mac與Apple Vision Pro等多條產品線，是蘋果全球供應鏈的關鍵夥伴之一。Sabih Khan表示，多次造訪中國可…',
#   'url': 'https://tw.stock.yahoo.com/news/%E8%98%8B%E6%9E%9Ccoo%E8%B5%B0%E8%A8%AA%E6%9E%9C%E9%8F%88-%E6%8E%A2%E8%A8%AA%E8%97%8D%E6%80%9D%E8%88%87%E7%91%9E%E8%81%B2%E8%87%AA%E5%8B%95%E5%8C%96%E7%94%A2%E7%B7%9A-%E8%81%9A%E7%84%A6i17%E4%B8%AD%E6%A1%86%E8%88%87%E5%9D%87%E7%86%B1%E6%9D%BF-234921902.html',
#   'urlToImage': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo-1200x1200.png',
#   'publishedAt': '2025-10-15T15:49:21Z',
#   'content': '91,28713.19%99931%85,5005,9608%91,163311.72%\r\n 2'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Rian Howlett',
#   'title': 'Stock market today: Dow, S&P 500, Nasdaq stage comeback as Trump tempers tariff talk toward China',
#   'description': "Markets are assessing Trump's retreat from combative comments on China.",
#   'url': 'https://finance.yahoo.com/news/live/stock-market-today-dow-sp-500-nasdaq-stage-comeback-as-trump-tempers-tariff-talk-toward-china-231010620.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/Pn9I.l1.mOupk2dcXCtwMA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2025-10/5b474fb0-9fc1-11f0-bfb4-6397842a3388',
#   'publishedAt': '2025-10-12T23:10:10Z',
#   'content': 'US stocks surged on Monday, bouncing back from Friday\'s rout after President Trump played down the escalating US trade standoff with China, saying it "will all be fine!"\r\nThe Dow Jones Industrial Ave… [+12011 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Yahoo Finance',
#   'title': 'Stock market today: S&P 500 and Dow rise, Nasdaq slides as US-China tensions simmer, big banks report',
#   'description': "China upped the ante in its trade spat with the US, rattling investors' nerves as big Wall Street banks kicked off earnings season.",
#   'url': 'https://finance.yahoo.com/news/live/stock-market-today-sp-500-and-dow-rise-nasdaq-slides-as-us-china-tensions-simmer-big-banks-report-233314867.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/lvmtNDwzV7lcqAQNJZd0kA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2025-10/6f40c5f0-a863-11f0-b3eb-c74a2e7e85d5',
#   'publishedAt': '2025-10-13T23:33:14Z',
#   'content': "US stocks diverged on Tuesday after China upped the ante in its trade spat with the US, while investors digested the kickoff of third quarter earnings season from Wall Street's banking giants.\r\nThe D… [+12107 chars]"},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Rian Howlett',
#   'title': 'Stock market today: Dow, S&P 500, Nasdaq slip amid strong bank earnings, rate-cut hopes',
#   'description': 'investors weighed hopes for rate cuts and strong results from Wall Street banks as the US-China trade dispute rolled on.',
#   'url': 'https://finance.yahoo.com/news/live/stock-market-today-dow-sp-500-nasdaq-slip-amid-strong-bank-earnings-rate-cut-hopes-231143750.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/Zk7Zl0452fPWsD39P9OVlQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2025-10/627bb6b0-a92e-11f0-9ddf-780113b6af78',
#   'publishedAt': '2025-10-14T23:11:43Z',
#   'content': 'US stocks reversed their gains on Wednesday as markets remained unsettled by US-China trade tensions amid hopes for interest rate cuts and strong results from Wall Street banks.\r\nThe Dow Jones Indust… [+12217 chars]'},
#  {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#   'author': 'Piyush Shukla',
#   'title': 'Why is US stock market booming today: big bank earnings, tech stock surge, and Fed rate-cut hopes power massive Wall Street comeback — see top Dow, S&P 500, Nasdaq winners',
#   'description': 'US stock market booms as bank and tech stocks soar. Dow, S&P 500, and Nasdaq climbed sharply. Strong bank earnings, tech growth, and hopes for a Federal Reserve rate cut boosted investor confidence. Easing U.S.-China trade tensions added fuel to the rally. In…',
#   'url': 'https://economictimes.indiatimes.com/news/international/us/why-is-us-stock-market-booming-today-big-bank-earnings-tech-stock-surge-and-fed-rate-cut-hopes-power-massive-wall-street-comeback-see-top-dow-sp-500-nasdaq-winners/articleshow/124584077.cms',
#   'urlToImage': 'https://img.etimg.com/thumb/msid-124584136,width-1200,height-630,imgsize-111000,overlay-economictimes/articleshow.jpg',
#   'publishedAt': '2025-10-15T15:50:13Z',
#   'content': 'U.S. stock market rose sharply on Wednesday, October 15, 2025. Investors reacted positively to strong bank earnings, hopes for a Federal Reserve rate cut, and easing tensions between the U.S. and Chi… [+5278 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': '財訊快報',
#   'title': '郭明錤揭折疊iPhone鉸鏈成本僅80美元內，立訊精密或後年加入供應鏈',
#   'description': '【財訊快報／陳孟朔】蘋果公司(美股代碼AAPL)傳將於明年推出首款可折疊iPhone。有「最強蘋果分析師」之稱的天風國際證券分析師郭明錤指出，折疊iPhone鉸鏈的大規模量產成本預估為70至80美元，顯著低於市場先前普遍預期的每支100至120美元，為新品定價提供更大彈性，同時不侵蝕旗艦實驗項目的利潤空間。郭明錤表示，軸承單價的大幅下調，有助蘋果在維持毛利的同時釋放價格空間，預期有利於擴大市占；若價格策略反映成本優勢，將提升首代折疊機的滲透速度。 他並強調，成本下降主因在組裝設計優化與鴻海( 2317 )的參與，…',
#   'url': 'https://tw.stock.yahoo.com/news/%E9%83%AD%E6%98%8E%E9%8C%A4%E6%8F%AD%E6%8A%98%E7%96%8Aiphone%E9%89%B8%E9%8F%88%E6%88%90%E6%9C%AC%E5%83%8580%E7%BE%8E%E5%85%83%E5%85%A7-%E7%AB%8B%E8%A8%8A%E7%B2%BE%E5%AF%86%E6%88%96%E5%BE%8C%E5%B9%B4%E5%8A%A0%E5%85%A5%E4%BE%9B%E6%87%89%E9%8F%88-033438631.html',
#   'urlToImage': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo-1200x1200.png',
#   'publishedAt': '2025-10-12T19:34:38Z',
#   'content': 'AIAIADR27,000153140.931.343.30.50.7610F2926,80040027,300OI3,5704,364-30,8874,633-10,453\r\n 4'},
#  {'source': {'id': None, 'name': 'Barchart.com'},
#   'author': 'Rich Asplund',
#   'title': 'Stocks Turn Mixed as Walmart-OpenAI Deal Pushes Dow Higher',
#   'description': 'The S&P 500 Index ($SPX ) (SPY ) today is up 0.09%, the Dow Jones Industrials Index ($DOWI ) (DIA ) is up 0.54%, and the Nasdaq-100 Index ($IUXX ) (QQQ ) is ...',
#   'url': 'https://www.barchart.com/story/news/35436979/stocks-pressured-from-us-china-trade-dispute',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/F_ZJDS12E4olt5iHV3X55A--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/barchart_com_477/fda4fa13493a27d0c8a4c56df32e0629',
#   'publishedAt': '2025-10-14T15:16:59Z',
#   'content': 'The\xa0S&amp;P 500 Index ($SPX) (SPY) today is up 0.09%,\xa0the Dow Jones Industrials Index ($DOWI)\xa0(DIA) is up 0.54%, and the\xa0Nasdaq-100 Index ($IUXX) (QQQ) is down -0.25%.\xa0 December E-mini S&amp;P future… [+8826 chars]'},
#  {'source': {'id': None, 'name': 'Pypi.org'},
#   'author': 'team@nexusdelta.ai',
#   'title': 'nexusdelta-sdk added to PyPI',
#   'description': 'Official Python SDK for the Nexus Delta AI Agent Marketplace',
#   'url': 'https://pypi.org/project/nexusdelta-sdk/',
#   'urlToImage': 'https://pypi.org/static/images/twitter.abaf4b19.webp',
#   'publishedAt': '2025-10-13T12:03:58Z',
#   'content': 'Last Updated: October 12, 2025\r\nNexus Delta is a complete decentralized AI agent marketplace and orchestration platform. This repository contains the full implementation including SDK, microservices,… [+9014 chars]'},
#  {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#   'author': 'Piyush Shukla',
#   'title': 'US stock markets surged sharply today, reversing Friday’s massive loss: Dow, S&P 500, Nasdaq stage comeback as Trump tempers China tariff talk — top stock pick today',
#   'description': 'US stock markets surged Monday. The Dow jumped 574 points, rebounding from Friday’s 1.05% loss. The S&P 500 and Nasdaq gained 1.1% and 1.5%, recovering after Friday’s sharp declines of 0.8% and 1.7%. President Trump eased tariff fears on China. Tech stocks le…',
#   'url': 'https://economictimes.indiatimes.com/news/international/us/us-stock-markets-surged-sharply-today-reversing-fridays-massive-loss-dow-sp-500-nasdaq-stage-comeback-as-trump-tempers-china-tariff-talk-top-stock-pick-today/articleshow/124530996.cms',
#   'urlToImage': 'https://img.etimg.com/thumb/msid-124531578,width-1200,height-630,imgsize-104856,overlay-economictimes/articleshow.jpg',
#   'publishedAt': '2025-10-13T15:59:30Z',
#   'content': 'US stock market today surged sharply, bouncing back after Fridays massive losses. Investors cheered as President Trump eased fears over a potential US-China trade war. He said, Dont worry about China… [+7563 chars]'},
#  {'source': {'id': None, 'name': 'Pypi.org'},
#   'author': 'pm@ml4trading.io',
#   'title': 'rustybt added to PyPI',
#   'description': 'Modern Python backtesting engine built on Zipline-Reloaded, enhanced with Decimal precision, Polars data engine, and live trading capabilities',
#   'url': 'https://pypi.org/project/rustybt/',
#   'urlToImage': 'https://pypi.org/static/images/twitter.abaf4b19.webp',
#   'publishedAt': '2025-10-14T13:58:45Z',
#   'content': 'Modern Python backtesting engine built on Zipline-Reloaded, enhanced with Decimal precision, Polars data engine, and live trading capabilities\r\nOverview\r\nRustyBT is a next-generation Python-based alg… [+7904 chars]'},
#  {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#   'author': 'Piyush Shukla',
#   'title': 'US Stock Market Crash: Why is the US stock market down today? Dow, S&P, Nasdaq plunge as Trump warns of “Massive” China tariffs; AMD, Nvidia, Tesla fall, Rare earth stocks surge',
#   'description': 'U.S. stock market crashes on October 10. Major indexes fell sharply. The S&P 500, Dow Jones, and Nasdaq all dropped. Tech shares AMD, Nvidia, Tesla decline. Rare earth stocks surge as Trump warns of massive China tariffs. Markets brace for Trade War 2.0.',
#   'url': 'https://economictimes.indiatimes.com/news/international/us/us-stock-market-crash-why-is-the-us-stock-market-down-today-dow-jones-sp-500-nasdaq-plunge-as-trump-warns-of-massive-china-tariffs-amd-nvidia-tesla-fall-rare-earth-stocks-surge-wall-street-braces-for-trade-war-2-0/articleshow/124459476.cms',
#   'urlToImage': 'https://img.etimg.com/thumb/msid-124459428,width-1200,height-630,imgsize-249154,overlay-economictimes/articleshow.jpg',
#   'publishedAt': '2025-10-10T16:38:49Z',
#   'content': 'US stock markets slid sharply Friday as President Trump announced plans for a "massive increase" in tariffs on Chinese imports. Investors woke up to a sudden drop, breaking the months-long calm in th… [+10877 chars]'},
#  {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#   'author': 'Piyush Shukla',
#   'title': 'US stock market today rallies strong: Dow jumps 351 points, the S&P 500 gains 1%, and the Nasdaq rises 1.2% as bank earnings smash forecasts, Fed rate-cut hopes lift Wall Street, and trade jitters ease before Trump-Xi talks',
#   'description': 'U.S. stock market rallied sharply Wednesday. Dow Jones Industrial Average rose 351 points (0.8%), while the S&P 500 gained 1%, and the Nasdaq Composite jumped 1.2%. Bank of America (BAC) and Morgan Stanley (MS) led the rally after posting far stronger-than-ex…',
#   'url': 'https://economictimes.indiatimes.com/news/international/us/us-stock-market-today-rallies-strong-dow-jumps-351-points-the-sp-500-gains-1-and-the-nasdaq-rises-1-2-as-bank-earnings-smash-forecasts-fed-rate-cut-hopes-lift-wall-street-and-trade-jitters-ease-before-trump-xi-talks/articleshow/124582313.cms',
#   'urlToImage': 'https://img.etimg.com/thumb/msid-124583065,width-1200,height-630,imgsize-84266,overlay-economictimes/articleshow.jpg',
#   'publishedAt': '2025-10-15T15:11:29Z',
#   'content': 'US stock market today surged sharply as powerful bank earnings and renewed optimism for Federal Reserve rate cuts overpowered fresh trade jitters with China.The Dow Jones Industrial Average jumped 35… [+8871 chars]'},
#  {'source': {'id': None, 'name': 'Slashdot.org'},
#   'author': 'feedfeeder',
#   'title': 'Apple reportedly acquiring computer vision startup Prompt AI’s team and technology - 9to5Mac',
#   'description': 'Apple reportedly acquiring computer vision startup Prompt AI’s team and technology9to5Mac Apple nears deal to acquire talent and technology from computer vision startup Prompt AICNBC M&A News: Apple Is Close to Acquiring Computer Vision Startup Prompt AITipRa…',
#   'url': 'https://slashdot.org/firehose.pl?op=view&amp;id=179753428',
#   'urlToImage': None,
#   'publishedAt': '2025-10-11T10:12:18Z',
#   'content': 'The Fine Print: The following comments are owned by whoever posted them. We are not responsible for them in any way.'}]

# %%
from newspaper import Article

url = arts[0]["url"]
article = Article(url)
article.download()
article.parse()
print(article.text)
# Out:
# Global stock markets fell after China banned certain U.S. shipping firms. Treasury Secretary Scott Bessent said: “If they want to slow down the global economy, they will be hurt the most.” Asian and European indexes all dropped on the news, and S&P 500 futures were in sharp decline prior to the bell in New York. The index itself dropped nearly 1% immediately after the open.
#
# A broad-based selloff swept global stock markets this morning after U.S. Treasury Secretary Scott Bessent told the Financial Times that China “will be hurt the most” if it doesn’t submit to Washington’s trade demands. At the same time, China showed no signs of backing down from President Trump’s trade war: It imposed sanctions banning Chinese companies from doing business with the U.S. subsidiaries of South Korean shipbuilder Hanwha Ocean. South Korea’s KOSPI fell 0.63% on the news.
#
# S&P 500 futures were down 0.87% this morning. The index opened the better part of 1% lower almost immediately. Markets in Asia and Europe were almost all down, with Japan’s Nikkei 225 off 2.58% and Europe’s Stoxx 600 down 0.49% by midmorning.
#
# Beijing’s new export controls on rare earth materials—which the U.S. is dependent on—are “a sign of how weak their economy is, and they want to pull everybody else down with them,” Bessent said. “Maybe there is some Leninist business model where hurting your customers is a good idea, but they are the largest supplier to the world,” he told the FT. “If they want to slow down the global economy, they will be hurt the most.
#
# “They are in the middle of a recession/depression,” he added, “and they are trying to export their way out of it. The problem is they’re exacerbating their standing in the world.” (China is, in fact, doing very well. Its exports rose 8.3% in September, and the World Bank expects China’s GDP to grow 4.8% this year. U.S. growth is forecast at 1.4%.)
#
# The mood among traders today is a stark reversal from yesterday, when the S&P 500 rose 1.56% after investors realized that Trump and China President Xi Jinping will likely meet at the upcoming APEC conference at the end of October—an opportunity for both men to reach one of Trump’s famous deals.
#
# Elsewhere, there wasn’t much to cheer up the markets. A third of bettors on Polymarket think the U.S. government shutdown will continue beyond Nov. 8.
#
# Pantheon Macroeconomics noted that consumer sentiment remains low: The University of Michigan’s consumer survey, which asks whether buyers feel now is a good time to make a major purchase, lately “points to year-over-year growth in this measure of core spending slowing to near-zero soon, a far cry from the 6% pace earlier this year,” according to Samuel Tombs and Oliver Allen.

# %%
type(article.text)
# Out:
# str

# %%
import trafilatura

downloaded = trafilatura.fetch_url(url)
content = trafilatura.extract(downloaded)
content
# Out:
# 'Global markets tumble as Beijing imposes new ban on U.S. shipping. Bessent vows China ‘will be hurt the most’ if it doesn’t surrender\n-\nGlobal stock markets fell after China banned certain U.S. shipping firms. Treasury Secretary Scott Bessent said: “If they want to slow down the global economy, they will be hurt the most.” Asian and European indexes all dropped on the news, and S&P 500 futures were in sharp decline prior to the bell in New York. The index itself dropped nearly 1% immediately after the open.\nA broad-based selloff swept global stock markets this morning after U.S. Treasury Secretary Scott Bessent told the Financial Times that China “will be hurt the most” if it doesn’t submit to Washington’s trade demands. At the same time, China showed no signs of backing down from President Trump’s trade war: It imposed sanctions banning Chinese companies from doing business with the U.S. subsidiaries of South Korean shipbuilder Hanwha Ocean. South Korea’s KOSPI fell 0.63% on the news.\nS&P 500 futures were down 0.87% this morning. The index opened the better part of 1% lower almost immediately. Markets in Asia and Europe were almost all down, with Japan’s Nikkei 225 off 2.58% and Europe’s Stoxx 600 down 0.49% by midmorning.\nBeijing’s new export controls on rare earth materials—which the U.S. is dependent on—are “a sign of how weak their economy is, and they want to pull everybody else down with them,” Bessent said. “Maybe there is some Leninist business model where hurting your customers is a good idea, but they are the largest supplier to the world,” he told the FT. “If they want to slow down the global economy, they will be hurt the most.\n“They are in the middle of a recession/depression,” he added, “and they are trying to export their way out of it. The problem is they’re exacerbating their standing in the world.” (China is, in fact, doing very well. Its exports rose 8.3% in September, and the World Bank expects China’s GDP to grow 4.8% this year. U.S. growth is forecast at 1.4%.)\nThe mood among traders today is a stark reversal from yesterday, when the S&P 500 rose 1.56% after investors realized that Trump and China President Xi Jinping will likely meet at the upcoming APEC conference at the end of October—an opportunity for both men to reach one of Trump’s famous deals.\nElsewhere, there wasn’t much to cheer up the markets. A third of bettors on Polymarket think the U.S. government shutdown will continue beyond Nov. 8.\nPantheon Macroeconomics noted that consumer sentiment remains low: The University of Michigan’s consumer survey, which asks whether buyers feel now is a good time to make a major purchase, lately “points to year-over-year growth in this measure of core spending slowing to near-zero soon, a far cry from the 6% pace earlier this year,” according to Samuel Tombs and Oliver Allen.'

# %%
type(content)
# Out:
# str

# %%
print(len(article.text), len(content))
# Out:
# 2717 2846

# %%
fetch_sentiment("aapl")
# Out:
# [2025-10-17 15:42:50,112: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 15:42:50,112: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# Device set to use cpu
# [2025-10-17 15:42:56,236: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\sentiment created successfully.]
# [2025-10-17 15:42:56,237: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\sentiment\AAPL.json]
# [2025-10-17 15:42:56,238: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 15:42:56,238: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-17 15:42:56,239: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 15:42:56,240: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# {'Overall Sentiment': 0.7928958213643024,
#  'Positive Articles': 25,
#  'Negative Artciles': 13,
#  'Total Artciles': 100,
#  'Category': 'Positive',
#  'Contents': ['Apple Inc. (NASDAQ:AAPL) is one of the AI Stocks Investors Are Watching Closely. On October 3, Jefferies downgraded the stock to “Underperform” from Hold...',
#   'LOS ANGELES (Reuters) -When Tesla directors offered Elon Musk the biggest executive pay package in corporate history in September, it reassured investors...',
#   'China showed no signs of backing down from President Trump’s trade war.',
#   'Apple Inc. (NASDAQ:AAPL) is one of the AI Stocks Shaping Wall Street’s Next Big Rally. On October 6, JPMorgan reiterated the stock as “Overweight” stating...',
#   'Apple Inc. (NASDAQ:AAPL) is one of the AI Stocks in Focus on Wall Street. On October 13, Jefferies reiterated the stock as “Underperform” and lowered its...',
#   'In the last decade, Medtronic (MDT) stock has returned a notable $52 Bil back to its shareholders through cold, hard cash via dividends and buybacks',
#   'Longview Economics says investors should tread carefully with stocks as something was broken with Friday’s selloff last week.',
#   'Investors weighed corporate earnings against the escalating US-China trade war.',
#   'A spate of unusual deals within the AI ecosystem has recently fueled concern that the AI boom is actually an AI bubble, but some professional market watchers...',
#   'Apple on Wednesday announced its latest M5 chip and upgraded MacBook Pro and iPad Pro lines.',
#   'Three weeks into the iPhone 17 cycle, global iPhone lead time data indicates that demand is slightly higher than last year. Gene Munster…\nThe post Sustained iPhone demand points to 2026 upside for Apple – Gene Munster appeared first on MacDailyNews.',
#   'AI companies now make up 14% of the high-grade market from 11.5% in 2020, surpassing US banks, the largest sector on the JPMorgan US Liquid Index (JULI...',
#   "Summary\n- Apple remains resilient amid tariff pressures, with strong free cash flow and stable profit margins demonstrating durable pricing power.\n- APLY, a conservative covered call ETF on AAPL, has captured ~20% of AAPL's ~27% rally, offering defensive upsi…",
#   'Investors paused to assess the optimism around AI and interest-rate cuts that has buoyed markets amid the government shutdown.',
#   'Apple Inc. (NASDAQ:AAPL) is one of the AI Stocks Investors Are Watching Closely. On October 3, Jefferies downgraded the stock to “Underperform” from Hold stating that expectations are too high for a foldable iPhone 18 for Apple. It also lowered its price targ…',
#   'Chronos Wealth Management LLC grew its holdings in shares of Apple Inc. (NASDAQ:AAPL – Free Report) by 0.3% in the second quarter, according to the company in its most recent 13F filing with the Securities and Exchange Commission. The fund owned 59,776 shares…',
#   'McCarthy & Cox lowered its holdings in shares of Apple Inc. (NASDAQ:AAPL – Free Report) by 7.3% during the 2nd quarter, according to its most recent 13F filing with the Securities and Exchange Commission (SEC). The institutional investor owned 1,544 shares of…',
#   'Lynch & Associates IN boosted its position in shares of Apple Inc. (NASDAQ:AAPL – Free Report) by 0.4% during the second quarter, according to the company in its most recent filing with the Securities and Exchange Commission. The firm owned 46,993 shares of t…',
#   'The S&P 500 Index ($SPX ) (SPY ) on Monday closed up +1.56%, the Dow Jones Industrials Index ($DOWI ) (DIA ) closed up +1.29%, and the Nasdaq 100 Index...',
#   'The S&P 500 Index ($SPX ) (SPY ) today is up +1.18%, the Dow Jones Industrials Index ($DOWI ) (DIA ) is up +0.97%, and the Nasdaq 100 Index ($IUXX ) (QQQ...',
#   'Apple Inc. (NASDAQ:AAPL) is one of the AI Stocks Shaping Wall Street’s Next Big Rally. On October 6, JPMorgan reiterated the stock as “Overweight” stating that its channel checks show lead times are moderating for Apple’s iPhone.\n“In Week 4 of our Apple Produ…',
#   'Foster Victor Wealth Advisors LLC increased its position in shares of Apple Inc. (NASDAQ:AAPL – Free Report) by 5.7% during the 2nd quarter, according to the company in its most recent Form 13F filing with the SEC. The fund owned 64,511 shares of the iPhone m…',
#   'Peddock Capital Advisors LLC trimmed its holdings in Apple Inc. (NASDAQ:AAPL – Free Report) by 0.7% during the second quarter, HoldingsChannel reports. The firm owned 105,130 shares of the iPhone maker’s stock after selling 717 shares during the period. Apple…',
#   'Financial Management Professionals Inc. cut its holdings in shares of Apple Inc. (NASDAQ:AAPL – Free Report) by 7.5% during the second quarter, Holdings Channel.com reports. The firm owned 20,732 shares of the iPhone maker’s stock after selling 1,669 shares d…',
#   'TD Private Client Wealth LLC lifted its position in Apple Inc. (NASDAQ:AAPL – Free Report) by 1.1% during the 2nd quarter, HoldingsChannel reports. The institutional investor owned 118,933 shares of the iPhone maker’s stock after acquiring an additional 1,283…',
#   'Apple (NASDAQ:AAPL) has outperformed the market over the past 15 years by 10.82% on an annualized basis producing an average annual return of 22.99%. Currently, Apple has a market capitalization of $3.71 trillion. \nBuying $100 In AAPL: If an ...\nFull story av…',
#   'In many ways, Apple’s (AAPL) 2025 story has been one of quiet resilience. \nDespite sluggish global smartphone demand, the world’s most valuable business was able to find new ways to bend the curve.\nIts success had everything to do with supply-chain recalibrat…',
#   'As the Dow Jones Industrial Average and other stock indexes traded higher during Wednesday trade, tech titan Apple (AAPL), Alnylam Pharmaceuticals (ALNY), Hims & Hers Health (HIMS) and Zscaler (ZS) were among the best names to watch in the current market. Wit…',
#   'Though it varies from analyst to analyst, the expectation is that Apple Inc. (NASDAQ: AAPL) needs to sell 90 million iPhone 17s this year for the new smartphone to be considered a success. The most recent forecast is from Morgan Stanley, which thinks iPhone 1…',
#   'Shares in tech giants Meta Platforms (META) and Apple (AAPL) were higher today as hopes were raised that they are close to settling antitrust disputes with the European Union.\nElevate Your Investing Strategy:\nFinal Stages\nAccording to a report in the Financia…',
#   'Patriot Investment Management Group Inc. reduced its position in shares of Apple Inc. (NASDAQ:AAPL – Free Report) by 0.6% in the 2nd quarter, according to its most recent filing with the Securities and Exchange Commission. The fund owned 37,246 shares of the …',
#   "Apple's (NASDAQ:AAPL) iPhone 17 Pro and Pro Max maintain stable global lead times, while the iPhone Air remains widely available with nearly all configurations in stock.\nAAPL is demonstrating strength. Stay ahead of the curve here.\nAccording to the Bank of Am…",
#   'Apple (NASDAQ:AAPL) stock gained on Wednesday after it unveiled the new M5 chip, featuring advanced graphics processing units (GPUs) with Neural Accelerators, high-performance central processing units (CPUs), and a faster Neural Engine, which supercharges App…',
#   'A key segment of the U.S. stock market, comprised of companies with strong balance sheets and stable earnings, is experiencing a period of underperformance relative to the rest of the market, drawing comparisons to the dot-com bubble of 1999.\nS&P 500 Quality …',
#   "China upped the ante in its trade spat with the US, rattling investors' nerves as big Wall Street banks kicked off earnings season.",
#   "China upped the ante in its trade spat with the US, rattling investors' nerves as big Wall Street banks kicked off earnings season.",
#   'investors weighed hopes for rate cuts and strong results from Wall Street banks as the US-China trade dispute rolled on.',
#   'investors weighed hopes for rate cuts and strong results from Wall Street banks as the US-China trade dispute rolled on.']}

# %% [markdown]
# ## Benchmark Data

# %%
import yfinance as yf

ticker = "SPY"
stock = yf.Ticker(ticker)
info = stock.info  # Pulls full fundamental data

# Select only relevant keys
benchmark = {
    "PE": info.get("trailingPE", "Not Found"),
    "PB": info.get("priceToBook", "Not Found"),
    "Book Value": info.get("bookValue", "Not Found"),
}

benchmark
# Out:
# {'PE': 27.895472, 'PB': 1.5391641, 'Book Value': 429.22}

# %%
import yfinance as yf
from StockScreener.utils.common import read_yaml, load_json

def load_benchmark(ticker: str):
    ticker = ticker.upper()
    sector_path = Path("config/sector_map.yaml")
    sector_map = read_yaml(path=sector_path)

    ticker_sector = load_json(Path(f"artifacts/fundamentals/{ticker}.json")).Sector

    try:
        fetch_benchmark(sector_map.sectors[ticker_sector])
    except:
        pass
    
    try:
        fetch_benchmark(sector_map.market)
    except:
        pass

def get_benchmark_data(ticker: str) -> dict:
    ticker = ticker.upper()
    etf = yf.Ticker(ticker)
    info = etf.info  # Pulls full fundamental data
    
    # Select only relevant keys
    benchmark = {
        "PE": info.get("trailingPE", "Not Found"),
        "PB": info.get("priceToBook", "Not Found"),
        "Book Value": info.get("bookValue", "Not Found"),
    }

    return benchmark


def fetch_benchmark(ticker: str):
    ticker = ticker.upper()
    load_path = WORK_DIR / f"benchmarks/{ticker}.json"

    if Path(load_path).exists() and not is_cache_stale(ticker, "benchmarks"):
        return load_json(load_path)
    
    data = get_benchmark_data(ticker)

    save_json(save_path=load_path, data=data)
    update_cache_index(ticker, "benchmarks")
    
    return data

# %%
sector = load_json(Path(f"artifacts/fundamentals/{"AAPL"}.json")).Sector
# Out:
# [2025-10-17 12:59:24,484: INFO: common: JSON file succesfully loaded form: artifacts\fundamentals\AAPL.json]

# %%
sector_map = read_yaml(path=Path("config/sector_map.yaml"))
sector_map.sectors[sector]
# Out:
# [2025-10-17 12:59:24,491: INFO: common: YAML file: config\sector_map.yaml loaded successfully]
# 'XLK'

# %%
load_benchmark("AAPL")
# Out:
# [2025-10-17 12:59:24,498: INFO: common: YAML file: config\sector_map.yaml loaded successfully]
# [2025-10-17 12:59:24,500: INFO: common: JSON file succesfully loaded form: artifacts\fundamentals\AAPL.json]
# [2025-10-17 12:59:24,501: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 12:59:24,502: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-17 12:59:24,647: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\benchmarks created successfully.]
# [2025-10-17 12:59:24,648: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\benchmarks\XLK.json]
# [2025-10-17 12:59:24,648: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 12:59:24,649: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-17 12:59:24,650: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 12:59:24,653: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-17 12:59:24,654: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 12:59:24,660: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-17 12:59:24,697: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\benchmarks created successfully.]
# [2025-10-17 12:59:24,698: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\benchmarks\SPY.json]
# [2025-10-17 12:59:24,698: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 12:59:24,699: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-17 12:59:24,699: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 12:59:24,700: INFO: common: JSON file saved at: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]

# %% [markdown]
# ## Combined

# %%
def update_all(ticker):
    fetch_prices(ticker)
    fetch_fundamentals(ticker)
    fetch_sentiment(ticker)
    load_benchmark(ticker)

# %%
stock = yf.Ticker("tsla")
info = stock.info
info.get("sector").lower()
# Out:
# 'consumer cyclical'

# %%
ticker = "tsla"
update_all(ticker=ticker)
# Out:
# [2025-10-17 16:02:24,328: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 16:02:24,337: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-17 16:02:24,339: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 16:02:24,340: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-17 16:02:24,341: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\fundamentals\TSLA.json]
# [2025-10-17 16:02:24,341: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 16:02:24,342: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-17 16:02:24,353: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\sentiment\TSLA.json]
# [2025-10-17 16:02:24,355: INFO: common: YAML file: config\sector_map.yaml loaded successfully]
# [2025-10-17 16:02:24,356: INFO: common: JSON file succesfully loaded form: artifacts\fundamentals\TSLA.json]
# [2025-10-17 16:02:24,357: INFO: common: Directory: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts created successfully.]
# [2025-10-17 16:02:24,357: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\cache_index.json]
# [2025-10-17 16:02:24,363: INFO: common: JSON file succesfully loaded form: D:\Projects\Stock Screener\Stock-Screener-Agent\artifacts\benchmarks\SPY.json]

# %% [markdown]
# ## Cleaned

# %%
from dataclasses import dataclass
from pathlib import Path
from StockScreener.utils.logger import get_logger

# Initializing the logger
logger = get_logger()

@dataclass(frozen=True)
class IngestionConfig:
    """
    Immutable configuration class to hold all necessary paths 
    and parameters required for the ingestion stage.
    """
    root_dir: Path

# %%
# TEMP INGESTION PATHS

'''

CACHE_PATH = "artifacts/cache_index.json"
CACHE_EXPIRY_HOURS = 6
working_directory = os.getenv("WORKING_DIRECTORY")


"artifacts/prices/{ticker}.pkl"
load_path = WORK_DIR / f"fundamentals/{ticker}.json"


load_path = WORK_DIR / f"sentiment/{ticker}.json"
api_key = os.getenv("NEWS_API_KEY")
url = f"https://newsapi.org/v2/everything?q={ticker}&from={(datetime.now()-timedelta(days=look_back)).date()}&apiKey={api_key}"


sector_path = Path("config/sector_map.yaml")
ticker_sector = load_json(Path(f"artifacts/fundamentals/{ticker}.json")).Sector


'''
